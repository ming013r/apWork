# %%
import numpy as np
import math
import matplotlib.pyplot as plt  
from sklearn.metrics import mean_squared_error
import pandas as pd

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM, Bidirectional
from keras.layers import Dropout
from keras.callbacks import EarlyStopping

import sys
import xlwt
from sklearn.preprocessing import MinMaxScaler
import datetime,pickle,os,glob


def transfromData(trainRaw, testRaw,windosSize):  ##Train ratial, train, test
    sc = MinMaxScaler(feature_range = (0, 1))
    #npRaw = np.array(rawData)
    #scaledData = sc.fit_transform(npRaw.reshape(-1,1))  
    #trainData = np.array(scaledData[:trainCount]).reshape(-1,1)##train 
    #testData = np.array(scaledData[-testCount:]).reshape(-1,1)
    
    npTrain = sc.fit_transform(np.array(trainRaw).reshape(-1,1))
    npTest = sc.fit_transform(np.array(trainRaw).reshape(-1,1))
    

    X_train, y_train = splitXy(npTrain,windosSize)
    X_test, y_test = splitXy(npTest,windosSize)
    return sc, X_train, y_train, X_test, y_test

def splitXy(data,windosSize):
    windows = []
    for i in range(windosSize, data.shape[0]):
        windows.append(data[i-windosSize:i, 0])
    np.random.shuffle(windows)
    X = []
    y = []
    for i in range(len(windows)):
        X.append(windows[i][:6])
        y.append(windows[i][-(windosSize-6):])
    X, y = np.array(X), np.array(y)
    #X = np.reshape(X, (X.shape[0], X.shape[1], 1))
    return X,y
def buildModel(outShape):

    model = Sequential()
    model.add(Dense(128, input_shape=(6,),activation='tanh'))
    model.add(Dropout(0.2))
    model.add(Dense(64,activation = 'tanh'))
    model.add(Dropout(0.2))
    model.add(Dense(32,activation = 'tanh'))
    model.add(Dropout(0.2))
    
    model.add(Dense(outShape))
    
    model.compile(loss='mse',
                  optimizer='adam')
    return model
def getStationList():
    with open('pickles/stationList.pickle', 'rb') as handle:
        stationList = pickle.load(handle)
    os.chdir('excelFiles/LSTM')
    replaceDict = ['.xls','LSTMresult']
    for direct in glob.glob("*.xls"):
        fileName = direct                                               
        for w in replaceDict:
            fileName = fileName.replace(w,'')
        
        if fileName in stationList:
            stationList.remove(fileName)
            print(fileName)
    os.chdir('../..')
    return stationList
def Visualize():
    predicted = sc.inverse_transform(regressor.predict(X_test))
    originY = sc.inverse_transform (y_test)
    print("MSE : ["+str(mean_squared_error(predicted, originY))+"]")
    # Visualising the results
    plt.plot(originY[:100], color = 'red', label = 'Real')  
    plt.plot(predicted[:100], color = 'blue', label = 'Predicted ') 
    plt.legend()
    plt.show()
def writeExcelHead(sheet1,epochs,station):
    sheet1.write(0,1,station)
    raw = 1
    for e in range(epochs):
        sheet1.write(raw,0,e+1)
        raw+=1


def fetchData(station,windosSize):

    with open('pickles/'+station+'2017trainRaw.pickle', 'rb') as handle:
        trainRawData = pickle.load(handle)
    with open('pickles/'+station+'2017testRaw.pickle', 'rb') as handle:
        testRawData = pickle.load(handle)
        
    sc, X_train, y_train, X_test, y_test = transfromData(trainRawData,testRawData,windosSize)
    return sc, X_train, y_train, X_test, y_test

def train(regressor,sc, X_train, y_train, X_test, y_test,epochs):
 
    for i in range(epochs):
        regressor.fit(X_train, y_train,validation_split=0.2, epochs = 1, batch_size = 32,verbose=2)
        predicted = sc.inverse_transform(regressor.predict(X_test))
        originY = sc.inverse_transform (y_test)
        mse = mean_squared_error(predicted, originY)
        print("Epoch : " +str(i+1)+", MSE : ["+str(mse)+"]")
        print('-------------------------------------------')
    return mse

# %%
epochs = 20
stationList = getStationList()
col=1

for station in stationList:
    print("training : " +station)
    MSEs = []
    for windowSize in range(7,17):
        sc, X_train, y_train, X_test, y_test = fetchData(station,windowSize)
        regressor = buildModel(windowSize-6)
        mse = train(regressor,sc,X_train, y_train, X_test, y_test,epochs)
        MSEs.append(mse)
        print('-------------running station :'+station+'---in '+str(windowSize-6)+'---------check point at ' + str(datetime.datetime.now()))
    
    book = xlwt.Workbook(encoding="utf-8")
    sheet1 = book.add_sheet("Sheet1")
    writeExcelHead(sheet1,epochs,station)
    row = 1
    for m in MSEs:
        sheet1.write(row,1,m)
        row+=1
    book.save("excelFiles/ANN/ANNresult"+station+".xls")

    
db.close()
# Out:
# training : 二林
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 4s - loss: 0.0022 - val_loss: 8.0552e-04
# Epoch : 1, MSE : [43.71211758240629]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0011 - val_loss: 9.2092e-04
# Epoch : 2, MSE : [49.737600784226395]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0011 - val_loss: 7.8779e-04
# Epoch : 3, MSE : [42.41496655069051]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0010 - val_loss: 8.0405e-04
# Epoch : 4, MSE : [43.93936445436947]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 9.6370e-04 - val_loss: 8.0797e-04
# Epoch : 5, MSE : [43.400811990541385]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 9.2709e-04 - val_loss: 8.0844e-04
# Epoch : 6, MSE : [43.11300451282698]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 9.3460e-04 - val_loss: 7.9276e-04
# Epoch : 7, MSE : [42.738677818752166]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 2s - loss: 8.9738e-04 - val_loss: 8.0925e-04
# Epoch : 8, MSE : [43.13192302288367]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 9.0019e-04 - val_loss: 8.0487e-04
# Epoch : 9, MSE : [42.60760428250947]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 9.1767e-04 - val_loss: 0.0015
# Epoch : 10, MSE : [84.33214204604064]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 8.7687e-04 - val_loss: 7.9958e-04
# Epoch : 11, MSE : [42.08480965118925]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 8.8123e-04 - val_loss: 7.9778e-04
# Epoch : 12, MSE : [41.700651113001896]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 8.9847e-04 - val_loss: 8.2649e-04
# Epoch : 13, MSE : [43.22835387480745]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 8.7689e-04 - val_loss: 8.2706e-04
# Epoch : 14, MSE : [42.906841376029156]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 8.9007e-04 - val_loss: 8.3333e-04
# Epoch : 15, MSE : [43.77563389769166]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 8.8711e-04 - val_loss: 8.0661e-04
# Epoch : 16, MSE : [41.6891647818655]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 8.8649e-04 - val_loss: 8.4131e-04
# Epoch : 17, MSE : [43.71981017725541]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 8.8304e-04 - val_loss: 8.9186e-04
# Epoch : 18, MSE : [46.4979645529373]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 8.6499e-04 - val_loss: 8.9968e-04
# Epoch : 19, MSE : [46.694629320417775]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 8.7208e-04 - val_loss: 8.3955e-04
# Epoch : 20, MSE : [43.62643039629383]
# -------------------------------------------
# -------------running station :二林---in 1---------check point at 2019-05-01 14:36:43.672437
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 4s - loss: 0.0028 - val_loss: 0.0012
# Epoch : 1, MSE : [71.92725533057357]
# -------------------------------------------
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0017 - val_loss: 0.0012
# Epoch : 2, MSE : [71.1001301741188]
# -------------------------------------------
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0016 - val_loss: 0.0013
# Epoch : 3, MSE : [76.22639479358324]
# -------------------------------------------
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0015 - val_loss: 0.0012
# Epoch : 4, MSE : [72.38306686732432]
# -------------------------------------------
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0015 - val_loss: 0.0012
# Epoch : 5, MSE : [69.24046052821598]
# -------------------------------------------
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0015 - val_loss: 0.0013
# Epoch : 6, MSE : [78.28966373362022]
# -------------------------------------------
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0015 - val_loss: 0.0012
# Epoch : 7, MSE : [71.62904009858242]
# -------------------------------------------
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0015 - val_loss: 0.0012
# Epoch : 8, MSE : [69.71527148369664]
# -------------------------------------------
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0015 - val_loss: 0.0011
# Epoch : 9, MSE : [68.004143943977]
# -------------------------------------------
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0014 - val_loss: 0.0019
# Epoch : 10, MSE : [109.08925746219214]
# -------------------------------------------
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0014 - val_loss: 0.0013
# Epoch : 11, MSE : [74.1797934023679]
# -------------------------------------------
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0014 - val_loss: 0.0012
# Epoch : 12, MSE : [70.39710192850667]
# -------------------------------------------
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0014 - val_loss: 0.0012
# Epoch : 13, MSE : [69.08019531580312]
# -------------------------------------------
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0014 - val_loss: 0.0012
# Epoch : 14, MSE : [68.87181351293074]
# -------------------------------------------
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0014 - val_loss: 0.0012
# Epoch : 15, MSE : [69.46917253671783]
# -------------------------------------------
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0014 - val_loss: 0.0012
# Epoch : 16, MSE : [69.9174472996288]
# -------------------------------------------
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0014 - val_loss: 0.0012
# Epoch : 17, MSE : [71.16203531433891]
# -------------------------------------------
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0014 - val_loss: 0.0013
# Epoch : 18, MSE : [74.58015955014312]
# -------------------------------------------
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 2s - loss: 0.0014 - val_loss: 0.0012
# Epoch : 19, MSE : [69.15661797794884]
# -------------------------------------------
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0014 - val_loss: 0.0012
# Epoch : 20, MSE : [69.57051219918169]
# -------------------------------------------
# -------------running station :二林---in 2---------check point at 2019-05-01 14:37:30.634787
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 4s - loss: 0.0030 - val_loss: 0.0018
# Epoch : 1, MSE : [99.08764336191469]
# -------------------------------------------
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0022 - val_loss: 0.0020
# Epoch : 2, MSE : [111.59272180679757]
# -------------------------------------------
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0021 - val_loss: 0.0019
# Epoch : 3, MSE : [103.29095102337801]
# -------------------------------------------
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0020 - val_loss: 0.0019
# Epoch : 4, MSE : [108.41333621777625]
# -------------------------------------------
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0020 - val_loss: 0.0019
# Epoch : 5, MSE : [102.55977530958769]
# -------------------------------------------
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0020 - val_loss: 0.0019
# Epoch : 6, MSE : [107.63754340324779]
# -------------------------------------------
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0020 - val_loss: 0.0018
# Epoch : 7, MSE : [100.39478509300375]
# -------------------------------------------
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0020 - val_loss: 0.0019
# Epoch : 8, MSE : [105.531120233079]
# -------------------------------------------
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0019 - val_loss: 0.0019
# Epoch : 9, MSE : [102.57101381586229]
# -------------------------------------------
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0019 - val_loss: 0.0020
# Epoch : 10, MSE : [112.72805856626559]
# -------------------------------------------
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0019 - val_loss: 0.0019
# Epoch : 11, MSE : [103.81271762395164]
# -------------------------------------------
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 2s - loss: 0.0019 - val_loss: 0.0018
# Epoch : 12, MSE : [98.27350307505117]
# -------------------------------------------
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0019 - val_loss: 0.0020
# Epoch : 13, MSE : [113.21717463965172]
# -------------------------------------------
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0019 - val_loss: 0.0018
# Epoch : 14, MSE : [98.06733285649011]
# -------------------------------------------
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0019 - val_loss: 0.0019
# Epoch : 15, MSE : [105.1924107294526]
# -------------------------------------------
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 2s - loss: 0.0019 - val_loss: 0.0018
# Epoch : 16, MSE : [97.91492761066952]
# -------------------------------------------
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 2s - loss: 0.0019 - val_loss: 0.0018
# Epoch : 17, MSE : [98.80862733537629]
# -------------------------------------------
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0019 - val_loss: 0.0018
# Epoch : 18, MSE : [101.12604102902611]
# -------------------------------------------
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0019 - val_loss: 0.0019
# Epoch : 19, MSE : [106.02927144989128]
# -------------------------------------------
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0019 - val_loss: 0.0017
# Epoch : 20, MSE : [97.87590620280582]
# -------------------------------------------
# -------------running station :二林---in 3---------check point at 2019-05-01 14:38:19.904079
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 5s - loss: 0.0035 - val_loss: 0.0021
# Epoch : 1, MSE : [124.09268440297531]
# -------------------------------------------
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0026 - val_loss: 0.0021
# Epoch : 2, MSE : [121.44074428660606]
# -------------------------------------------
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 2s - loss: 0.0025 - val_loss: 0.0022
# Epoch : 3, MSE : [128.05930948511855]
# -------------------------------------------
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0025 - val_loss: 0.0022
# Epoch : 4, MSE : [127.02585441842793]
# -------------------------------------------
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 2s - loss: 0.0025 - val_loss: 0.0022
# Epoch : 5, MSE : [125.2200053129481]
# -------------------------------------------
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0025 - val_loss: 0.0021
# Epoch : 6, MSE : [122.22219389516167]
# -------------------------------------------
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0024 - val_loss: 0.0021
# Epoch : 7, MSE : [122.71358792614198]
# -------------------------------------------
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0024 - val_loss: 0.0021
# Epoch : 8, MSE : [120.9940869777247]
# -------------------------------------------
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0024 - val_loss: 0.0023
# Epoch : 9, MSE : [130.94209379539444]
# -------------------------------------------
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0023 - val_loss: 0.0021
# Epoch : 10, MSE : [123.62085925127354]
# -------------------------------------------
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0023 - val_loss: 0.0022
# Epoch : 11, MSE : [128.17727010161673]
# -------------------------------------------
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 2s - loss: 0.0023 - val_loss: 0.0021
# Epoch : 12, MSE : [121.90977995074721]
# -------------------------------------------
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0023 - val_loss: 0.0021
# Epoch : 13, MSE : [119.7708422002249]
# -------------------------------------------
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0023 - val_loss: 0.0021
# Epoch : 14, MSE : [122.71856604176179]
# -------------------------------------------
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0023 - val_loss: 0.0021
# Epoch : 15, MSE : [120.49266949844588]
# -------------------------------------------
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0023 - val_loss: 0.0023
# Epoch : 16, MSE : [128.96614168962714]
# -------------------------------------------
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 2s - loss: 0.0023 - val_loss: 0.0022
# Epoch : 17, MSE : [126.45638400892715]
# -------------------------------------------
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 2s - loss: 0.0023 - val_loss: 0.0022
# Epoch : 18, MSE : [125.27679025200374]
# -------------------------------------------
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0023 - val_loss: 0.0021
# Epoch : 19, MSE : [123.12623126249886]
# -------------------------------------------
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 2s - loss: 0.0023 - val_loss: 0.0021
# Epoch : 20, MSE : [119.69084958640218]
# -------------------------------------------
# -------------running station :二林---in 4---------check point at 2019-05-01 14:39:12.559201
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 5s - loss: 0.0041 - val_loss: 0.0026
# Epoch : 1, MSE : [145.26012337187353]
# -------------------------------------------
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0029 - val_loss: 0.0026
# Epoch : 2, MSE : [149.29331953179607]
# -------------------------------------------
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0029 - val_loss: 0.0025
# Epoch : 3, MSE : [143.36459452573826]
# -------------------------------------------
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0028 - val_loss: 0.0026
# Epoch : 4, MSE : [150.3882963359681]
# -------------------------------------------
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0028 - val_loss: 0.0025
# Epoch : 5, MSE : [141.153285182105]
# -------------------------------------------
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0027 - val_loss: 0.0025
# Epoch : 6, MSE : [143.14301991232998]
# -------------------------------------------
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0027 - val_loss: 0.0025
# Epoch : 7, MSE : [141.43298875221328]
# -------------------------------------------
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0027 - val_loss: 0.0025
# Epoch : 8, MSE : [141.78969617247049]
# -------------------------------------------
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0027 - val_loss: 0.0025
# Epoch : 9, MSE : [146.64887656867396]
# -------------------------------------------
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0027 - val_loss: 0.0025
# Epoch : 10, MSE : [140.3409491073474]
# -------------------------------------------
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0027 - val_loss: 0.0025
# Epoch : 11, MSE : [141.22526164156176]
# -------------------------------------------
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0026 - val_loss: 0.0025
# Epoch : 12, MSE : [142.48700541902946]
# -------------------------------------------
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0027 - val_loss: 0.0025
# Epoch : 13, MSE : [141.0069335968736]
# -------------------------------------------
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0027 - val_loss: 0.0024
# Epoch : 14, MSE : [140.58773451116784]
# -------------------------------------------
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0026 - val_loss: 0.0024
# Epoch : 15, MSE : [139.41436972109713]
# -------------------------------------------
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0026 - val_loss: 0.0025
# Epoch : 16, MSE : [142.94438170288515]
# -------------------------------------------
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0026 - val_loss: 0.0025
# Epoch : 17, MSE : [142.11928015791418]
# -------------------------------------------
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0026 - val_loss: 0.0025
# Epoch : 18, MSE : [140.6677070648114]
# -------------------------------------------
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0026 - val_loss: 0.0025
# Epoch : 19, MSE : [143.1515378586666]
# -------------------------------------------
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0026 - val_loss: 0.0027
# Epoch : 20, MSE : [152.00404027974065]
# -------------------------------------------
# -------------running station :二林---in 5---------check point at 2019-05-01 14:40:01.535780
# Train on 17136 samples, validate on 4284 samples
# Epoch 1/1
#  - 4s - loss: 0.0045 - val_loss: 0.0029
# Epoch : 1, MSE : [166.3615345849989]
# -------------------------------------------
# Train on 17136 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0033 - val_loss: 0.0029
# Epoch : 2, MSE : [164.92876952403103]
# -------------------------------------------
# Train on 17136 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0032 - val_loss: 0.0030
# Epoch : 3, MSE : [173.01841528119812]
# -------------------------------------------
# Train on 17136 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0031 - val_loss: 0.0028
# Epoch : 4, MSE : [162.90764011033858]
# -------------------------------------------
# Train on 17136 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0031 - val_loss: 0.0028
# Epoch : 5, MSE : [161.5345715808668]
# -------------------------------------------
# Train on 17136 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0031 - val_loss: 0.0028
# Epoch : 6, MSE : [161.71978046955078]
# -------------------------------------------
# Train on 17136 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0030 - val_loss: 0.0028
# Epoch : 7, MSE : [159.0272622360204]
# -------------------------------------------
# Train on 17136 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0030 - val_loss: 0.0028
# Epoch : 8, MSE : [163.38578617918628]
# -------------------------------------------
# Train on 17136 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0030 - val_loss: 0.0027
# Epoch : 9, MSE : [157.08872792535638]
# -------------------------------------------
# Train on 17136 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0030 - val_loss: 0.0027
# Epoch : 10, MSE : [157.7737791400175]
# -------------------------------------------
# Train on 17136 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0030 - val_loss: 0.0029
# Epoch : 11, MSE : [165.88299135394263]
# -------------------------------------------
# Train on 17136 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0029 - val_loss: 0.0028
# Epoch : 12, MSE : [160.54304572939176]
# -------------------------------------------
# Train on 17136 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0030 - val_loss: 0.0028
# Epoch : 13, MSE : [162.17139626932666]
# -------------------------------------------
# Train on 17136 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0029 - val_loss: 0.0028
# Epoch : 14, MSE : [158.22838348607291]
# -------------------------------------------
# Train on 17136 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0029 - val_loss: 0.0027
# Epoch : 15, MSE : [155.73163743721608]
# -------------------------------------------
# Train on 17136 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0029 - val_loss: 0.0029
# Epoch : 16, MSE : [163.50232529433052]
# -------------------------------------------
# Train on 17136 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0029 - val_loss: 0.0028
# Epoch : 17, MSE : [163.65650069020606]
# -------------------------------------------
# Train on 17136 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0029 - val_loss: 0.0027
# Epoch : 18, MSE : [156.86897904339096]
# -------------------------------------------
# Train on 17136 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0029 - val_loss: 0.0027
# Epoch : 19, MSE : [157.43439226888265]
# -------------------------------------------
# Train on 17136 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0029 - val_loss: 0.0029
# Epoch : 20, MSE : [164.9061903051463]
# -------------------------------------------
# -------------running station :二林---in 6---------check point at 2019-05-01 14:40:50.521509
# Train on 17135 samples, validate on 4284 samples
# Epoch 1/1
#  - 5s - loss: 0.0045 - val_loss: 0.0030
# Epoch : 1, MSE : [177.3766695879058]
# -------------------------------------------
# Train on 17135 samples, validate on 4284 samples
# Epoch 1/1
#  - 2s - loss: 0.0035 - val_loss: 0.0029
# Epoch : 2, MSE : [171.59429171481082]
# -------------------------------------------
# Train on 17135 samples, validate on 4284 samples
# Epoch 1/1
#  - 2s - loss: 0.0034 - val_loss: 0.0029
# Epoch : 3, MSE : [171.12519426500302]
# -------------------------------------------
# Train on 17135 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0034 - val_loss: 0.0031
# Epoch : 4, MSE : [180.422831002156]
# -------------------------------------------
# Train on 17135 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0033 - val_loss: 0.0031
# Epoch : 5, MSE : [181.69040313478635]
# -------------------------------------------
# Train on 17135 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0033 - val_loss: 0.0029
# Epoch : 6, MSE : [170.7665980410323]
# -------------------------------------------
# Train on 17135 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0033 - val_loss: 0.0030
# Epoch : 7, MSE : [174.19174747359656]
# -------------------------------------------
# Train on 17135 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0033 - val_loss: 0.0030
# Epoch : 8, MSE : [173.93918111907382]
# -------------------------------------------
# Train on 17135 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0033 - val_loss: 0.0032
# Epoch : 9, MSE : [186.51925744643907]
# -------------------------------------------
# Train on 17135 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0032 - val_loss: 0.0030
# Epoch : 10, MSE : [178.3165983404007]
# -------------------------------------------
# Train on 17135 samples, validate on 4284 samples
# Epoch 1/1
#  - 2s - loss: 0.0032 - val_loss: 0.0030
# Epoch : 11, MSE : [178.48469969198771]
# -------------------------------------------
# Train on 17135 samples, validate on 4284 samples
# Epoch 1/1
#  - 2s - loss: 0.0032 - val_loss: 0.0029
# Epoch : 12, MSE : [171.73982951008938]
# -------------------------------------------
# Train on 17135 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0032 - val_loss: 0.0029
# Epoch : 13, MSE : [169.92008702720423]
# -------------------------------------------
# Train on 17135 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0032 - val_loss: 0.0030
# Epoch : 14, MSE : [174.38055978737106]
# -------------------------------------------
# Train on 17135 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0032 - val_loss: 0.0029
# Epoch : 15, MSE : [171.6474126575688]
# -------------------------------------------
# Train on 17135 samples, validate on 4284 samples
# Epoch 1/1
#  - 2s - loss: 0.0032 - val_loss: 0.0030
# Epoch : 16, MSE : [178.49873967329344]
# -------------------------------------------
# Train on 17135 samples, validate on 4284 samples
# Epoch 1/1
#  - 2s - loss: 0.0032 - val_loss: 0.0030
# Epoch : 17, MSE : [173.1831501742469]
# -------------------------------------------
# Train on 17135 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0032 - val_loss: 0.0029
# Epoch : 18, MSE : [170.1477232446761]
# -------------------------------------------
# Train on 17135 samples, validate on 4284 samples
# Epoch 1/1
#  - 2s - loss: 0.0032 - val_loss: 0.0030
# Epoch : 19, MSE : [172.80783371261006]
# -------------------------------------------
# Train on 17135 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0032 - val_loss: 0.0030
# Epoch : 20, MSE : [172.83647480686423]
# -------------------------------------------
# -------------running station :二林---in 7---------check point at 2019-05-01 14:41:44.717689
# Train on 17134 samples, validate on 4284 samples
# Epoch 1/1
#  - 5s - loss: 0.0046 - val_loss: 0.0033
# Epoch : 1, MSE : [189.98165987190492]
# -------------------------------------------
# Train on 17134 samples, validate on 4284 samples
# Epoch 1/1
#  - 2s - loss: 0.0037 - val_loss: 0.0033
# Epoch : 2, MSE : [185.52644566854661]
# -------------------------------------------
# Train on 17134 samples, validate on 4284 samples
# Epoch 1/1
#  - 2s - loss: 0.0036 - val_loss: 0.0032
# Epoch : 3, MSE : [184.95660232177062]
# -------------------------------------------
# Train on 17134 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0036 - val_loss: 0.0032
# Epoch : 4, MSE : [184.69998131204352]
# -------------------------------------------
# Train on 17134 samples, validate on 4284 samples
# Epoch 1/1
#  - 2s - loss: 0.0035 - val_loss: 0.0032
# Epoch : 5, MSE : [185.27056491166923]
# -------------------------------------------
# Train on 17134 samples, validate on 4284 samples
# Epoch 1/1
#  - 2s - loss: 0.0035 - val_loss: 0.0032
# Epoch : 6, MSE : [185.37168260356012]
# -------------------------------------------
# Train on 17134 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0035 - val_loss: 0.0033
# Epoch : 7, MSE : [186.78568830720315]
# -------------------------------------------
# Train on 17134 samples, validate on 4284 samples
# Epoch 1/1
#  - 2s - loss: 0.0035 - val_loss: 0.0032
# Epoch : 8, MSE : [185.26590040341802]
# -------------------------------------------
# Train on 17134 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0035 - val_loss: 0.0032
# Epoch : 9, MSE : [185.86518583230628]
# -------------------------------------------
# Train on 17134 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0035 - val_loss: 0.0032
# Epoch : 10, MSE : [182.55518643602997]
# -------------------------------------------
# Train on 17134 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0034 - val_loss: 0.0032
# Epoch : 11, MSE : [184.57649256766993]
# -------------------------------------------
# Train on 17134 samples, validate on 4284 samples
# Epoch 1/1
#  - 2s - loss: 0.0034 - val_loss: 0.0032
# Epoch : 12, MSE : [182.4847600664162]
# -------------------------------------------
# Train on 17134 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0034 - val_loss: 0.0033
# Epoch : 13, MSE : [191.4325677103628]
# -------------------------------------------
# Train on 17134 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0034 - val_loss: 0.0032
# Epoch : 14, MSE : [182.30260019383206]
# -------------------------------------------
# Train on 17134 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0034 - val_loss: 0.0033
# Epoch : 15, MSE : [188.51036249858856]
# -------------------------------------------
# Train on 17134 samples, validate on 4284 samples
# Epoch 1/1
#  - 2s - loss: 0.0034 - val_loss: 0.0032
# Epoch : 16, MSE : [186.51762353502187]
# -------------------------------------------
# Train on 17134 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0034 - val_loss: 0.0032
# Epoch : 17, MSE : [182.61847132266365]
# -------------------------------------------
# Train on 17134 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0034 - val_loss: 0.0033
# Epoch : 18, MSE : [187.39267944478405]
# -------------------------------------------
# Train on 17134 samples, validate on 4284 samples
# Epoch 1/1
#  - 2s - loss: 0.0034 - val_loss: 0.0032
# Epoch : 19, MSE : [184.71496295419198]
# -------------------------------------------
# Train on 17134 samples, validate on 4284 samples
# Epoch 1/1
#  - 2s - loss: 0.0034 - val_loss: 0.0032
# Epoch : 20, MSE : [182.2917413582506]
# -------------------------------------------
# -------------running station :二林---in 8---------check point at 2019-05-01 14:42:40.173620
# Train on 17133 samples, validate on 4284 samples
# Epoch 1/1
#  - 5s - loss: 0.0049 - val_loss: 0.0036
# Epoch : 1, MSE : [204.7596867184523]
# -------------------------------------------
# Train on 17133 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0039 - val_loss: 0.0034
# Epoch : 2, MSE : [196.8699364078219]
# -------------------------------------------
# Train on 17133 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0038 - val_loss: 0.0036
# Epoch : 3, MSE : [203.91168955026816]
# -------------------------------------------
# Train on 17133 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0037 - val_loss: 0.0034
# Epoch : 4, MSE : [194.86792220478048]
# -------------------------------------------
# Train on 17133 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0037 - val_loss: 0.0035
# Epoch : 5, MSE : [198.9649829954493]
# -------------------------------------------
# Train on 17133 samples, validate on 4284 samples
# Epoch 1/1
#  - 2s - loss: 0.0037 - val_loss: 0.0036
# Epoch : 6, MSE : [204.19498470039468]
# -------------------------------------------
# Train on 17133 samples, validate on 4284 samples
# Epoch 1/1
#  - 2s - loss: 0.0036 - val_loss: 0.0034
# Epoch : 7, MSE : [197.01738474105466]
# -------------------------------------------
# Train on 17133 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0036 - val_loss: 0.0035
# Epoch : 8, MSE : [198.94478171202974]
# -------------------------------------------
# Train on 17133 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0036 - val_loss: 0.0036
# Epoch : 9, MSE : [203.986920590404]
# -------------------------------------------
# Train on 17133 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0036 - val_loss: 0.0034
# Epoch : 10, MSE : [193.61681805855724]
# -------------------------------------------
# Train on 17133 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0036 - val_loss: 0.0035
# Epoch : 11, MSE : [198.77459621091154]
# -------------------------------------------
# Train on 17133 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0036 - val_loss: 0.0034
# Epoch : 12, MSE : [195.17679051012044]
# -------------------------------------------
# Train on 17133 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0035 - val_loss: 0.0034
# Epoch : 13, MSE : [196.62995816244154]
# -------------------------------------------
# Train on 17133 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0036 - val_loss: 0.0035
# Epoch : 14, MSE : [200.30590059407325]
# -------------------------------------------
# Train on 17133 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0036 - val_loss: 0.0035
# Epoch : 15, MSE : [198.67827866464123]
# -------------------------------------------
# Train on 17133 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0035 - val_loss: 0.0034
# Epoch : 16, MSE : [196.04843351459945]
# -------------------------------------------
# Train on 17133 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0036 - val_loss: 0.0035
# Epoch : 17, MSE : [201.65340307422443]
# -------------------------------------------
# Train on 17133 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0036 - val_loss: 0.0035
# Epoch : 18, MSE : [196.96583133225533]
# -------------------------------------------
# Train on 17133 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0035 - val_loss: 0.0034
# Epoch : 19, MSE : [193.71156716940345]
# -------------------------------------------
# Train on 17133 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0035 - val_loss: 0.0034
# Epoch : 20, MSE : [193.54638071537667]
# -------------------------------------------
# -------------running station :二林---in 9---------check point at 2019-05-01 14:43:29.956082
# Train on 17132 samples, validate on 4284 samples
# Epoch 1/1
#  - 5s - loss: 0.0051 - val_loss: 0.0036
# Epoch : 1, MSE : [206.88162295878337]
# -------------------------------------------
# Train on 17132 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0040 - val_loss: 0.0036
# Epoch : 2, MSE : [207.68020995959054]
# -------------------------------------------
# Train on 17132 samples, validate on 4284 samples
# Epoch 1/1
#  - 2s - loss: 0.0040 - val_loss: 0.0036
# Epoch : 3, MSE : [203.99101083484138]
# -------------------------------------------
# Train on 17132 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0039 - val_loss: 0.0037
# Epoch : 4, MSE : [208.94337426672618]
# -------------------------------------------
# Train on 17132 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0038 - val_loss: 0.0037
# Epoch : 5, MSE : [207.32756844769023]
# -------------------------------------------
# Train on 17132 samples, validate on 4284 samples
# Epoch 1/1
#  - 2s - loss: 0.0039 - val_loss: 0.0036
# Epoch : 6, MSE : [204.0142192155601]
# -------------------------------------------
# Train on 17132 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0038 - val_loss: 0.0037
# Epoch : 7, MSE : [208.87028662810326]
# -------------------------------------------
# Train on 17132 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0038 - val_loss: 0.0036
# Epoch : 8, MSE : [204.91035987567685]
# -------------------------------------------
# Train on 17132 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0038 - val_loss: 0.0036
# Epoch : 9, MSE : [205.35731748348763]
# -------------------------------------------
# Train on 17132 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0038 - val_loss: 0.0036
# Epoch : 10, MSE : [205.80848926668477]
# -------------------------------------------
# Train on 17132 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0038 - val_loss: 0.0036
# Epoch : 11, MSE : [208.23192238922806]
# -------------------------------------------
# Train on 17132 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0037 - val_loss: 0.0036
# Epoch : 12, MSE : [206.35475444074956]
# -------------------------------------------
# Train on 17132 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0037 - val_loss: 0.0036
# Epoch : 13, MSE : [202.83357062926999]
# -------------------------------------------
# Train on 17132 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0037 - val_loss: 0.0036
# Epoch : 14, MSE : [203.60689313939585]
# -------------------------------------------
# Train on 17132 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0037 - val_loss: 0.0036
# Epoch : 15, MSE : [203.16663472274428]
# -------------------------------------------
# Train on 17132 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0037 - val_loss: 0.0036
# Epoch : 16, MSE : [204.33583594060462]
# -------------------------------------------
# Train on 17132 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0037 - val_loss: 0.0038
# Epoch : 17, MSE : [217.48396108871506]
# -------------------------------------------
# Train on 17132 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0037 - val_loss: 0.0037
# Epoch : 18, MSE : [210.75401272966684]
# -------------------------------------------
# Train on 17132 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0037 - val_loss: 0.0036
# Epoch : 19, MSE : [206.579749955414]
# -------------------------------------------
# Train on 17132 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0037 - val_loss: 0.0035
# Epoch : 20, MSE : [201.90156853992855]
# -------------------------------------------
# -------------running station :二林---in 10---------check point at 2019-05-01 14:44:20.613444
# training : 南投
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 5s - loss: 0.0028 - val_loss: 9.2069e-04
# Epoch : 1, MSE : [29.237893111623556]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 2s - loss: 0.0012 - val_loss: 7.4345e-04
# Epoch : 2, MSE : [24.530675513411516]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 2s - loss: 0.0011 - val_loss: 7.5035e-04
# Epoch : 3, MSE : [24.88093082883708]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 2s - loss: 0.0010 - val_loss: 7.7976e-04
# Epoch : 4, MSE : [25.24967157964741]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 2s - loss: 9.8915e-04 - val_loss: 6.2425e-04
# Epoch : 5, MSE : [20.813700378831903]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 2s - loss: 9.7138e-04 - val_loss: 5.7884e-04
# Epoch : 6, MSE : [19.473523235875824]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 2s - loss: 9.3066e-04 - val_loss: 6.5766e-04
# Epoch : 7, MSE : [21.56669919241762]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 2s - loss: 9.4717e-04 - val_loss: 5.7271e-04
# Epoch : 8, MSE : [19.290657484161514]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 2s - loss: 9.1279e-04 - val_loss: 5.9247e-04
# Epoch : 9, MSE : [19.73917769454054]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 3s - loss: 9.1570e-04 - val_loss: 7.2272e-04
# Epoch : 10, MSE : [23.403653330047025]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 2s - loss: 9.1276e-04 - val_loss: 5.8905e-04
# Epoch : 11, MSE : [19.656544463369322]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 2s - loss: 8.9919e-04 - val_loss: 0.0013
# Epoch : 12, MSE : [39.93581753298647]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 2s - loss: 9.0373e-04 - val_loss: 6.3546e-04
# Epoch : 13, MSE : [21.344587301342816]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 2s - loss: 9.1728e-04 - val_loss: 5.9253e-04
# Epoch : 14, MSE : [19.954852199303307]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 2s - loss: 8.9715e-04 - val_loss: 7.7291e-04
# Epoch : 15, MSE : [24.661727030498596]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 2s - loss: 9.1389e-04 - val_loss: 6.2762e-04
# Epoch : 16, MSE : [20.83491562337249]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 2s - loss: 9.1121e-04 - val_loss: 6.0323e-04
# Epoch : 17, MSE : [20.283158934080955]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 2s - loss: 9.2307e-04 - val_loss: 6.1945e-04
# Epoch : 18, MSE : [20.754991533106526]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 2s - loss: 8.9718e-04 - val_loss: 5.9524e-04
# Epoch : 19, MSE : [20.01218734341621]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 2s - loss: 9.0371e-04 - val_loss: 6.6152e-04
# Epoch : 20, MSE : [21.58790147282634]
# -------------------------------------------
# -------------running station :南投---in 1---------check point at 2019-05-01 14:45:24.795713
# Train on 22035 samples, validate on 5509 samples
# Epoch 1/1
#  - 5s - loss: 0.0034 - val_loss: 0.0014
# Epoch : 1, MSE : [42.5204112126261]
# -------------------------------------------
# Train on 22035 samples, validate on 5509 samples
# Epoch 1/1
#  - 2s - loss: 0.0018 - val_loss: 0.0015
# Epoch : 2, MSE : [48.221634192258975]
# -------------------------------------------
# Train on 22035 samples, validate on 5509 samples
# Epoch 1/1
#  - 2s - loss: 0.0017 - val_loss: 0.0014
# Epoch : 3, MSE : [42.88127479865511]
# -------------------------------------------
# Train on 22035 samples, validate on 5509 samples
# Epoch 1/1
#  - 2s - loss: 0.0017 - val_loss: 0.0013
# Epoch : 4, MSE : [40.44402738150746]
# -------------------------------------------
# Train on 22035 samples, validate on 5509 samples
# Epoch 1/1
#  - 2s - loss: 0.0016 - val_loss: 0.0014
# Epoch : 5, MSE : [42.02519443844055]
# -------------------------------------------
# Train on 22035 samples, validate on 5509 samples
# Epoch 1/1
#  - 2s - loss: 0.0016 - val_loss: 0.0013
# Epoch : 6, MSE : [41.140518543960745]
# -------------------------------------------
# Train on 22035 samples, validate on 5509 samples
# Epoch 1/1
#  - 2s - loss: 0.0016 - val_loss: 0.0014
# Epoch : 7, MSE : [43.185188434195155]
# -------------------------------------------
# Train on 22035 samples, validate on 5509 samples
# Epoch 1/1
#  - 2s - loss: 0.0016 - val_loss: 0.0014
# Epoch : 8, MSE : [43.98934074106755]
# -------------------------------------------
# Train on 22035 samples, validate on 5509 samples
# Epoch 1/1
#  - 2s - loss: 0.0016 - val_loss: 0.0013
# Epoch : 9, MSE : [39.349247717910856]
# -------------------------------------------
# Train on 22035 samples, validate on 5509 samples
# Epoch 1/1
#  - 2s - loss: 0.0015 - val_loss: 0.0013
# Epoch : 10, MSE : [39.67172641717497]
# -------------------------------------------
# Train on 22035 samples, validate on 5509 samples
# Epoch 1/1
#  - 2s - loss: 0.0015 - val_loss: 0.0013
# Epoch : 11, MSE : [40.56920909117666]
# -------------------------------------------
# Train on 22035 samples, validate on 5509 samples
# Epoch 1/1
#  - 2s - loss: 0.0015 - val_loss: 0.0014
# Epoch : 12, MSE : [42.47541396962533]
# -------------------------------------------
# Train on 22035 samples, validate on 5509 samples
# Epoch 1/1
#  - 2s - loss: 0.0015 - val_loss: 0.0014
# Epoch : 13, MSE : [43.32470544164762]
# -------------------------------------------
# Train on 22035 samples, validate on 5509 samples
# Epoch 1/1
#  - 2s - loss: 0.0015 - val_loss: 0.0013
# Epoch : 14, MSE : [41.10098718698262]
# -------------------------------------------
# Train on 22035 samples, validate on 5509 samples
# Epoch 1/1
#  - 2s - loss: 0.0015 - val_loss: 0.0013
# Epoch : 15, MSE : [41.58828995660805]
# -------------------------------------------
# Train on 22035 samples, validate on 5509 samples
# Epoch 1/1
#  - 2s - loss: 0.0016 - val_loss: 0.0013
# Epoch : 16, MSE : [39.289348449773485]
# -------------------------------------------
# Train on 22035 samples, validate on 5509 samples
# Epoch 1/1
#  - 2s - loss: 0.0016 - val_loss: 0.0013
# Epoch : 17, MSE : [40.82485802292548]
# -------------------------------------------
# Train on 22035 samples, validate on 5509 samples
# Epoch 1/1
#  - 2s - loss: 0.0015 - val_loss: 0.0013
# Epoch : 18, MSE : [39.28945945706127]
# -------------------------------------------
# Train on 22035 samples, validate on 5509 samples
# Epoch 1/1
#  - 2s - loss: 0.0015 - val_loss: 0.0013
# Epoch : 19, MSE : [40.36842182777012]
# -------------------------------------------
# Train on 22035 samples, validate on 5509 samples
# Epoch 1/1
#  - 2s - loss: 0.0015 - val_loss: 0.0017
# Epoch : 20, MSE : [50.81554198720019]
# -------------------------------------------
# -------------running station :南投---in 2---------check point at 2019-05-01 14:46:28.952673
# Train on 22034 samples, validate on 5509 samples
# Epoch 1/1
#  - 6s - loss: 0.0042 - val_loss: 0.0023
# Epoch : 1, MSE : [71.30149508435375]
# -------------------------------------------
# Train on 22034 samples, validate on 5509 samples
# Epoch 1/1
#  - 2s - loss: 0.0025 - val_loss: 0.0019
# Epoch : 2, MSE : [59.84615968650642]
# -------------------------------------------
# Train on 22034 samples, validate on 5509 samples
# Epoch 1/1
#  - 2s - loss: 0.0024 - val_loss: 0.0019
# Epoch : 3, MSE : [58.15937512615755]
# -------------------------------------------
# Train on 22034 samples, validate on 5509 samples
# Epoch 1/1
#  - 2s - loss: 0.0023 - val_loss: 0.0019
# Epoch : 4, MSE : [58.40057516117034]
# -------------------------------------------
# Train on 22034 samples, validate on 5509 samples
# Epoch 1/1
#  - 2s - loss: 0.0022 - val_loss: 0.0019
# Epoch : 5, MSE : [58.63492251072312]
# -------------------------------------------
# Train on 22034 samples, validate on 5509 samples
# Epoch 1/1
#  - 2s - loss: 0.0022 - val_loss: 0.0019
# Epoch : 6, MSE : [58.651826209196656]
# -------------------------------------------
# Train on 22034 samples, validate on 5509 samples
# Epoch 1/1
#  - 2s - loss: 0.0022 - val_loss: 0.0018
# Epoch : 7, MSE : [57.00956318432582]
# -------------------------------------------
# Train on 22034 samples, validate on 5509 samples
# Epoch 1/1
#  - 2s - loss: 0.0021 - val_loss: 0.0021
# Epoch : 8, MSE : [64.75294679020381]
# -------------------------------------------
# Train on 22034 samples, validate on 5509 samples
# Epoch 1/1
#  - 2s - loss: 0.0022 - val_loss: 0.0022
# Epoch : 9, MSE : [69.05856412239793]
# -------------------------------------------
# Train on 22034 samples, validate on 5509 samples
# Epoch 1/1
#  - 2s - loss: 0.0021 - val_loss: 0.0019
# Epoch : 10, MSE : [58.51450747161775]
# -------------------------------------------
# Train on 22034 samples, validate on 5509 samples
# Epoch 1/1
#  - 2s - loss: 0.0021 - val_loss: 0.0019
# Epoch : 11, MSE : [58.69099821654845]
# -------------------------------------------
# Train on 22034 samples, validate on 5509 samples
# Epoch 1/1
#  - 2s - loss: 0.0021 - val_loss: 0.0020
# Epoch : 12, MSE : [59.84362959075029]
# -------------------------------------------
# Train on 22034 samples, validate on 5509 samples
# Epoch 1/1
#  - 2s - loss: 0.0021 - val_loss: 0.0019
# Epoch : 13, MSE : [57.49800662935726]
# -------------------------------------------
# Train on 22034 samples, validate on 5509 samples
# Epoch 1/1
#  - 3s - loss: 0.0021 - val_loss: 0.0020
# Epoch : 14, MSE : [60.600582494991365]
# -------------------------------------------
# Train on 22034 samples, validate on 5509 samples
# Epoch 1/1
#  - 4s - loss: 0.0021 - val_loss: 0.0020
# Epoch : 15, MSE : [62.69752278965592]
# -------------------------------------------
# Train on 22034 samples, validate on 5509 samples
# Epoch 1/1
#  - 4s - loss: 0.0021 - val_loss: 0.0019
# Epoch : 16, MSE : [57.745764230685076]
# -------------------------------------------
# Train on 22034 samples, validate on 5509 samples
# Epoch 1/1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-911b9487a1ba> in <module>
#      13         sc, X_train, y_train, X_test, y_test = fetchData(cursor,station,windowSize)
#      14         regressor = buildModel(windowSize-6)
# ---> 15         mse = train(regressor,sc,X_train, y_train, X_test, y_test,epochs)
#      16         MSEs.append(mse)
#      17         print('-------------running station :'+station+'---in '+str(windowSize-6)+'---------check point at ' + str(datetime.datetime.now()))
#
# <ipython-input-10-18a54392205f> in train(regressor, sc, X_train, y_train, X_test, y_test, epochs)
#     112
#     113     for i in range(epochs):
# --> 114         regressor.fit(X_train, y_train,validation_split=0.2, epochs = 1, batch_size = 32,verbose=2)
#     115         predicted = sc.inverse_transform(regressor.predict(X_test))
#     116         originY = sc.inverse_transform (y_test)
#
# c:\users\ming\appdata\local\programs\python\python36\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# c:\users\ming\appdata\local\programs\python\python36\lib\site-packages\keras\engine\training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     210                         val_outs = test_loop(model, val_f, val_ins,
#     211                                              batch_size=batch_size,
# --> 212                                              verbose=0)
#     213                         val_outs = to_list(val_outs)
#     214                         # Same labels assumed.
#
# c:\users\ming\appdata\local\programs\python\python36\lib\site-packages\keras\engine\training_arrays.py in test_loop(model, f, ins, batch_size, verbose, steps)
#     390                 ins_batch[i] = ins_batch[i].toarray()
#     391
# --> 392             batch_outs = f(ins_batch)
#     393             if isinstance(batch_outs, list):
#     394                 if batch_index == 0:
#
# c:\users\ming\appdata\local\programs\python\python36\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# c:\users\ming\appdata\local\programs\python\python36\lib\site-packages\keras\backend\tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# c:\users\ming\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
regressor.predict(X_test[:1])
# Out:
# array([[0.05180421, 0.06033435, 0.06701006]], dtype=float32)
