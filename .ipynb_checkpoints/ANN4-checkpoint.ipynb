# %%
import numpy as np
import math
import matplotlib.pyplot as plt  
from sklearn.metrics import mean_squared_error
import pandas as pd

from keras.layers import Dropout
from keras.layers import Dense,Input
from keras.models import Sequential,Model
from keras.callbacks import EarlyStopping
import numpy

import sys
import xlwt
##get data##
import MySQLdb
from sklearn.preprocessing import MinMaxScaler


def transfromData(trainRaw, testRaw,windosSize):  ##Train ratial, train, test
    sc = MinMaxScaler(feature_range = (0, 1))
    #npRaw = np.array(rawData)
    #scaledData = sc.fit_transform(npRaw.reshape(-1,1))  
    #trainData = np.array(scaledData[:trainCount]).reshape(-1,1)##train 
    #testData = np.array(scaledData[-testCount:]).reshape(-1,1)
    
    npTrain = sc.fit_transform(np.array(trainRaw).reshape(-1,1))
    npTest = sc.fit_transform(np.array(trainRaw).reshape(-1,1))
    

    X_train, y_train = splitXy(npTrain,windosSize)
    X_test, y_test = splitXy(npTest,windosSize)
    return sc, X_train, y_train, X_test, y_test

def splitXy(data,windosSize):
    windows = []
    for i in range(windosSize, data.shape[0]):
        windows.append(data[i-windosSize:i, 0])
    np.random.shuffle(windows)
    X = []
    y = []
    for i in range(len(windows)):
        X.append(windows[i][:6])
        y.append(windows[i][-(windosSize-6):])
    X, y = np.array(X), np.array(y)
    #X = np.reshape(X, (X.shape[0], X.shape[1], 1))
    return X,y
def buildModel(outShape):

    model = Sequential()
    model.add(Dense(128, input_shape=(6,),activation='tanh'))
    model.add(Dropout(0.2))
    model.add(Dense(64,activation = 'tanh'))
    model.add(Dropout(0.2))
    model.add(Dense(32,activation = 'tanh'))
    model.add(Dropout(0.2))
    
    model.add(Dense(outShape))
    
    model.compile(loss='mse',
                  optimizer='adam')
    return model
def getStationList(cursor):
    stationList = []
    queryString = "SELECT distinct station from cleandata"
    cursor.execute(queryString)
    results = cursor.fetchall()
    for row in results :
        val = str(row).strip("',()")
        stationList.append(val)
    stationList.remove('富貴角')##only 106少數資料
    return stationList
def Visualize():
    predicted = sc.inverse_transform(regressor.predict(X_test))
    originY = sc.inverse_transform (y_test)
    print("MSE : ["+str(mean_squared_error(predicted, originY))+"]")
    # Visualising the results
    plt.plot(originY[:100], color = 'red', label = 'Real')  
    plt.plot(predicted[:100], color = 'blue', label = 'Predicted ') 
    plt.legend()
    plt.show()
def writeExcelHead(sheet1,epochs,station):
    sheet1.write(0,1,station)
    raw = 1
    for e in range(epochs):
        sheet1.write(raw,0,e+1)
        raw+=1


def fetchData(cursor,station,windosSize):
    queryString = "SELECT * from cleandata where station='"+station+"' and item = 'PM2.5' and date NOT like '2017%'"
    cursor.execute(queryString)
    results = cursor.fetchall()

    trainRawData = []
    for row in results:
        for i in range(3,27):
            trainRawData.append(float(row[i]))
            
    queryString = "SELECT * from cleandata where station='"+station+"' and item = 'PM2.5' and date like '2017%'"
    cursor.execute(queryString)
    results = cursor.fetchall()

    testRawData = []
    for row in results:
        for i in range(3,27):
            testRawData.append(float(row[i]))

    sc, X_train, y_train, X_test, y_test = transfromData(trainRawData,testRawData,windosSize)
    return sc, X_train, y_train, X_test, y_test
def train(regressor,sc, X_train, y_train, X_test, y_test,epochs):
 
    for i in range(epochs):
        regressor.fit(X_train, y_train,validation_split=0.2, epochs = 1, batch_size = 32,verbose=2)
        predicted = sc.inverse_transform(regressor.predict(X_test))
        originY = sc.inverse_transform (y_test)
        mse = mean_squared_error(predicted, originY)
        print("Epoch : " +str(i+1)+", MSE : ["+str(mse)+"]")
        print('-------------------------------------------')
    return mse

# %%
import datetime
db=MySQLdb.connect(host="localhost",user="root", passwd="swater0", db="airdb", charset="utf8")
cursor = db.cursor()

epochs = 20
stationList = getStationList(cursor)
col=1

for station in stationList:
    print("training : " +station)
    MSEs = []
    for windowSize in range(7,17):
        sc, X_train, y_train, X_test, y_test = fetchData(cursor,station,windowSize)
        regressor = buildModel(windowSize-6)
        mse = train(regressor,sc,X_train, y_train, X_test, y_test,epochs)
        MSEs.append(mse)
    print('-------------running station :'+station+'---in '+str(windowSize-6)+'---------check point at ' + str(datetime.datetime.now()))
    
    book = xlwt.Workbook(encoding="utf-8")
    sheet1 = book.add_sheet("Sheet1")
    writeExcelHead(sheet1,epochs,station)
    row = 1
    for m in MSEs:
        sheet1.write(row,1,m)
        row+=1
    book.save("excelFiles/ANN/ANNresult"+station+".xls")

    

db.close()
# Out:
# training : 二林
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 4s - loss: 0.0025 - val_loss: 7.9784e-04
# Epoch : 1, MSE : [43.78982490441386]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0012 - val_loss: 7.6839e-04
# Epoch : 2, MSE : [42.30814039810676]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0011 - val_loss: 8.5786e-04
# Epoch : 3, MSE : [46.78572225516475]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0011 - val_loss: 7.8007e-04
# Epoch : 4, MSE : [42.722269759994596]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0010 - val_loss: 7.5558e-04
# Epoch : 5, MSE : [41.776953501803135]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 9.6780e-04 - val_loss: 7.8692e-04
# Epoch : 6, MSE : [43.047041119361964]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 9.6814e-04 - val_loss: 8.2410e-04
# Epoch : 7, MSE : [45.09420992104118]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 9.4952e-04 - val_loss: 9.4306e-04
# Epoch : 8, MSE : [52.17217362623186]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 9.4406e-04 - val_loss: 8.0979e-04
# Epoch : 9, MSE : [44.319180712266885]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 2s - loss: 8.9542e-04 - val_loss: 7.6270e-04
# Epoch : 10, MSE : [42.256376942459056]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 8.9857e-04 - val_loss: 7.4314e-04
# Epoch : 11, MSE : [41.126453534826894]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 8.8503e-04 - val_loss: 7.7176e-04
# Epoch : 12, MSE : [42.153979973427475]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 8.9258e-04 - val_loss: 8.3566e-04
# Epoch : 13, MSE : [45.84816556606484]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 9.0383e-04 - val_loss: 7.5282e-04
# Epoch : 14, MSE : [41.373614186824895]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 8.8253e-04 - val_loss: 7.6279e-04
# Epoch : 15, MSE : [41.930162137676014]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 9.0201e-04 - val_loss: 7.6028e-04
# Epoch : 16, MSE : [41.86969967314141]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 8.6424e-04 - val_loss: 9.1323e-04
# Epoch : 17, MSE : [49.9770381879121]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 9.0164e-04 - val_loss: 7.5224e-04
# Epoch : 18, MSE : [41.6628690527172]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 8.7369e-04 - val_loss: 8.3570e-04
# Epoch : 19, MSE : [45.562305029334084]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 8.9219e-04 - val_loss: 9.1155e-04
# Epoch : 20, MSE : [50.244290751569935]
# -------------------------------------------
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 4s - loss: 0.0028 - val_loss: 0.0012
# Epoch : 1, MSE : [74.5811241091648]
# -------------------------------------------
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0017 - val_loss: 0.0011
# Epoch : 2, MSE : [68.96358925063726]
# -------------------------------------------
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0016 - val_loss: 0.0012
# Epoch : 3, MSE : [73.14351565475033]
# -------------------------------------------
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0016 - val_loss: 0.0013
# Epoch : 4, MSE : [77.96660915091944]
# -------------------------------------------
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0015 - val_loss: 0.0012
# Epoch : 5, MSE : [71.49167170358044]
# -------------------------------------------
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0015 - val_loss: 0.0012
# Epoch : 6, MSE : [73.33750530857765]
# -------------------------------------------
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0014 - val_loss: 0.0012
# Epoch : 7, MSE : [71.66524775285441]
# -------------------------------------------
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0014 - val_loss: 0.0012
# Epoch : 8, MSE : [72.76541677200792]
# -------------------------------------------
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0015 - val_loss: 0.0011
# Epoch : 9, MSE : [68.62521398104508]
# -------------------------------------------
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0014 - val_loss: 0.0011
# Epoch : 10, MSE : [68.63143548425164]
# -------------------------------------------
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0014 - val_loss: 0.0013
# Epoch : 11, MSE : [75.99416999573549]
# -------------------------------------------
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0014 - val_loss: 0.0011
# Epoch : 12, MSE : [68.3824215312986]
# -------------------------------------------
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0014 - val_loss: 0.0012
# Epoch : 13, MSE : [70.8559617584452]
# -------------------------------------------
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0014 - val_loss: 0.0012
# Epoch : 14, MSE : [69.7253024714865]
# -------------------------------------------
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0014 - val_loss: 0.0012
# Epoch : 15, MSE : [69.45343577631735]
# -------------------------------------------
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0014 - val_loss: 0.0012
# Epoch : 16, MSE : [72.33809135904404]
# -------------------------------------------
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 2s - loss: 0.0014 - val_loss: 0.0012
# Epoch : 17, MSE : [70.42038496864366]
# -------------------------------------------
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0014 - val_loss: 0.0011
# Epoch : 18, MSE : [67.95581146633334]
# -------------------------------------------
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0014 - val_loss: 0.0011
# Epoch : 19, MSE : [69.26369329368607]
# -------------------------------------------
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0014 - val_loss: 0.0011
# Epoch : 20, MSE : [67.77836809109493]
# -------------------------------------------
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 4s - loss: 0.0032 - val_loss: 0.0019
# Epoch : 1, MSE : [107.30305923946294]
# -------------------------------------------
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0022 - val_loss: 0.0017
# Epoch : 2, MSE : [100.73874054177911]
# -------------------------------------------
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0022 - val_loss: 0.0017
# Epoch : 3, MSE : [99.0709978851123]
# -------------------------------------------
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0021 - val_loss: 0.0017
# Epoch : 4, MSE : [99.51768664397628]
# -------------------------------------------
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0021 - val_loss: 0.0017
# Epoch : 5, MSE : [100.9420065270187]
# -------------------------------------------
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0021 - val_loss: 0.0017
# Epoch : 6, MSE : [98.54986666256731]
# -------------------------------------------
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0020 - val_loss: 0.0017
# Epoch : 7, MSE : [101.10276538532518]
# -------------------------------------------
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0020 - val_loss: 0.0018
# Epoch : 8, MSE : [101.87972439865717]
# -------------------------------------------
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0020 - val_loss: 0.0018
# Epoch : 9, MSE : [107.20560514766049]
# -------------------------------------------
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0020 - val_loss: 0.0017
# Epoch : 10, MSE : [100.83309972602085]
# -------------------------------------------
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0020 - val_loss: 0.0017
# Epoch : 11, MSE : [100.64314089729078]
# -------------------------------------------
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0019 - val_loss: 0.0017
# Epoch : 12, MSE : [98.82707432195132]
# -------------------------------------------
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0019 - val_loss: 0.0017
# Epoch : 13, MSE : [97.56061624863473]
# -------------------------------------------
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0019 - val_loss: 0.0017
# Epoch : 14, MSE : [98.24688715055352]
# -------------------------------------------
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0019 - val_loss: 0.0017
# Epoch : 15, MSE : [99.31398865842088]
# -------------------------------------------
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0019 - val_loss: 0.0018
# Epoch : 16, MSE : [106.1818649512491]
# -------------------------------------------
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0019 - val_loss: 0.0018
# Epoch : 17, MSE : [107.04772877246593]
# -------------------------------------------
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0019 - val_loss: 0.0017
# Epoch : 18, MSE : [100.71249988624943]
# -------------------------------------------
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0019 - val_loss: 0.0018
# Epoch : 19, MSE : [102.64856614550729]
# -------------------------------------------
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0019 - val_loss: 0.0018
# Epoch : 20, MSE : [102.68040815043666]
# -------------------------------------------
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 4s - loss: 0.0039 - val_loss: 0.0020
# Epoch : 1, MSE : [123.43543314740825]
# -------------------------------------------
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0026 - val_loss: 0.0020
# Epoch : 2, MSE : [124.1973925601809]
# -------------------------------------------
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0025 - val_loss: 0.0021
# Epoch : 3, MSE : [124.76656187485372]
# -------------------------------------------
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0025 - val_loss: 0.0021
# Epoch : 4, MSE : [124.66877225507383]
# -------------------------------------------
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0025 - val_loss: 0.0021
# Epoch : 5, MSE : [126.26832713745911]
# -------------------------------------------
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0024 - val_loss: 0.0020
# Epoch : 6, MSE : [124.03765669131708]
# -------------------------------------------
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0024 - val_loss: 0.0020
# Epoch : 7, MSE : [123.76389215478522]
# -------------------------------------------
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0024 - val_loss: 0.0020
# Epoch : 8, MSE : [121.2663343538661]
# -------------------------------------------
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0024 - val_loss: 0.0025
# Epoch : 9, MSE : [146.87844333800453]
# -------------------------------------------
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0024 - val_loss: 0.0021
# Epoch : 10, MSE : [123.44538631471836]
# -------------------------------------------
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0024 - val_loss: 0.0021
# Epoch : 11, MSE : [125.36321213778949]
# -------------------------------------------
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0024 - val_loss: 0.0020
# Epoch : 12, MSE : [120.90398719813987]
# -------------------------------------------
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0024 - val_loss: 0.0020
# Epoch : 13, MSE : [122.10995462277253]
# -------------------------------------------
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0023 - val_loss: 0.0020
# Epoch : 14, MSE : [121.1048937424459]
# -------------------------------------------
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0023 - val_loss: 0.0020
# Epoch : 15, MSE : [122.27411398383956]
# -------------------------------------------
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0023 - val_loss: 0.0020
# Epoch : 16, MSE : [121.13397276776755]
# -------------------------------------------
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0023 - val_loss: 0.0020
# Epoch : 17, MSE : [123.79890314591057]
# -------------------------------------------
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0024 - val_loss: 0.0021
# Epoch : 18, MSE : [124.43934042352686]
# -------------------------------------------
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0023 - val_loss: 0.0021
# Epoch : 19, MSE : [124.75780971456454]
# -------------------------------------------
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0023 - val_loss: 0.0022
# Epoch : 20, MSE : [133.51736521715975]
# -------------------------------------------
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 4s - loss: 0.0042 - val_loss: 0.0025
# Epoch : 1, MSE : [157.95623389289298]
# -------------------------------------------
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0030 - val_loss: 0.0023
# Epoch : 2, MSE : [142.13251802471788]
# -------------------------------------------
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0029 - val_loss: 0.0023
# Epoch : 3, MSE : [143.52765422502384]
# -------------------------------------------
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0029 - val_loss: 0.0023
# Epoch : 4, MSE : [141.58961872562193]
# -------------------------------------------
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0028 - val_loss: 0.0024
# Epoch : 5, MSE : [144.08083049924102]
# -------------------------------------------
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0029 - val_loss: 0.0023
# Epoch : 6, MSE : [144.56253126714228]
# -------------------------------------------
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0028 - val_loss: 0.0023
# Epoch : 7, MSE : [142.6889627644474]
# -------------------------------------------
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0028 - val_loss: 0.0023
# Epoch : 8, MSE : [142.8616584571644]
# -------------------------------------------
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0028 - val_loss: 0.0024
# Epoch : 9, MSE : [146.31185561986928]
# -------------------------------------------
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0027 - val_loss: 0.0023
# Epoch : 10, MSE : [143.46772858844557]
# -------------------------------------------
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0027 - val_loss: 0.0023
# Epoch : 11, MSE : [142.2618507518508]
# -------------------------------------------
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0027 - val_loss: 0.0023
# Epoch : 12, MSE : [140.32605932535768]
# -------------------------------------------
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0027 - val_loss: 0.0024
# Epoch : 13, MSE : [145.3658034313728]
# -------------------------------------------
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0027 - val_loss: 0.0023
# Epoch : 14, MSE : [141.87598650569868]
# -------------------------------------------
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0027 - val_loss: 0.0023
# Epoch : 15, MSE : [139.9694071880857]
# -------------------------------------------
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0027 - val_loss: 0.0027
# Epoch : 16, MSE : [167.96472519562718]
# -------------------------------------------
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0027 - val_loss: 0.0023
# Epoch : 17, MSE : [140.25816098980835]
# -------------------------------------------
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0027 - val_loss: 0.0023
# Epoch : 18, MSE : [143.5272181304522]
# -------------------------------------------
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 2s - loss: 0.0027 - val_loss: 0.0023
# Epoch : 19, MSE : [140.7442108007217]
# -------------------------------------------
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0027 - val_loss: 0.0024
# Epoch : 20, MSE : [145.69047081522885]
# -------------------------------------------
# Train on 17136 samples, validate on 4284 samples
# Epoch 1/1
#  - 4s - loss: 0.0044 - val_loss: 0.0027
# Epoch : 1, MSE : [160.27166081857663]
# -------------------------------------------
# Train on 17136 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0032 - val_loss: 0.0027
# Epoch : 2, MSE : [157.59260600432484]
# -------------------------------------------
# Train on 17136 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0031 - val_loss: 0.0027
# Epoch : 3, MSE : [160.36485504686453]
# -------------------------------------------
# Train on 17136 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0031 - val_loss: 0.0029
# Epoch : 4, MSE : [168.1077781156753]
# -------------------------------------------
# Train on 17136 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0031 - val_loss: 0.0028
# Epoch : 5, MSE : [161.64352347596082]
# -------------------------------------------
# Train on 17136 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0031 - val_loss: 0.0027
# Epoch : 6, MSE : [157.29897007135355]
# -------------------------------------------
# Train on 17136 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0030 - val_loss: 0.0027
# Epoch : 7, MSE : [159.14193761414023]
# -------------------------------------------
# Train on 17136 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0030 - val_loss: 0.0027
# Epoch : 8, MSE : [159.29406967092802]
# -------------------------------------------
# Train on 17136 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0030 - val_loss: 0.0027
# Epoch : 9, MSE : [160.18383610945878]
# -------------------------------------------
# Train on 17136 samples, validate on 4284 samples
# Epoch 1/1
#  - 1s - loss: 0.0030 - val_loss: 0.0027
# Epoch : 10, MSE : [160.06507422479055]
# -------------------------------------------
# Train on 17136 samples, validate on 4284 samples
# Epoch 1/1

# %%
X_train.shape
# Out:
# (21422, 9, 1)
