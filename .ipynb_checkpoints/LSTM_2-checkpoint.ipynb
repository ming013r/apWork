# %%
import numpy as np
import math
import matplotlib.pyplot as plt  
from sklearn.metrics import mean_squared_error
import pandas as pd

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM, Bidirectional
from keras.layers import Dropout
from keras.callbacks import EarlyStopping

import sys
import xlwt


def transfromData(trainRaw, testRaw,windosSize):  ##Train ratial, train, test
    sc = MinMaxScaler(feature_range = (0, 1))
    #npRaw = np.array(rawData)
    #scaledData = sc.fit_transform(npRaw.reshape(-1,1))  
    #trainData = np.array(scaledData[:trainCount]).reshape(-1,1)##train 
    #testData = np.array(scaledData[-testCount:]).reshape(-1,1)
    
    npTrain = sc.fit_transform(np.array(trainRaw).reshape(-1,1))
    npTest = sc.fit_transform(np.array(testRaw).reshape(-1,1))
    

    X_train, y_train = splitXy(npTrain,windosSize)
    X_test, y_test = splitXy(npTest,windosSize)
    return sc, X_train, y_train, X_test, y_test

def splitXy(data,windosSize):
    windows = []
    for i in range(windosSize, data.shape[0]):
        windows.append(data[i-windosSize:i, 0])
    np.random.shuffle(windows)
    X = []
    y = []
    for i in range(len(windows)):
        X.append(windows[i][:windosSize-1])
        y.append(windows[i][-1:])
    X, y = np.array(X), np.array(y)
    X = np.reshape(X, (X.shape[0], X.shape[1], 1))
    return X,y
def buildModel():
    regressor = Sequential()
    #regressor.add(Bidirectional(LSTM(units=50,return_sequences=True),input_shape = (X_train.shape[1], 1)))
    regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
    regressor.add(Dropout(0.2))
    regressor.add(LSTM(units = 50))
    regressor.add(Dropout(0.2))
    regressor.add(Dense(units = 1))
    # Compiling
    regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')
    return regressor
def getStationList(cursor):
    stationList = []
    queryString = "SELECT distinct station from cleandata"
    cursor.execute(queryString)
    results = cursor.fetchall()
    for row in results :
        val = str(row).strip("',()")
        stationList.append(val)
    stationList.remove('富貴角')##only 106少數資料
    return stationList
def Visualize():
    predicted = sc.inverse_transform(regressor.predict(X_test))
    originY = sc.inverse_transform (y_test)
    print("MSE : ["+str(mean_squared_error(predicted, originY))+"]")
    # Visualising the results
    plt.plot(originY[:100], color = 'red', label = 'Real')  
    plt.plot(predicted[:100], color = 'blue', label = 'Predicted ') 
    plt.legend()
    plt.show()
def writeExcelHead(sheet1,epochs,station):
    sheet1.write(0,1,station)
    raw = 1
    for e in range(epochs):
        sheet1.write(raw,0,e+1)
        raw+=1

# %%
##get data##
import MySQLdb
import numpy as np
from sklearn.preprocessing import MinMaxScaler
def fetchData(cursor,station,windosSize):
    queryString = "SELECT * from cleandata where station='"+station+"' and item = 'PM2.5' and date NOT like '2017%'"
    cursor.execute(queryString)
    results = cursor.fetchall()

    trainRawData = []
    for row in results:
        for i in range(3,27):
            trainRawData.append(float(row[i]))
            
    queryString = "SELECT * from cleandata where station='"+station+"' and item = 'PM2.5' and date like '2017%'"
    cursor.execute(queryString)
    results = cursor.fetchall()

    testRawData = []
    for row in results:
        for i in range(3,27):
            testRawData.append(float(row[i]))

    sc, X_train, y_train, X_test, y_test = transfromData(trainRawData,testRawData,windosSize)
    return sc, X_train, y_train, X_test, y_test

# %%
def train(regressor,sc, X_train, y_train, X_test, y_test,epochs):
    patient = 50
    p_cnt = 0
    prev_mse = 0.0
    mseList = []
    for i in range(epochs):
        regressor.fit(X_train, y_train,validation_split=0.2, epochs = 1, batch_size = 32,verbose=2)
        predicted = sc.inverse_transform(regressor.predict(X_test))
        originY = sc.inverse_transform (y_test)
        mse = mean_squared_error(predicted, originY)
        mseList.append(mse)
        if prev_mse < mse:
            p_cnt += 1
        if prev_mse >mse :
            p_cnt -= 1
        print("Epoch : " +str(i)+", MSE : ["+str(mse)+"]")
        print('-------------------------------------------')
        prev_mse = mse
    
        if p_cnt > 50 :
            break
    plt.plot(mseList, color = 'blue', label = 'MSEs ') 
    plt.legend()
    plt.show()
    return mseList

# %%
import datetime
db=MySQLdb.connect(host="localhost",user="root", passwd="swater0", db="airdb", charset="utf8")
cursor = db.cursor()


epochs = 200
windosSize = 7

stationList = getStationList(cursor)

col=1
for station in stationList:
    print("training : " +station)
    sc, X_train, y_train, X_test, y_test = fetchData(cursor,station,windosSize)
    regressor = buildModel()
    MSEs = train(regressor,sc,X_train, y_train, X_test, y_test,epochs)
    
    book = xlwt.Workbook(encoding="utf-8")
    sheet1 = book.add_sheet("Sheet1")
    writeExcelHead(sheet1,epochs,station)
    row = 1
    for mse in MSEs:
        sheet1.write(row,1,mse)
        row+=1
    book.save("excelFiles/LSTM/LSTMresult"+station+".xls")
        
    print('check point at ' + str(datetime.datetime.now()))

db.close()
# Out:
# training : 二林
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 9s - loss: 0.0027 - val_loss: 0.0015
# Epoch : 0, MSE : [79.38029047637671]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 4s - loss: 0.0012 - val_loss: 0.0010
# Epoch : 1, MSE : [50.400221864144754]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 5s - loss: 9.0738e-04 - val_loss: 8.5728e-04
# Epoch : 2, MSE : [43.028808381197805]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 4s - loss: 8.6200e-04 - val_loss: 8.5546e-04
# Epoch : 3, MSE : [43.103045571501916]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 4s - loss: 8.1426e-04 - val_loss: 8.2832e-04
# Epoch : 4, MSE : [42.106263103952124]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 5s - loss: 8.1588e-04 - val_loss: 8.6296e-04
# Epoch : 5, MSE : [43.44889706308968]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 4s - loss: 8.0445e-04 - val_loss: 8.5905e-04
# Epoch : 6, MSE : [43.834025832784675]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 4s - loss: 8.1604e-04 - val_loss: 8.2553e-04
# Epoch : 7, MSE : [41.652109503525665]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 4s - loss: 8.2497e-04 - val_loss: 8.2526e-04
# Epoch : 8, MSE : [41.51849757333265]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 4s - loss: 7.9486e-04 - val_loss: 8.1382e-04
# Epoch : 9, MSE : [40.657303121716716]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 5s - loss: 7.8994e-04 - val_loss: 8.7748e-04
# Epoch : 10, MSE : [44.662500045571264]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 4s - loss: 8.0566e-04 - val_loss: 8.1468e-04
# Epoch : 11, MSE : [41.76510198582004]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 4s - loss: 7.9308e-04 - val_loss: 8.1032e-04
# Epoch : 12, MSE : [41.033080890683976]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 5s - loss: 7.9006e-04 - val_loss: 8.0204e-04
# Epoch : 13, MSE : [40.90838781723241]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 4s - loss: 7.8261e-04 - val_loss: 7.9019e-04
# Epoch : 14, MSE : [40.5268795897036]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 4s - loss: 7.7053e-04 - val_loss: 7.8242e-04
# Epoch : 15, MSE : [39.83936597175268]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 4s - loss: 7.7292e-04 - val_loss: 8.7651e-04
# Epoch : 16, MSE : [44.895301927352016]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 4s - loss: 7.8809e-04 - val_loss: 8.2003e-04
# Epoch : 17, MSE : [42.09628376308921]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 4s - loss: 7.7740e-04 - val_loss: 8.2044e-04
# Epoch : 18, MSE : [42.48076342370013]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 5s - loss: 7.7600e-04 - val_loss: 7.9166e-04
# Epoch : 19, MSE : [40.188505014514554]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 6s - loss: 7.6932e-04 - val_loss: 7.8657e-04
# Epoch : 20, MSE : [39.99870305746565]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 5s - loss: 7.6699e-04 - val_loss: 7.8557e-04
# Epoch : 21, MSE : [39.85410040892113]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 5s - loss: 7.6224e-04 - val_loss: 7.7067e-04
# Epoch : 22, MSE : [39.228007868389184]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 4s - loss: 7.6381e-04 - val_loss: 7.9287e-04
# Epoch : 23, MSE : [40.330027258770045]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 5s - loss: 7.6553e-04 - val_loss: 8.0491e-04
# Epoch : 24, MSE : [40.97258394094932]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 4s - loss: 7.6464e-04 - val_loss: 7.7606e-04
# Epoch : 25, MSE : [39.529263149153365]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 5s - loss: 7.7058e-04 - val_loss: 7.9245e-04
# Epoch : 26, MSE : [40.433222248418595]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 5s - loss: 7.6081e-04 - val_loss: 8.0065e-04
# Epoch : 27, MSE : [41.2319042663013]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 4s - loss: 7.6840e-04 - val_loss: 7.8539e-04
# Epoch : 28, MSE : [39.66165376851322]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 4s - loss: 7.6432e-04 - val_loss: 7.9299e-04
# Epoch : 29, MSE : [40.364939258605304]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 4s - loss: 7.5442e-04 - val_loss: 7.7844e-04
# Epoch : 30, MSE : [39.67707684860051]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 5s - loss: 7.4933e-04 - val_loss: 7.6992e-04
# Epoch : 31, MSE : [39.10141105829118]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 4s - loss: 7.5656e-04 - val_loss: 8.0671e-04
# Epoch : 32, MSE : [41.320545460872545]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 4s - loss: 7.6900e-04 - val_loss: 7.8813e-04
# Epoch : 33, MSE : [40.007401797248015]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 5s - loss: 7.5454e-04 - val_loss: 7.9997e-04
# Epoch : 34, MSE : [40.58877519867526]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 4s - loss: 7.5189e-04 - val_loss: 8.1439e-04
# Epoch : 35, MSE : [41.62381316598119]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 4s - loss: 7.3975e-04 - val_loss: 7.8573e-04
# Epoch : 36, MSE : [40.06249624030583]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 4s - loss: 7.5129e-04 - val_loss: 7.7554e-04
# Epoch : 37, MSE : [39.266701616420384]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 4s - loss: 7.4616e-04 - val_loss: 7.9806e-04
# Epoch : 38, MSE : [40.543723150468566]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 5s - loss: 7.4477e-04 - val_loss: 7.8125e-04
# Epoch : 39, MSE : [39.808576272439836]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 5s - loss: 7.5296e-04 - val_loss: 7.8484e-04
# Epoch : 40, MSE : [39.88393869687844]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 4s - loss: 7.5733e-04 - val_loss: 7.8678e-04
# Epoch : 41, MSE : [39.88400371416488]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 4s - loss: 7.4642e-04 - val_loss: 7.9332e-04
# Epoch : 42, MSE : [40.43262591088188]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 4s - loss: 7.4894e-04 - val_loss: 7.7620e-04
# Epoch : 43, MSE : [39.24965643557091]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 4s - loss: 7.4774e-04 - val_loss: 7.7233e-04
# Epoch : 44, MSE : [39.41737457930152]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 4s - loss: 7.5568e-04 - val_loss: 7.7912e-04
# Epoch : 45, MSE : [39.70928535543535]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 4s - loss: 7.4808e-04 - val_loss: 7.6684e-04
# Epoch : 46, MSE : [38.93279421998443]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 4s - loss: 7.4906e-04 - val_loss: 8.0977e-04
# Epoch : 47, MSE : [41.520307925869176]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 5s - loss: 7.5792e-04 - val_loss: 7.9512e-04
# Epoch : 48, MSE : [40.3858511781455]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 5s - loss: 7.6758e-04 - val_loss: 7.8802e-04
# Epoch : 49, MSE : [40.298686321211314]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 5s - loss: 7.4571e-04 - val_loss: 7.8191e-04
# Epoch : 50, MSE : [39.78118837647488]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 5s - loss: 7.4007e-04 - val_loss: 8.0928e-04
# Epoch : 51, MSE : [41.394769581974884]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 5s - loss: 7.4505e-04 - val_loss: 7.7773e-04
# Epoch : 52, MSE : [39.45188478149095]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 5s - loss: 7.4343e-04 - val_loss: 7.7101e-04
# Epoch : 53, MSE : [38.999814673147576]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 4s - loss: 7.4385e-04 - val_loss: 7.7021e-04
# Epoch : 54, MSE : [38.944267570359315]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 5s - loss: 7.4861e-04 - val_loss: 7.6302e-04
# Epoch : 55, MSE : [38.749612870858634]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 4s - loss: 7.4256e-04 - val_loss: 7.9030e-04
# Epoch : 56, MSE : [39.93337773863716]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 4s - loss: 7.4909e-04 - val_loss: 7.7353e-04
# Epoch : 57, MSE : [39.106773520391215]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 4s - loss: 7.
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 8s - loss: 0.0031 - val_loss: 0.0014
# Epoch : 0, MSE : [43.54975151793058]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 5s - loss: 0.0013 - val_loss: 7.4039e-04
# Epoch : 1, MSE : [23.51764392003459]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 5s - loss: 9.0061e-04 - val_loss: 6.2397e-04
# Epoch : 2, MSE : [19.893786192742954]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 6s - loss: 8.2248e-04 - val_loss: 6.4079e-04
# Epoch : 3, MSE : [20.460259154335063]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 5s - loss: 8.1796e-04 - val_loss: 6.7627e-04
# Epoch : 4, MSE : [21.52334217955416]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 5s - loss: 8.0539e-04 - val_loss: 6.1921e-04
# Epoch : 5, MSE : [19.85987283925849]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 6s - loss: 8.0340e-04 - val_loss: 5.8712e-04
# Epoch : 6, MSE : [18.99283073809736]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 5s - loss: 7.8906e-04 - val_loss: 6.0428e-04
# Epoch : 7, MSE : [19.40924987208826]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 5s - loss: 7.6953e-04 - val_loss: 6.1451e-04
# Epoch : 8, MSE : [19.969906787838077]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 5s - loss: 7.8376e-04 - val_loss: 6.2749e-04
# Epoch : 9, MSE : [20.394047416270908]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 5s - loss: 7.7283e-04 - val_loss: 6.0227e-04
# Epoch : 10, MSE : [19.406704087260792]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 5s - loss: 7.6544e-04 - val_loss: 6.0243e-04
# Epoch : 11, MSE : [19.515429550565624]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 5s - loss: 7.6397e-04 - val_loss: 6.4081e-04
# Epoch : 12, MSE : [20.47046891648223]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 5s - loss: 7.7103e-04 - val_loss: 6.8983e-04
# Epoch : 13, MSE : [21.876139535413454]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 5s - loss: 7.6741e-04 - val_loss: 5.9097e-04
# Epoch : 14, MSE : [19.000265419172383]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 5s - loss: 7.5749e-04 - val_loss: 6.0528e-04
# Epoch : 15, MSE : [19.391878576098446]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 5s - loss: 7.6848e-04 - val_loss: 5.9412e-04
# Epoch : 16, MSE : [19.095072866492405]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 5s - loss: 7.6372e-04 - val_loss: 5.9478e-04
# Epoch : 17, MSE : [19.323300855724995]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 5s - loss: 7.6025e-04 - val_loss: 5.9091e-04
# Epoch : 18, MSE : [19.007309367523355]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 5s - loss: 7.6468e-04 - val_loss: 5.9526e-04
# Epoch : 19, MSE : [19.25226305395014]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 5s - loss: 7.4599e-04 - val_loss: 5.9273e-04
# Epoch : 20, MSE : [19.12113766843687]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 5s - loss: 7.6206e-04 - val_loss: 6.0866e-04
# Epoch : 21, MSE : [19.496936133568198]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 5s - loss: 7.6160e-04 - val_loss: 6.2638e-04
# Epoch : 22, MSE : [20.111194250160544]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 5s - loss: 7.4509e-04 - val_loss: 5.8794e-04
# Epoch : 23, MSE : [18.96849116790885]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 5s - loss: 7.5988e-04 - val_loss: 6.0183e-04
# Epoch : 24, MSE : [19.2979022070448]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 5s - loss: 7.4861e-04 - val_loss: 6.0336e-04
# Epoch : 25, MSE : [19.450846673766303]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 5s - loss: 7.7013e-04 - val_loss: 6.2108e-04
# Epoch : 26, MSE : [20.083415416788455]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 5s - loss: 7.4881e-04 - val_loss: 7.1450e-04
# Epoch : 27, MSE : [23.195017495440762]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 5s - loss: 7.5025e-04 - val_loss: 6.2580e-04
# Epoch : 28, MSE : [19.999595049083375]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 5s - loss: 7.6003e-04 - val_loss: 6.5080e-04
# Epoch : 29, MSE : [20.723550982232865]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 5s - loss: 7.5970e-04 - val_loss: 6.2317e-04
# Epoch : 30, MSE : [19.88089279767006]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 5s - loss: 7.5184e-04 - val_loss: 5.9306e-04
# Epoch : 31, MSE : [18.978683773259657]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 5s - loss: 7.5511e-04 - val_loss: 5.9437e-04
# Epoch : 32, MSE : [19.09411527735616]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 5s - loss: 7.5048e-04 - val_loss: 6.0677e-04
# Epoch : 33, MSE : [19.398894691766]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 5s - loss: 7.3911e-04 - val_loss: 5.9661e-04
# Epoch : 34, MSE : [19.162116571864416]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 5s - loss: 7.5425e-04 - val_loss: 6.1191e-04
# Epoch : 35, MSE : [19.72692691885484]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 5s - loss: 7.3872e-04 - val_loss: 6.2065e-04
# Epoch : 36, MSE : [19.87883476016593]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 5s - loss: 7.4199e-04 - val_loss: 6.0637e-04
# Epoch : 37, MSE : [19.377359345759714]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 5s - loss: 7.3710e-04 - val_loss: 5.9646e-04
# Epoch : 38, MSE : [19.14224145896868]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 5s - loss: 7.3859e-04 - val_loss: 5.8896e-04
# Epoch : 39, MSE : [18.83940899617705]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 5s - loss: 7.3310e-04 - val_loss: 6.0819e-04
# Epoch : 40, MSE : [19.49310042274377]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 5s - loss: 7.4462e-04 - val_loss: 5.9459e-04
# Epoch : 41, MSE : [19.2178856198833]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 5s - loss: 7.3487e-04 - val_loss: 6.1105e-04
# Epoch : 42, MSE : [19.520583307233515]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 5s - loss: 7.4449e-04 - val_loss: 6.3263e-04
# Epoch : 43, MSE : [20.147830475471356]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 5s - loss: 7.4573e-04 - val_loss: 5.9284e-04
# Epoch : 44, MSE : [19.027260515705063]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 5s - loss: 7.3548e-04 - val_loss: 5.9227e-04
# Epoch : 45, MSE : [18.927772799764707]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 5s - loss: 7.2667e-04 - val_loss: 5.8876e-04
# Epoch : 46, MSE : [18.986664275606937]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 5s - loss: 7.3161e-04 - val_loss: 5.9303e-04
# Epoch : 47, MSE : [18.982666850464874]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 5s - loss: 7.3332e-04 - val_loss: 5.8731e-04
# Epoch : 48, MSE : [18.8899723428129]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 5s - loss: 7.2654e-04 - val_loss: 6.9143e-04
# Epoch : 49, MSE : [22.20798603539307]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 5s - loss: 7.2059e-04 - val_loss: 5.7868e-04
# Epoch : 50, MSE : [18.547707723336586]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 5s - loss: 7.3221e-04 - val_loss: 5.9166e-04
# Epoch : 51, MSE : [18.875296517847293]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 5s - loss: 7.2983e-04 - val_loss: 5.8294e-04
# Epoch : 52, MSE : [18.614722399081124]
# ...
# Epoch : 140, MSE : [15.858124471189653]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 7s - loss: 5.5462e-04 - val_loss: 5.3037e-04
# Epoch : 141, MSE : [15.704886681736697]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 7s - loss: 5.4874e-04 - val_loss: 5.5348e-04
# Epoch : 142, MSE : [16.330279527543684]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 7s - loss: 5.4986e-04 - val_loss: 5.3921e-04
# Epoch : 143, MSE : [16.074311400595352]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 7s - loss: 5.4910e-04 - val_loss: 5.3752e-04
# Epoch : 144, MSE : [16.267846863829597]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 7s - loss: 5.5259e-04 - val_loss: 5.3354e-04
# Epoch : 145, MSE : [15.757707922096603]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 7s - loss: 5.5142e-04 - val_loss: 5.3905e-04
# Epoch : 146, MSE : [15.79930408678992]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 7s - loss: 5.4834e-04 - val_loss: 5.3160e-04
# Epoch : 147, MSE : [15.71014003701101]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 6s - loss: 5.5545e-04 - val_loss: 5.7294e-04
# Epoch : 148, MSE : [17.446065463055017]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 7s - loss: 5.4329e-04 - val_loss: 5.3527e-04
# Epoch : 149, MSE : [15.800655429061981]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 7s - loss: 5.4127e-04 - val_loss: 5.3543e-04
# Epoch : 150, MSE : [15.76938835898113]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 7s - loss: 5.4474e-04 - val_loss: 5.3809e-04
# Epoch : 151, MSE : [16.176528265730255]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 7s - loss: 5.4530e-04 - val_loss: 5.4028e-04
# Epoch : 152, MSE : [15.942869650078181]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 7s - loss: 5.4824e-04 - val_loss: 5.3198e-04
# Epoch : 153, MSE : [15.857137518283192]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 7s - loss: 5.4489e-04 - val_loss: 5.3071e-04
# Epoch : 154, MSE : [15.772891487084276]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 7s - loss: 5.4632e-04 - val_loss: 5.2957e-04
# Epoch : 155, MSE : [15.673269286319066]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 7s - loss: 5.5125e-04 - val_loss: 5.6074e-04
# Epoch : 156, MSE : [16.28223698620028]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 7s - loss: 5.5355e-04 - val_loss: 5.2774e-04
# Epoch : 157, MSE : [15.634101110139715]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 7s - loss: 5.4918e-04 - val_loss: 5.3091e-04
# Epoch : 158, MSE : [15.730721243877246]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 6s - loss: 5.4576e-04 - val_loss: 5.3660e-04
# Epoch : 159, MSE : [16.11909568659794]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 7s - loss: 5.4822e-04 - val_loss: 5.3896e-04
# Epoch : 160, MSE : [16.294799333209095]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 7s - loss: 5.4257e-04 - val_loss: 5.2614e-04
# Epoch : 161, MSE : [15.64020232028478]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 7s - loss: 5.4928e-04 - val_loss: 5.4678e-04
# Epoch : 162, MSE : [15.904200226326546]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 7s - loss: 5.5383e-04 - val_loss: 5.4063e-04
# Epoch : 163, MSE : [16.011237991832594]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 7s - loss: 5.4944e-04 - val_loss: 5.2638e-04
# Epoch : 164, MSE : [15.729394685155595]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 7s - loss: 5.4687e-04 - val_loss: 5.3175e-04
# Epoch : 165, MSE : [15.759166545172318]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 7s - loss: 5.4707e-04 - val_loss: 5.3331e-04
# Epoch : 166, MSE : [15.700405548887517]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 7s - loss: 5.4734e-04 - val_loss: 5.3589e-04
# Epoch : 167, MSE : [15.718220480253072]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 7s - loss: 5.4674e-04 - val_loss: 5.5192e-04
# Epoch : 168, MSE : [16.017905652014903]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 7s - loss: 5.3936e-04 - val_loss: 5.3805e-04
# Epoch : 169, MSE : [16.27513783836188]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 7s - loss: 5.4387e-04 - val_loss: 5.3411e-04
# Epoch : 170, MSE : [15.704628855303463]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 7s - loss: 5.4779e-04 - val_loss: 5.4375e-04
# Epoch : 171, MSE : [16.10819182257404]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 7s - loss: 5.4699e-04 - val_loss: 5.4450e-04
# Epoch : 172, MSE : [16.403140987597535]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 7s - loss: 5.4080e-04 - val_loss: 5.2838e-04
# Epoch : 173, MSE : [15.68395541686801]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 7s - loss: 5.4191e-04 - val_loss: 5.3533e-04
# Epoch : 174, MSE : [16.00645727914747]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 7s - loss: 5.5158e-04 - val_loss: 5.3181e-04
# Epoch : 175, MSE : [15.625832629965114]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 7s - loss: 5.4733e-04 - val_loss: 5.4011e-04
# Epoch : 176, MSE : [15.758354722689862]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 7s - loss: 5.4319e-04 - val_loss: 5.4148e-04
# Epoch : 177, MSE : [16.077158497325456]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 6s - loss: 5.5094e-04 - val_loss: 5.3477e-04
# Epoch : 178, MSE : [15.850502356243604]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 7s - loss: 5.4681e-04 - val_loss: 5.4812e-04
# Epoch : 179, MSE : [15.951749284264007]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 7s - loss: 5.4448e-04 - val_loss: 5.5377e-04
# Epoch : 180, MSE : [16.586282794830762]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 7s - loss: 5.5245e-04 - val_loss: 5.6182e-04
# Epoch : 181, MSE : [16.706894518218007]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 7s - loss: 5.4064e-04 - val_loss: 5.3898e-04
# Epoch : 182, MSE : [16.084882354618916]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 7s - loss: 5.4650e-04 - val_loss: 5.2947e-04
# Epoch : 183, MSE : [15.63870621234677]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 7s - loss: 5.4497e-04 - val_loss: 5.4289e-04
# Epoch : 184, MSE : [16.115514351191603]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 7s - loss: 5.4368e-04 - val_loss: 5.8192e-04
# Epoch : 185, MSE : [17.044347606094888]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 7s - loss: 5.4980e-04 - val_loss: 5.3089e-04
# Epoch : 186, MSE : [15.783067104579585]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 7s - loss: 5.4571e-04 - val_loss: 5.4986e-04
# Epoch : 187, MSE : [15.951577416100573]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 7s - loss: 5.4195e-04 - val_loss: 5.3833e-04
# Epoch : 188, MSE : [15.904093059650922]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 7s - loss: 5.5156e-04 - val_loss: 5.3350e-04
# Epoch : 189, MSE : [15.844827082077442]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 7s - loss: 5.4056e-04 - val_loss: 5.3444e-04
# Epoch : 190, MSE : [15.96171992858722]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 7s - loss: 5.4185e-04 - val_loss: 5.3801e-04
# Epoch : 191, MSE : [15.832060691761136]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 7s - loss: 5.3945e-04 - val_loss: 5.5600e-04
# Epoch : 192, MSE : [16.473038401033335]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 7s - loss: 5.4567e-04 - val_loss: 5.3374e-04
# Epoch : 193, MSE : [15.826899706669783]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 7s - loss: 5.4567e-04 - val_loss: 5.5305e-04
# Epoch : 194, MSE : [16.770476987528948]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 7s - loss: 5.4731e-04 - val_loss: 5.3206e-04
# Epoch : 195, MSE : [15.91074284136039]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 7s - loss: 5.4064e-04 - val_loss: 5.3593e-04
# Epoch : 196, MSE : [16.098983294264524]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 7s - loss: 5.4568e-04 - val_loss: 5.4412e-04
# Epoch : 197, MSE : [15.905683005821608]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 7s - loss: 5.4468e-04 - val_loss: 5.6127e-04
# Epoch : 198, MSE : [16.29197900180715]
# -------------------------------------------
# Train on 22400 samples, validate on 5601 samples
# Epoch 1/1
#  - 7s - loss: 5.4159e-04 - val_loss: 5.4533e-04
# Epoch : 199, MSE : [16.40489537927157]
# -------------------------------------------
# check point at 2019-04-25 20:42:49.541390
# training : 桃園
# Train on 21767 samples, validate on 5442 samples
# Epoch 1/1
#  - 14s - loss: 0.0025 - val_loss: 0.0013
# Epoch : 0, MSE : [37.2312468899287]
# -------------------------------------------
# Train on 21767 samples, validate on 5442 samples
# Epoch 1/1
#  - 7s - loss: 0.0012 - val_loss: 0.0010
# Epoch : 1, MSE : [29.272475738619057]
# -------------------------------------------
# Train on 21767 samples, validate on 5442 samples
# Epoch 1/1
#  - 7s - loss: 0.0011 - val_loss: 9.7932e-04
# Epoch : 2, MSE : [28.16067484836485]
# -------------------------------------------
# Train on 21767 samples, validate on 5442 samples
# Epoch 1/1
#  - 7s - loss: 0.0011 - val_loss: 0.0010
# Epoch : 3, MSE : [30.17661692034833]
# -------------------------------------------
# Train on 21767 samples, validate on 5442 samples
# Epoch 1/1
#  - 7s - loss: 0.0010 - val_loss: 8.9082e-04
# Epoch : 4, MSE : [25.921047003461076]
# -------------------------------------------
# Train on 21767 samples, validate on 5442 samples
# Epoch 1/1
#  - 7s - loss: 9.9120e-04 - val_loss: 9.1143e-04
# Epoch : 5, MSE : [26.50665083866841]
# -------------------------------------------
# Train on 21767 samples, validate on 5442 samples
# Epoch 1/1
#  - 7s - loss: 9.8379e-04 - val_loss: 9.7167e-04
# Epoch : 6, MSE : [28.605495058126827]
# -------------------------------------------
# Train on 21767 samples, validate on 5442 samples
# Epoch 1/1
#  - 7s - loss: 9.9321e-04 - val_loss: 8.8283e-04
# Epoch : 7, MSE : [25.760023153109273]
# -------------------------------------------
# Train on 21767 samples, validate on 5442 samples
# Epoch 1/1
#  - 7s - loss: 9.8146e-04 - val_loss: 8.6495e-04
# Epoch : 8, MSE : [25.224341408786955]
# -------------------------------------------
# Train on 21767 samples, validate on 5442 samples
# Epoch 1/1
#  - 7s - loss: 9.8232e-04 - val_loss: 8.5417e-04
# Epoch : 9, MSE : [25.00376716269063]
# -------------------------------------------
# Train on 21767 samples, validate on 5442 samples
# Epoch 1/1
#  - 7s - loss: 9.6493e-04 - val_loss: 8.5608e-04
# Epoch : 10, MSE : [24.92522515426205]
# -------------------------------------------
# Train on 21767 samples, validate on 5442 samples
# Epoch 1/1
#  - 7s - loss: 9.5836e-04 - val_loss: 8.4083e-04
# Epoch : 11, MSE : [24.586079891013718]
# -------------------------------------------
# Train on 21767 samples, validate on 5442 samples
# Epoch 1/1
#  - 7s - loss: 9.6425e-04 - val_loss: 9.1466e-04
# Epoch : 12, MSE : [26.827204609845342]
# -------------------------------------------
# Train on 21767 samples, validate on 5442 samples
# Epoch 1/1
#  - 7s - loss: 9.5893e-04 - val_loss: 8.4898e-04
# Epoch : 13, MSE : [24.758785832967284]
# -------------------------------------------
# Train on 21767 samples, validate on 5442 samples
# Epoch 1/1
#  - 7s - loss: 9.4783e-04 - val_loss: 8.6618e-04
# Epoch : 14, MSE : [25.17801840442779]
# -------------------------------------------
# Train on 21767 samples, validate on 5442 samples
# Epoch 1/1
#  - 7s - loss: 9.5163e-04 - val_loss: 8.4892e-04
# Epoch : 15, MSE : [24.69943735219362]
# -------------------------------------------
# Train on 21767 samples, validate on 5442 samples
# Epoch 1/1
#  - 6s - loss: 9.4866e-04 - val_loss: 8.5520e-04
# Epoch : 16, MSE : [25.022862656178226]
# -------------------------------------------
# Train on 21767 samples, validate on 5442 samples
# Epoch 1/1
#  - 6s - loss: 9.4740e-04 - val_loss: 8.5129e-04
# Epoch : 17, MSE : [24.893798887468215]
# -------------------------------------------
# Train on 21767 samples, validate on 5442 samples
# Epoch 1/1
#  - 7s - loss: 9.4075e-04 - val_loss: 8.5834e-04
# Epoch : 18, MSE : [25.11474405073112]
# -------------------------------------------
# Train on 21767 samples, validate on 5442 samples
# Epoch 1/1
#  - 6s - loss: 9.4456e-04 - val_loss: 8.3677e-04
# Epoch : 19, MSE : [24.52968313975908]
# -------------------------------------------
# Train on 21767 samples, validate on 5442 samples
# Epoch 1/1
#  - 7s - loss: 9.4330e-04 - val_loss: 8.5983e-04
# Epoch : 20, MSE : [25.218732755874473]
# -------------------------------------------
# Train on 21767 samples, validate on 5442 samples
# Epoch 1/1
#  - 7s - loss: 9.4137e-04 - val_loss: 8.5569e-04
# Epoch : 21, MSE : [25.059177787451812]
# -------------------------------------------
# Train on 21767 samples, validate on 5442 samples
# Epoch 1/1
#  - 7s - loss: 9.4346e-04 - val_loss: 8.4913e-04
# Epoch : 22, MSE : [24.764224482877708]
# -------------------------------------------
# Train on 21767 samples, validate on 5442 samples
# Epoch 1/1
#  - 7s - loss: 9.4237e-04 - val_loss: 8.8798e-04
# Epoch : 23, MSE : [25.94920187382495]
# -------------------------------------------
# Train on 21767 samples, validate on 5442 samples
# Epoch 1/1

# %%
book.save("Test1EXCCCC.xls")
