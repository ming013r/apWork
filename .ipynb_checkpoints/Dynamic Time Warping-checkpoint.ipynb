# %%
import numpy as np
from dtw import dtw

x = np.array([2, 0, 1, 1, 2, 4, 2, 1, 2, 0]).reshape(-1, 1)
y = np.array([1, 1, 2, 4, 2, 1, 2, 0]).reshape(-1, 1)
euclidean_norm = lambda x, y: np.abs(x - y)

d, cost_matrix, acc_cost_matrix, path = dtw(x, y, dist=euclidean_norm)

# %%
import pickle
import datetime
def getStation():
    with open('DBaccess/dbPickle/stationList.pickle', 'rb') as f:
        stationList = pickle.load(f)
    return stationList
def loadDB():
    with open('DBaccess/dbPickle/cleandataDB.pickle', 'rb') as f:
        DB = pickle.load(f)
    return DB
def stationFilter(DB,station):
    DB2 = []
    for row in DB:
        if row[1] == station:
            DB2.append(row)
    return DB2
def DTWD(x,y):
    x = np.array(x).reshape(-1, 1)
    y = np.array(y).reshape(-1, 1)
    euclidean_norm = lambda x, y: np.abs(x - y)
    d, cost_matrix, acc_cost_matrix, path = dtw(x, y, dist=euclidean_norm)
def emptyDateFilter(DB,stations):
    DateList = []
    for year in range(2013,2019):
        for month in range(0,13):
            for day in range(1,32):
                dString = str(year)+'/'+str(month)+'/'+str(day)
                DateList.append(dString)
    DateList2 = []
    for d in DateList:
        Non  = False
        print('start filt'+d)
        for station in stations:
            
            sData = stationFilter(DB,station)
            for row in sData:
                if row[1] == d:
                    Non = True
        if Non:
            DateList2.append(d)
        else :
            if d in  DateList2 :
                DateList2.remove(d)
        
    
            
            
    return DateList

# %%
print('start at ' + str(datetime.datetime.now()))
stations = getStation()
DB = emptyDateFilter(loadDB(),stations)

distances = []
for station in stations:
    DTWD(station)
        
        
print('finish at ' + str(datetime.datetime.now()))
# Out:
# start at 2019-05-05 23:14:39.873610
# start filt2013/0/1
# start filt2013/0/2
# start filt2013/0/3
# start filt2013/0/4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-67-d9b1abcc15d4> in <module>
#       1 print('start at ' + str(datetime.datetime.now()))
#       2 stations = getStation()
# ----> 3 DB = emptyDateFilter(loadDB(),stations)
#       4
#       5 distances = []
#
# <ipython-input-66-4fb1db34bbbc> in emptyDateFilter(DB, stations)
#      33         for station in stations:
#      34
# ---> 35             sData = stationFilter(DB,station)
#      36             for row in sData:
#      37                 if row[1] == d:
#
# <ipython-input-66-4fb1db34bbbc> in stationFilter(DB, station)
#      12     DB2 = []
#      13     for row in DB:
# ---> 14         if row[1] == station:
#      15             DB2.append(row)
#      16     return DB2
#
# KeyboardInterrupt:

# %%
k = emptyDateFilter(loadDB(),getStation()) # start from 11pm
# Out:
# start filt2013/0/1
# start filt2013/0/2
# start filt2013/0/3
# start filt2013/0/4
# start filt2013/0/5
# start filt2013/0/6
# start filt2013/0/7
# start filt2013/0/8
# start filt2013/0/9
# start filt2013/0/10
# start filt2013/0/11
# start filt2013/0/12
# start filt2013/0/13
# start filt2013/0/14
# start filt2013/0/15
# start filt2013/0/16
# start filt2013/0/17
# start filt2013/0/18
# start filt2013/0/19
# start filt2013/0/20
# start filt2013/0/21
# start filt2013/0/22
# start filt2013/0/23
# start filt2013/0/24
# start filt2013/0/25
# start filt2013/0/26
# start filt2013/0/27
# start filt2013/0/28
# start filt2013/0/29
# start filt2013/0/30
# start filt2013/0/31
# start filt2013/1/1
# start filt2013/1/2
# start filt2013/1/3
# start filt2013/1/4
# start filt2013/1/5
# start filt2013/1/6
# start filt2013/1/7
# start filt2013/1/8
# start filt2013/1/9
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-69-fe34bc00a327> in <module>
# ----> 1 k = emptyDateFilter(loadDB(),getStation()) # start from 11pm
#
# <ipython-input-66-4fb1db34bbbc> in emptyDateFilter(DB, stations)
#      33         for station in stations:
#      34
# ---> 35             sData = stationFilter(DB,station)
#      36             for row in sData:
#      37                 if row[1] == d:
#
# <ipython-input-66-4fb1db34bbbc> in stationFilter(DB, station)
#      12     DB2 = []
#      13     for row in DB:
# ---> 14         if row[1] == station:
#      15             DB2.append(row)
#      16     return DB2
#
# KeyboardInterrupt:

# %%
loadDB()
# Out:
# (('2013/01/01',
#   '二林',
#   'PM2.5',
#   '37',
#   '40',
#   '42',
#   '40',
#   '36',
#   '39',
#   '40',
#   '43',
#   '39',
#   '44',
#   '46',
#   '50',
#   '46',
#   '38',
#   '45',
#   '43',
#   '59',
#   '58',
#   '54',
#   '44',
#   '40',
#   '46',
#   '47',
#   '41'),
#  ('2013/01/02',
#   '二林',
#   'PM2.5',
#   '43',
#   '45',
#   '46',
#   '42',
#   '41',
#   '51',
#   '56',
#   '52',
#   '43',
#   '39',
#   '35',
#   '36',
#   '37',
#   '41',
#   '35',
#   '29',
#   '24',
#   '28',
#   '27',
#   '35',
#   '35',
#   '34',
#   '29',
#   '25'),
#  ('2013/01/03',
#   '二林',
#   'PM2.5',
#   '28',
#   '28',
#   '29',
#   '28',
#   '20',
#   '16',
#   '12',
#   '17',
#   '20',
#   '22',
#   '18',
#   '20',
#   '21',
#   '23',
#   '19',
#   '20',
#   '17',
#   '19',
#   '13',
#   '18',
#   '18',
#   '23',
#   '24',
#   '26'),
#  ('2013/01/05',
#   '二林',
#   'PM2.5',
#   '12',
#   '17',
#   '20',
#   '19',
#   '20',
#   '21',
#   '19',
#   '11',
#   '9',
#   '14',
#   '16',
#   '21',
#   '24',
#   '24',
#   '20',
#   '18',
#   '25',
#   '21',
#   '24',
#   '28',
#   '36',
#   '32',
#   '28',
#   '25'),
#  ('2013/01/06',
#   '二林',
#   'PM2.5',
#   '26',
#   '22',
#   '22',
#   '17',
#   '18',
#   '15',
#   '20',
#   '23',
#   '25',
#   '34',
#   '40',
#   '31',
#   '27',
#   '17',
#   '24',
#   '21',
#   '29',
#   '29',
#   '29',
#   '27',
#   '26',
#   '16',
#   '16',
#   '17'),
#  ('2013/01/08',
#   '二林',
#   'PM2.5',
#   '32',
#   '28',
#   '20',
#   '17',
#   '20',
#   '22',
#   '22',
#   '20',
#   '20',
#   '24',
#   '33',
#   '31',
#   '30',
#   '21',
#   '25',
#   '26',
#   '27',
#   '27',
#   '25',
#   '26',
#   '29',
#   '27',
#   '24',
#   '22'),
#  ('2013/01/09',
#   '二林',
#   'PM2.5',
#   '23',
#   '22',
#   '15',
#   '12',
#   '20',
#   '26',
#   '24',
#   '21',
#   '21',
#   '21',
#   '22',
#   '21',
#   '31',
#   '26',
#   '22',
#   '19',
#   '23',
#   '28',
#   '30',
#   '34',
#   '33',
#   '30',
#   '28',
#   '27'),
#  ('2013/01/10',
#   '二林',
#   'PM2.5',
#   '27',
#   '26',
#   '21',
#   '20',
#   '15',
#   '18',
#   '17',
#   '20',
#   '20',
#   '19',
#   '20',
#   '22',
#   '24',
#   '24',
#   '36',
#   '48',
#   '51',
#   '43',
#   '30',
#   '28',
#   '30',
#   '36',
#   '33',
#   '27'),
#  ('2013/01/11',
#   '二林',
#   'PM2.5',
#   '21',
#   '21',
#   '20',
#   '23',
#   '20',
#   '22',
#   '18',
#   '17',
#   '14',
#   '12',
#   '13',
#   '16',
#   '19',
#   '20',
#   '22',
#   '25',
#   '29',
#   '36',
#   '37',
#   '40',
#   '38',
#   '40',
#   '40',
#   '39'),
#  ('2013/01/12',
#   '二林',
#   'PM2.5',
#   '38',
#   '38',
#   '36',
#   '32',
#   '25',
#   '19',
#   '13',
#   '16',
#   '23',
#   '23',
#   '22',
#   '20',
#   '24',
#   '27',
#   '28',
#   '30',
#   '25',
#   '21',
#   '23',
#   '22',
#   '17',
#   '19',
#   '16',
#   '30'),
#  ('2013/01/13',
#   '二林',
#   'PM2.5',
#   '27',
#   '32',
#   '31',
#   '27',
#   '33',
#   '31',
#   '31',
#   '26',
#   '15',
#   '15',
#   '16',
#   '20',
#   '18',
#   '18',
#   '16',
#   '24',
#   '22',
#   '27',
#   '23',
#   '20',
#   '17',
#   '12',
#   '14',
#   '18'),
#  ('2013/01/16',
#   '二林',
#   'PM2.5',
#   '57',
#   '50',
#   '40',
#   '35',
#   '32',
#   '31',
#   '31',
#   '42',
#   '49',
#   '64',
#   '68',
#   '76',
#   '43',
#   '38',
#   '58',
#   '58',
#   '53',
#   '50',
#   '43',
#   '40',
#   '50',
#   '58',
#   '69',
#   '62'),
#  ('2013/01/17',
#   '二林',
#   'PM2.5',
#   '60',
#   '58',
#   '64',
#   '70',
#   '74',
#   '68',
#   '67',
#   '74',
#   '78',
#   '78',
#   '73',
#   '76',
#   '80',
#   '77',
#   '70',
#   '63',
#   '58',
#   '58',
#   '54',
#   '48',
#   '40',
#   '31',
#   '37',
#   '39'),
#  ('2013/01/18',
#   '二林',
#   'PM2.5',
#   '41',
#   '42',
#   '45',
#   '49',
#   '43',
#   '42',
#   '39',
#   '44',
#   '34',
#   '30',
#   '28',
#   '29',
#   '36',
#   '34',
#   '37',
#   '32',
#   '28',
#   '30',
#   '30',
#   '30',
#   '30',
#   '36',
#   '39',
#   '38'),
#  ('2013/01/19',
#   '二林',
#   'PM2.5',
#   '31',
#   '33',
#   '30',
#   '35',
#   '41',
#   '44',
#   '42',
#   '39',
#   '46',
#   '53',
#   '58',
#   '57',
#   '49',
#   '38',
#   '35',
#   '35',
#   '39',
#   '51',
#   '53',
#   '53',
#   '42',
#   '42',
#   '42',
#   '38'),
#  ('2013/01/20',
#   '二林',
#   'PM2.5',
#   '39',
#   '30',
#   '33',
#   '29',
#   '43',
#   '45',
#   '53',
#   '56',
#   '60',
#   '63',
#   '50',
#   '52',
#   '47',
#   '52',
#   '45',
#   '49',
#   '45',
#   '44',
#   '45',
#   '46',
#   '56',
#   '49',
#   '58',
#   '58'),
#  ('2013/01/22',
#   '二林',
#   'PM2.5',
#   '68',
#   '65',
#   '61',
#   '53',
#   '52',
#   '52',
#   '61',
#   '67',
#   '85',
#   '81',
#   '79',
#   '79',
#   '97',
#   '105',
#   '99',
#   '82',
#   '68',
#   '59',
#   '50',
#   '48',
#   '44',
#   '44',
#   '39',
#   '41'),
#  ('2013/01/23',
#   '二林',
#   'PM2.5',
#   '42',
#   '41',
#   '40',
#   '45',
#   '50',
#   '53',
#   '46',
#   '45',
#   '42',
#   '46',
#   '49',
#   '49',
#   '50',
#   '44',
#   '46',
#   '52',
#   '55',
#   '57',
#   '52',
#   '58',
#   '53',
#   '52',
#   '50',
#   '56'),
#  ('2013/01/24',
#   '二林',
#   'PM2.5',
#   '61',
#   '67',
#   '67',
#   '64',
#   '63',
#   '67',
#   '73',
#   '78',
#   '81',
#   '83',
#   '78',
#   '73',
#   '70',
#   '72',
#   '76',
#   '83',
#   '87',
#   '91',
#   '87',
#   '88',
#   '91',
#   '88',
#   '84',
#   '84'),
#  ('2013/01/25',
#   '二林',
#   'PM2.5',
#   '89',
#   '87',
#   '81',
#   '79',
#   '79',
#   '81',
#   '76',
#   '78',
#   '78',
#   '88',
#   '93',
#   '91',
#   '90',
#   '92',
#   '94',
#   '91',
#   '80',
#   '69',
#   '63',
#   '61',
#   '61',
#   '56',
#   '51',
#   '49'),
#  ('2013/01/26',
#   '二林',
#   'PM2.5',
#   '45',
#   '43',
#   '47',
#   '47',
#   '52',
#   '50',
#   '55',
#   '63',
#   '71',
#   '77',
#   '77',
#   '70',
#   '67',
#   '62',
#   '64',
#   '57',
#   '52',
#   '42',
#   '36',
#   '30',
#   '27',
#   '29',
#   '29',
#   '28'),
#  ('2013/01/27',
#   '二林',
#   'PM2.5',
#   '25',
#   '23',
#   '25',
#   '26',
#   '27',
#   '27',
#   '25',
#   '24',
#   '29',
#   '32',
#   '30',
#   '34',
#   '38',
#   '53',
#   '57',
#   '62',
#   '55',
#   '54',
#   '50',
#   '51',
#   '41',
#   '36',
#   '35',
#   '39'),
#  ('2013/01/30',
#   '二林',
#   'PM2.5',
#   '51',
#   '49',
#   '51',
#   '46',
#   '42',
#   '39',
#   '38',
#   '39',
#   '39',
#   '47',
#   '51',
#   '54',
#   '49',
#   '45',
#   '45',
#   '42',
#   '44',
#   '39',
#   '39',
#   '36',
#   '41',
#   '49',
#   '52',
#   '53'),
#  ('2013/01/31',
#   '二林',
#   'PM2.5',
#   '53',
#   '63',
#   '63',
#   '53',
#   '49',
#   '55',
#   '59',
#   '56',
#   '50',
#   '51',
#   '49',
#   '49',
#   '56',
#   '51',
#   '44',
#   '36',
#   '66',
#   '79',
#   '85',
#   '74',
#   '73',
#   '80',
#   '82',
#   '81'),
#  ('2013/02/01',
#   '二林',
#   'PM2.5',
#   '80',
#   '75',
#   '75',
#   '70',
#   '67',
#   '62',
#   '50',
#   '40',
#   '49',
#   '54',
#   '55',
#   '44',
#   '43',
#   '42',
#   '40',
#   '41',
#   '38',
#   '40',
#   '40',
#   '45',
#   '49',
#   '54',
#   '65',
#   '71'),
#  ('2013/02/02',
#   '二林',
#   'PM2.5',
#   '79',
#   '83',
#   '82',
#   '77',
#   '76',
#   '74',
#   '75',
#   '67',
#   '61',
#   '55',
#   '53',
#   '58',
#   '62',
#   '62',
#   '60',
#   '58',
#   '55',
#   '51',
#   '46',
#   '48',
#   '49',
#   '48',
#   '37',
#   '28'),
#  ('2013/02/03',
#   '二林',
#   'PM2.5',
#   '26',
#   '29',
#   '22',
#   '21',
#   '20',
#   '27',
#   '29',
#   '35',
#   '39',
#   '39',
#   '31',
#   '28',
#   '33',
#   '45',
#   '54',
#   '52',
#   '41',
#   '29',
#   '27',
#   '31',
#   '40',
#   '46',
#   '42',
#   '33'),
#  ('2013/02/05',
#   '二林',
#   'PM2.5',
#   '61',
#   '49',
#   '43',
#   '46',
#   '54',
#   '62',
#   '61',
#   '61',
#   '56',
#   '53',
#   '48',
#   '45',
#   '44',
#   '35',
#   '34',
#   '25',
#   '22',
#   '14',
#   '13',
#   '26',
#   '26',
#   '31',
#   '23',
#   '28'),
#  ('2013/02/06',
#   '二林',
#   'PM2.5',
#   '23',
#   '26',
#   '24',
#   '31',
#   '32',
#   '29',
#   '24',
#   '20',
#   '21',
#   '23',
#   '24',
#   '30',
#   '38',
#   '43',
#   '45',
#   '46',
#   '52',
#   '50',
#   '42',
#   '37',
#   '35',
#   '37',
#   '37',
#   '32'),
#  ('2013/02/07',
#   '二林',
#   'PM2.5',
#   '30',
#   '29',
#   '33',
#   '36',
#   '32',
#   '29',
#   '28',
#   '30',
#   '36',
#   '42',
#   '45',
#   '49',
#   '47',
#   '45',
#   '42',
#   '46',
#   '47',
#   '40',
#   '31',
#   '21',
#   '17',
#   '22',
#   '22',
#   '22'),
#  ('2013/02/08',
#   '二林',
#   'PM2.5',
#   '13',
#   '13',
#   '10',
#   '12',
#   '11',
#   '10',
#   '9',
#   '8',
#   '11',
#   '11',
#   '15',
#   '15',
#   '21',
#   '18',
#   '22',
#   '21',
#   '24',
#   '23',
#   '18',
#   '16',
#   '10',
#   '12',
#   '10',
#   '13'),
#  ('2013/02/09',
#   '二林',
#   'PM2.5',
#   '8',
#   '10',
#   '14',
#   '19',
#   '19',
#   '21',
#   '20',
#   '20',
#   '14',
#   '15',
#   '16',
#   '18',
#   '15',
#   '13',
#   '13',
#   '15',
#   '16',
#   '22',
#   '21',
#   '24',
#   '17',
#   '21',
#   '20',
#   '20'),
#  ('2013/02/10',
#   '二林',
#   'PM2.5',
#   '15',
#   '19',
#   '23',
#   '28',
#   '27',
#   '26',
#   '20',
#   '14',
#   '14',
#   '22',
#   '24',
#   '25',
#   '21',
#   '24',
#   '19',
#   '14',
#   '18',
#   '18',
#   '25',
#   '16',
#   '14',
#   '8',
#   '8',
#   '14'),
#  ('2013/02/12',
#   '二林',
#   'PM2.5',
#   '24',
#   '18',
#   '20',
#   '22',
#   '25',
#   '23',
#   '20',
#   '17',
#   '23',
#   '24',
#   '33',
#   '33',
#   '33',
#   '24',
#   '21',
#   '27',
#   '40',
#   '37',
#   '30',
#   '24',
#   '24',
#   '23',
#   '18',
#   '21'),
#  ('2013/02/13',
#   '二林',
#   'PM2.5',
#   '16',
#   '14',
#   '10',
#   '16',
#   '21',
#   '19',
#   '15',
#   '15',
#   '19',
#   '15',
#   '17',
#   '22',
#   '31',
#   '29',
#   '32',
#   '36',
#   '45',
#   '44',
#   '44',
#   '38',
#   '40',
#   '36',
#   '46',
#   '51'),
#  ('2013/02/14',
#   '二林',
#   'PM2.5',
#   '61',
#   '60',
#   '60',
#   '64',
#   '62',
#   '62',
#   '56',
#   '56',
#   '56',
#   '60',
#   '64',
#   '65',
#   '62',
#   '62',
#   '67',
#   '73',
#   '79',
#   '83',
#   '87',
#   '83',
#   '77',
#   '75',
#   '75',
#   '74'),
#  ('2013/02/15',
#   '二林',
#   'PM2.5',
#   '73',
#   '82',
#   '92',
#   '90',
#   '83',
#   '72',
#   '69',
#   '66',
#   '84',
#   '91',
#   '88',
#   '64',
#   '52',
#   '42',
#   '37',
#   '33',
#   '30',
#   '30',
#   '23',
#   '23',
#   '21',
#   '23',
#   '24',
#   '20'),
#  ('2013/02/16',
#   '二林',
#   'PM2.5',
#   '20',
#   '17',
#   '20',
#   '20',
#   '20',
#   '18',
#   '16',
#   '16',
#   '19',
#   '19',
#   '21',
#   '23',
#   '31',
#   '35',
#   '40',
#   '44',
#   '49',
#   '48',
#   '37',
#   '35',
#   '34',
#   '39',
#   '32',
#   '27'),
#  ('2013/02/17',
#   '二林',
#   'PM2.5',
#   '25',
#   '24',
#   '27',
#   '30',
#   '38',
#   '34',
#   '30',
#   '26',
#   '29',
#   '34',
#   '37',
#   '47',
#   '54',
#   '51',
#   '46',
#   '45',
#   '49',
#   '47',
#   '44',
#   '39',
#   '40',
#   '37',
#   '41',
#   '39'),
#  ('2013/02/19',
#   '二林',
#   'PM2.5',
#   '58',
#   '69',
#   '54',
#   '46',
#   '36',
#   '42',
#   '39',
#   '35',
#   '26',
#   '19',
#   '14',
#   '18',
#   '25',
#   '32',
#   '23',
#   '22',
#   '23',
#   '22',
#   '24',
#   '17',
#   '19',
#   '12',
#   '20',
#   '14'),
#  ('2013/02/20',
#   '二林',
#   'PM2.5',
#   '15',
#   '12',
#   '12',
#   '11',
#   '5',
#   '14',
#   '16',
#   '19',
#   '16',
#   '15',
#   '23',
#   '22',
#   '24',
#   '26',
#   '30',
#   '38',
#   '28',
#   '28',
#   '21',
#   '28',
#   '28',
#   '24',
#   '19',
#   '27'),
#  ('2013/02/22',
#   '二林',
#   'PM2.5',
#   '17',
#   '12',
#   '13',
#   '19',
#   '22',
#   '30',
#   '26',
#   '27',
#   '18',
#   '22',
#   '22',
#   '25',
#   '23',
#   '27',
#   '23',
#   '19',
#   '15',
#   '22',
#   '23',
#   '24',
#   '17',
#   '19',
#   '18',
#   '19'),
#  ('2013/02/23',
#   '二林',
#   'PM2.5',
#   '18',
#   '20',
#   '20',
#   '20',
#   '22',
#   '28',
#   '33',
#   '33',
#   '33',
#   '34',
#   '40',
#   '33',
#   '35',
#   '29',
#   '42',
#   '37',
#   '45',
#   '39',
#   '48',
#   '45',
#   '48',
#   '48',
#   '48',
#   '45'),
#  ('2013/02/24',
#   '二林',
#   'PM2.5',
#   '42',
#   '41',
#   '48',
#   '55',
#   '59',
#   '60',
#   '58',
#   '54',
#   '70',
#   '89',
#   '101',
#   '85',
#   '75',
#   '73',
#   '75',
#   '72',
#   '78',
#   '84',
#   '92',
#   '93',
#   '87',
#   '79',
#   '74',
#   '81'),
#  ('2013/02/26',
#   '二林',
#   'PM2.5',
#   '58',
#   '44',
#   '40',
#   '32',
#   '34',
#   '40',
#   '41',
#   '41',
#   '32',
#   '52',
#   '60',
#   '74',
#   '79',
#   '101',
#   '109',
#   '96',
#   '71',
#   '74',
#   '81',
#   '98',
#   '99',
#   '116',
#   '117',
#   '108'),
#  ('2013/02/27',
#   '二林',
#   'PM2.5',
#   '96',
#   '82',
#   '79',
#   '63',
#   '61',
#   '61',
#   '64',
#   '63',
#   '68',
#   '61',
#   '65',
#   '51',
#   '56',
#   '44',
#   '37',
#   '30',
#   '26',
#   '30',
#   '32',
#   '39',
#   '44',
#   '45',
#   '46',
#   '43'),
#  ('2013/03/01',
#   '二林',
#   'PM2.5',
#   '42',
#   '45',
#   '38',
#   '39',
#   '37',
#   '44',
#   '50',
#   '60',
#   '70',
#   '63',
#   '63',
#   '61',
#   '59',
#   '42',
#   '37',
#   '38',
#   '28',
#   '37',
#   '65',
#   '76',
#   '83',
#   '70',
#   '55',
#   '31'),
#  ('2013/03/02',
#   '二林',
#   'PM2.5',
#   '31',
#   '19',
#   '19',
#   '12',
#   '14',
#   '14',
#   '12',
#   '16',
#   '19',
#   '20',
#   '20',
#   '19',
#   '20',
#   '22',
#   '23',
#   '23',
#   '19',
#   '18',
#   '20',
#   '22',
#   '23',
#   '23',
#   '18',
#   '23'),
#  ('2013/03/03',
#   '二林',
#   'PM2.5',
#   '19',
#   '31',
#   '29',
#   '33',
#   '27',
#   '22',
#   '25',
#   '19',
#   '26',
#   '20',
#   '24',
#   '18',
#   '19',
#   '20',
#   '23',
#   '25',
#   '26',
#   '34',
#   '30',
#   '32',
#   '27',
#   '33',
#   '36',
#   '35'),
#  ('2013/03/05',
#   '二林',
#   'PM2.5',
#   '38',
#   '39',
#   '42',
#   '36',
#   '44',
#   '41',
#   '48',
#   '49',
#   '63',
#   '79',
#   '84',
#   '75',
#   '65',
#   '67',
#   '75',
#   '76',
#   '71',
#   '61',
#   '84',
#   '85',
#   '95',
#   '66',
#   '69',
#   '63'),
#  ('2013/03/06',
#   '二林',
#   'PM2.5',
#   '67',
#   '68',
#   '72',
#   '72',
#   '67',
#   '65',
#   '66',
#   '75',
#   '74',
#   '68',
#   '58',
#   '57',
#   '67',
#   '67',
#   '69',
#   '68',
#   '70',
#   '72',
#   '70',
#   '82',
#   '108',
#   '119',
#   '124',
#   '111'),
#  ('2013/03/08',
#   '二林',
#   'PM2.5',
#   '86',
#   '81',
#   '79',
#   '77',
#   '80',
#   '92',
#   '101',
#   '114',
#   '99',
#   '81',
#   '64',
#   '61',
#   '59',
#   '63',
#   '54',
#   '63',
#   '63',
#   '66',
#   '59',
#   '66',
#   '79',
#   '89',
#   '91',
#   '91'),
#  ('2013/03/09',
#   '二林',
#   'PM2.5',
#   '87',
#   '82',
#   '78',
#   '82',
#   '84',
#   '82',
#   '75',
#   '69',
#   '66',
#   '66',
#   '63',
#   '55',
#   '47',
#   '43',
#   '41',
#   '44',
#   '44',
#   '48',
#   '48',
#   '56',
#   '53',
#   '59',
#   '60',
#   '74'),
#  ('2013/03/10',
#   '二林',
#   'PM2.5',
#   '77',
#   '74',
#   '74',
#   '81',
#   '79',
#   '70',
#   '72',
#   '72',
#   '68',
#   '51',
#   '40',
#   '39',
#   '29',
#   '31',
#   '30',
#   '39',
#   '46',
#   '41',
#   '35',
#   '32',
#   '40',
#   '42',
#   '41',
#   '40'),
#  ('2013/03/12',
#   '二林',
#   'PM2.5',
#   '41',
#   '42',
#   '42',
#   '41',
#   '44',
#   '39',
#   '48',
#   '51',
#   '61',
#   '60',
#   '59',
#   '48',
#   '49',
#   '46',
#   '50',
#   '50',
#   '57',
#   '55',
#   '52',
#   '42',
#   '44',
#   '44',
#   '48',
#   '53'),
#  ('2013/03/13',
#   '二林',
#   'PM2.5',
#   '58',
#   '61',
#   '61',
#   '63',
#   '60',
#   '62',
#   '64',
#   '66',
#   '63',
#   '54',
#   '55',
#   '50',
#   '46',
#   '36',
#   '33',
#   '29',
#   '29',
#   '27',
#   '28',
#   '34',
#   '46',
#   '52',
#   '51',
#   '47'),
#  ('2013/03/14',
#   '二林',
#   'PM2.5',
#   '42',
#   '36',
#   '27',
#   '25',
#   '24',
#   '28',
#   '28',
#   '31',
#   '31',
#   '32',
#   '35',
#   '36',
#   '38',
#   '37',
#   '37',
#   '36',
#   '37',
#   '30',
#   '34',
#   '30',
#   '34',
#   '31',
#   '33',
#   '32'),
#  ('2013/03/15',
#   '二林',
#   'PM2.5',
#   '28',
#   '28',
#   '28',
#   '31',
#   '27',
#   '24',
#   '27',
#   '31',
#   '34',
#   '34',
#   '34',
#   '31',
#   '33',
#   '34',
#   '45',
#   '50',
#   '47',
#   '47',
#   '39',
#   '38',
#   '36',
#   '38',
#   '41',
#   '36'),
#  ('2013/03/16',
#   '二林',
#   'PM2.5',
#   '37',
#   '39',
#   '43',
#   '44',
#   '44',
#   '40',
#   '36',
#   '44',
#   '44',
#   '56',
#   '54',
#   '54',
#   '48',
#   '47',
#   '60',
#   '83',
#   '87',
#   '74',
#   '52',
#   '49',
#   '54',
#   '51',
#   '46',
#   '48'),
#  ('2013/03/17',
#   '二林',
#   'PM2.5',
#   '52',
#   '57',
#   '52',
#   '47',
#   '47',
#   '48',
#   '54',
#   '64',
#   '80',
#   '84',
#   '71',
#   '57',
#   '51',
#   '49',
#   '50',
#   '49',
#   '52',
#   '47',
#   '41',
#   '42',
#   '48',
#   '54',
#   '52',
#   '53'),
#  ('2013/03/19',
#   '二林',
#   'PM2.5',
#   '41',
#   '29',
#   '27',
#   '29',
#   '33',
#   '40',
#   '35',
#   '35',
#   '37',
#   '39',
#   '43',
#   '41',
#   '38',
#   '43',
#   '39',
#   '18',
#   '18',
#   '31',
#   '35',
#   '37',
#   '37',
#   '33',
#   '29',
#   '20'),
#  ('2013/03/20',
#   '二林',
#   'PM2.5',
#   '23',
#   '27',
#   '28',
#   '28',
#   '18',
#   '23',
#   '17',
#   '25',
#   '29',
#   '32',
#   '37',
#   '35',
#   '30',
#   '21',
#   '15',
#   '22',
#   '26',
#   '30',
#   '29',
#   '37',
#   '43',
#   '40',
#   '31',
#   '32'),
#  ('2013/03/21',
#   '二林',
#   'PM2.5',
#   '49',
#   '65',
#   '67',
#   '56',
#   '39',
#   '31',
#   '29',
#   '27',
#   '30',
#   '29',
#   '33',
#   '37',
#   '36',
#   '41',
#   '43',
#   '44',
#   '41',
#   '28',
#   '33',
#   '33',
#   '44',
#   '51',
#   '56',
#   '53'),
#  ('2013/03/22',
#   '二林',
#   'PM2.5',
#   '45',
#   '38',
#   '43',
#   '44',
#   '46',
#   '45',
#   '52',
#   '66',
#   '68',
#   '73',
#   '73',
#   '82',
#   '65',
#   '53',
#   '38',
#   '42',
#   '41',
#   '42',
#   '38',
#   '38',
#   '34',
#   '46',
#   '49',
#   '50'),
#  ('2013/03/23',
#   '二林',
#   'PM2.5',
#   '50',
#   '53',
#   '54',
#   '49',
#   '53',
#   '64',
#   '63',
#   '69',
#   '67',
#   '61',
#   '44',
#   '35',
#   '39',
#   '45',
#   '58',
#   '61',
#   '64',
#   '53',
#   '55',
#   '58',
#   '60',
#   '62',
#   '64',
#   '66'),
#  ('2013/03/24',
#   '二林',
#   'PM2.5',
#   '67',
#   '69',
#   '68',
#   '71',
#   '66',
#   '68',
#   '75',
#   '86',
#   '78',
#   '62',
#   '42',
#   '42',
#   '51',
#   '51',
#   '47',
#   '46',
#   '51',
#   '64',
#   '58',
#   '54',
#   '44',
#   '40',
#   '40',
#   '42'),
#  ('2013/03/26',
#   '二林',
#   'PM2.5',
#   '56',
#   '56',
#   '56',
#   '57',
#   '53',
#   '58',
#   '58',
#   '58',
#   '58',
#   '53',
#   '42',
#   '34',
#   '33',
#   '30',
#   '34',
#   '31',
#   '34',
#   '34',
#   '29',
#   '26',
#   '24',
#   '23',
#   '18',
#   '14'),
#  ('2013/03/27',
#   '二林',
#   'PM2.5',
#   '21',
#   '24',
#   '21',
#   '9',
#   '9',
#   '11',
#   '15',
#   '14',
#   '17',
#   '18',
#   '28',
#   '25',
#   '30',
#   '23',
#   '26',
#   '23',
#   '32',
#   '31',
#   '43',
#   '48',
#   '53',
#   '57',
#   '58',
#   '56'),
#  ('2013/03/28',
#   '二林',
#   'PM2.5',
#   '43',
#   '32',
#   '32',
#   '36',
#   '42',
#   '34',
#   '35',
#   '35',
#   '37',
#   '30',
#   '26',
#   '33',
#   '38',
#   '42',
#   '33',
#   '30',
#   '30',
#   '37',
#   '37',
#   '28',
#   '19',
#   '24',
#   '26',
#   '24'),
#  ('2013/03/30',
#   '二林',
#   'PM2.5',
#   '24',
#   '27',
#   '21',
#   '24',
#   '26',
#   '35',
#   '35',
#   '39',
#   '41',
#   '39',
#   '43',
#   '38',
#   '41',
#   '34',
#   '43',
#   '44',
#   '44',
#   '41',
#   '40',
#   '42',
#   '47',
#   '53',
#   '52',
#   '45'),
#  ('2013/04/02',
#   '二林',
#   'PM2.5',
#   '39',
#   '41',
#   '46',
#   '40',
#   '38',
#   '38',
#   '39',
#   '59',
#   '73',
#   '74',
#   '52',
#   '37',
#   '36',
#   '39',
#   '43',
#   '45',
#   '53',
#   '54',
#   '60',
#   '64',
#   '79',
#   '95',
#   '99',
#   '91'),
#  ('2013/04/03',
#   '二林',
#   'PM2.5',
#   '78',
#   '77',
#   '85',
#   '82',
#   '82',
#   '68',
#   '70',
#   '56',
#   '54',
#   '41',
#   '47',
#   '45',
#   '54',
#   '48',
#   '47',
#   '47',
#   '50',
#   '49',
#   '41',
#   '40',
#   '40',
#   '37',
#   '32',
#   '32'),
#  ('2013/04/04',
#   '二林',
#   'PM2.5',
#   '29',
#   '29',
#   '26',
#   '29',
#   '34',
#   '36',
#   '39',
#   '38',
#   '43',
#   '41',
#   '40',
#   '39',
#   '46',
#   '43',
#   '40',
#   '33',
#   '42',
#   '42',
#   '54',
#   '50',
#   '49',
#   '34',
#   '28',
#   '22'),
#  ('2013/04/05',
#   '二林',
#   'PM2.5',
#   '25',
#   '26',
#   '22',
#   '22',
#   '26',
#   '32',
#   '24',
#   '16',
#   '11',
#   '14',
#   '15',
#   '15',
#   '16',
#   '16',
#   '8',
#   '14',
#   '19',
#   '29',
#   '24',
#   '21',
#   '21',
#   '21',
#   '21',
#   '11'),
#  ('2013/04/06',
#   '二林',
#   'PM2.5',
#   '13',
#   '8',
#   '9',
#   '8',
#   '9',
#   '12',
#   '10',
#   '14',
#   '18',
#   '25',
#   '24',
#   '23',
#   '23',
#   '20',
#   '24',
#   '27',
#   '23',
#   '16',
#   '18',
#   '21',
#   '24',
#   '22',
#   '22',
#   '21'),
#  ('2013/04/07',
#   '二林',
#   'PM2.5',
#   '25',
#   '28',
#   '33',
#   '33',
#   '30',
#   '28',
#   '29',
#   '33',
#   '34',
#   '39',
#   '39',
#   '43',
#   '45',
#   '53',
#   '55',
#   '61',
#   '55',
#   '57',
#   '54',
#   '56',
#   '55',
#   '58',
#   '59',
#   '75'),
#  ('2013/04/08',
#   '二林',
#   'PM2.5',
#   '72',
#   '69',
#   '56',
#   '55',
#   '66',
#   '65',
#   '73',
#   '73',
#   '74',
#   '78',
#   '74',
#   '71',
#   '61',
#   '54',
#   '48',
#   '41',
#   '37',
#   '42',
#   '47',
#   '55',
#   '55',
#   '59',
#   '57',
#   '60'),
#  ('2013/04/12',
#   '二林',
#   'PM2.5',
#   '42',
#   '36',
#   '29',
#   '26',
#   '24',
#   '26',
#   '21',
#   '22',
#   '18',
#   '18',
#   '22',
#   '26',
#   '27',
#   '26',
#   '27',
#   '28',
#   '33',
#   '38',
#   '41',
#   '39',
#   '37',
#   '45',
#   '52',
#   '58'),
#  ('2013/04/13',
#   '二林',
#   'PM2.5',
#   '53',
#   '49',
#   '49',
#   '54',
#   '56',
#   '52',
#   '48',
#   '52',
#   '53',
#   '51',
#   '35',
#   '26',
#   '25',
#   '28',
#   '28',
#   '28',
#   '34',
#   '42',
#   '46',
#   '50',
#   '50',
#   '55',
#   '53',
#   '55'),
#  ('2013/04/14',
#   '二林',
#   'PM2.5',
#   '55',
#   '53',
#   '52',
#   '47',
#   '48',
#   '44',
#   '47',
#   '46',
#   '50',
#   '45',
#   '34',
#   '26',
#   '19',
#   '20',
#   '18',
#   '18',
#   '17',
#   '16',
#   '20',
#   '15',
#   '18',
#   '17',
#   '21',
#   '24'),
#  ('2013/04/16',
#   '二林',
#   'PM2.5',
#   '54',
#   '57',
#   '59',
#   '55',
#   '52',
#   '48',
#   '53',
#   '67',
#   '65',
#   '57',
#   '48',
#   '48',
#   '49',
#   '51',
#   '48',
#   '52',
#   '52',
#   '57',
#   '52',
#   '48',
#   '49',
#   '54',
#   '52',
#   '55'),
#  ('2013/04/17',
#   '二林',
#   'PM2.5',
#   '55',
#   '61',
#   '57',
#   '60',
#   '51',
#   '51',
#   '44',
#   '45',
#   '39',
#   '40',
#   '42',
#   '39',
#   '38',
#   '40',
#   '42',
#   '42',
#   '44',
#   '46',
#   '49',
#   '44',
#   '50',
#   '44',
#   '47',
#   '41'),
#  ('2013/04/18',
#   '二林',
#   'PM2.5',
#   '46',
#   '37',
#   '43',
#   '38',
#   '43',
#   '38',
#   '42',
#   '44',
#   '43',
#   '45',
#   '44',
#   '41',
#   '42',
#   '36',
#   '37',
#   '30',
#   '33',
#   '27',
#   '30',
#   '28',
#   '31',
#   '30',
#   '34',
#   '37'),
#  ('2013/04/19',
#   '二林',
#   'PM2.5',
#   '32',
#   '28',
#   '29',
#   '37',
#   '37',
#   '36',
#   '32',
#   '31',
#   '35',
#   '30',
#   '33',
#   '26',
#   '43',
#   '50',
#   '64',
#   '53',
#   '52',
#   '45',
#   '53',
#   '49',
#   '47',
#   '49',
#   '50',
#   '50'),
#  ('2013/04/20',
#   '二林',
#   'PM2.5',
#   '49',
#   '51',
#   '58',
#   '53',
#   '59',
#   '56',
#   '61',
#   '61',
#   '67',
#   '81',
#   '93',
#   '96',
#   '77',
#   '65',
#   '62',
#   '61',
#   '55',
#   '48',
#   '43',
#   '30',
#   '20',
#   '24',
#   '26',
#   '34'),
#  ('2013/04/21',
#   '二林',
#   'PM2.5',
#   '27',
#   '25',
#   '22',
#   '20',
#   '14',
#   '9',
#   '11',
#   '17',
#   '12',
#   '8',
#   '10',
#   '15',
#   '19',
#   '22',
#   '22',
#   '24',
#   '23',
#   '23',
#   '27',
#   '35',
#   '39',
#   '42',
#   '48',
#   '49'),
#  ('2013/04/24',
#   '二林',
#   'PM2.5',
#   '49',
#   '52',
#   '54',
#   '47',
#   '46',
#   '48',
#   '61',
#   '71',
#   '69',
#   '56',
#   '42',
#   '41',
#   '38',
#   '33',
#   '24',
#   '23',
#   '24',
#   '28',
#   '26',
#   '27',
#   '18',
#   '27',
#   '35',
#   '55'),
#  ('2013/04/25',
#   '二林',
#   'PM2.5',
#   '57',
#   '54',
#   '52',
#   '59',
#   '57',
#   '52',
#   '38',
#   '42',
#   '47',
#   '52',
#   '49',
#   '38',
#   '25',
#   '20',
#   '18',
#   '15',
#   '15',
#   '18',
#   '28',
#   '22',
#   '13',
#   '19',
#   '27',
#   '36'),
#  ('2013/04/26',
#   '二林',
#   'PM2.5',
#   '24',
#   '26',
#   '26',
#   '26',
#   '19',
#   '21',
#   '22',
#   '35',
#   '46',
#   '58',
#   '57',
#   '49',
#   '49',
#   '39',
#   '37',
#   '30',
#   '45',
#   '45',
#   '46',
#   '43',
#   '47',
#   '54',
#   '54',
#   '54'),
#  ('2013/04/28',
#   '二林',
#   'PM2.5',
#   '41',
#   '48',
#   '45',
#   '49',
#   '45',
#   '46',
#   '39',
#   '39',
#   '33',
#   '37',
#   '50',
#   '59',
#   '66',
#   '58',
#   '52',
#   '43',
#   '35',
#   '39',
#   '48',
#   '55',
#   '54',
#   '54',
#   '59',
#   '57'),
#  ('2013/04/29',
#   '二林',
#   'PM2.5',
#   '56',
#   '43',
#   '46',
#   '40',
#   '45',
#   '41',
#   '38',
#   '48',
#   '44',
#   '50',
#   '44',
#   '48',
#   '45',
#   '35',
#   '31',
#   '23',
#   '27',
#   '34',
#   '42',
#   '44',
#   '39',
#   '40',
#   '41',
#   '39'),
#  ('2013/05/01',
#   '二林',
#   'PM2.5',
#   '12',
#   '10',
#   '13',
#   '10',
#   '13',
#   '15',
#   '14',
#   '16',
#   '14',
#   '20',
#   '19',
#   '20',
#   '26',
#   '26',
#   '33',
#   '29',
#   '25',
#   '20',
#   '24',
#   '28',
#   '29',
#   '21',
#   '19',
#   '21'),
#  ('2013/05/02',
#   '二林',
#   'PM2.5',
#   '23',
#   '25',
#   '21',
#   '21',
#   '24',
#   '22',
#   '29',
#   '29',
#   '41',
#   '41',
#   '47',
#   '48',
#   '42',
#   '35',
#   '31',
#   '38',
#   '40',
#   '43',
#   '34',
#   '30',
#   '27',
#   '31',
#   '34',
#   '37'),
#  ('2013/05/03',
#   '二林',
#   'PM2.5',
#   '42',
#   '44',
#   '47',
#   '52',
#   '59',
#   '60',
#   '56',
#   '51',
#   '43',
#   '42',
#   '42',
#   '41',
#   '33',
#   '29',
#   '27',
#   '30',
#   '29',
#   '33',
#   '26',
#   '32',
#   '23',
#   '30',
#   '31',
#   '41'),
#  ('2013/05/04',
#   '二林',
#   'PM2.5',
#   '47',
#   '46',
#   '50',
#   '50',
#   '55',
#   '56',
#   '51',
#   '44',
#   '33',
#   '33',
#   '32',
#   '35',
#   '33',
#   '27',
#   '22',
#   '18',
#   '25',
#   '27',
#   '27',
#   '25',
#   '23',
#   '26',
#   '24',
#   '26'),
#  ('2013/05/05',
#   '二林',
#   'PM2.5',
#   '27',
#   '20',
#   '17',
#   '14',
#   '22',
#   '24',
#   '24',
#   '26',
#   '26',
#   '31',
#   '29',
#   '34',
#   '32',
#   '30',
#   '23',
#   '26',
#   '27',
#   '29',
#   '27',
#   '27',
#   '30',
#   '27',
#   '19',
#   '17'),
#  ('2013/05/06',
#   '二林',
#   'PM2.5',
#   '12',
#   '20',
#   '22',
#   '24',
#   '25',
#   '19',
#   '27',
#   '23',
#   '32',
#   '35',
#   '40',
#   '50',
#   '49',
#   '54',
#   '49',
#   '47',
#   '42',
#   '38',
#   '40',
#   '44',
#   '45',
#   '43',
#   '43',
#   '47'),
#  ('2013/05/07',
#   '二林',
#   'PM2.5',
#   '48',
#   '50',
#   '51',
#   '45',
#   '38',
#   '38',
#   '43',
#   '52',
#   '53',
#   '60',
#   '62',
#   '59',
#   '56',
#   '53',
#   '50',
#   '46',
#   '46',
#   '50',
#   '55',
#   '51',
#   '48',
#   '40',
#   '36',
#   '35'),
#  ('2013/05/08',
#   '二林',
#   'PM2.5',
#   '36',
#   '42',
#   '42',
#   '49',
#   '52',
#   '49',
#   '58',
#   '65',
#   '79',
#   '74',
#   '68',
#   '61',
#   '58',
#   '47',
#   '44',
#   '36',
#   '45',
#   '45',
#   '50',
#   '50',
#   '62',
#   '68',
#   '61',
#   '46'),
#  ('2013/05/10',
#   '二林',
#   'PM2.5',
#   '45',
#   '45',
#   '49',
#   '49',
#   '59',
#   '78',
#   '92',
#   '101',
#   '93',
#   '85',
#   '57',
#   '37',
#   '20',
#   '16',
#   '20',
#   '20',
#   '29',
#   '22',
#   '24',
#   '19',
#   '19',
#   '16',
#   '14',
#   '14'),
#  ('2013/05/11',
#   '二林',
#   'PM2.5',
#   '10',
#   '14',
#   '15',
#   '14',
#   '14',
#   '15',
#   '21',
#   '21',
#   '25',
#   '25',
#   '21',
#   '12',
#   '7',
#   '15',
#   '21',
#   '19',
#   '14',
#   '18',
#   '46',
#   '53',
#   '51',
#   '35',
#   '38',
#   '46'),
#  ('2013/05/12',
#   '二林',
#   'PM2.5',
#   '48',
#   '45',
#   '49',
#   '47',
#   '47',
#   '41',
#   '43',
#   '49',
#   '47',
#   '54',
#   '44',
#   '45',
#   '54',
#   '56',
#   '48',
#   '21',
#   '14',
#   '16',
#   '16',
#   '18',
#   '24',
#   '25',
#   '25',
#   '18'),
#  ('2013/05/14',
#   '二林',
#   'PM2.5',
#   '18',
#   '16',
#   '10',
#   '10',
#   '10',
#   '17',
#   '23',
#   '29',
#   '27',
#   '37',
#   '45',
#   '57',
#   '50',
#   '45',
#   '37',
#   '34',
#   '26',
#   '24',
#   '24',
#   '20',
#   '30',
#   '32',
#   '39',
#   '33'),
#  ('2013/05/15',
#   '二林',
#   'PM2.5',
#   '34',
#   '34',
#   '33',
#   '31',
#   '22',
#   '20',
#   '18',
#   '29',
#   '30',
#   '33',
#   '27',
#   '26',
#   '23',
#   '21',
#   '22',
#   '17',
#   '17',
#   '15',
#   '18',
#   '20',
#   '25',
#   '22',
#   '24',
#   '20'),
#  ('2013/05/16',
#   '二林',
#   'PM2.5',
#   '30',
#   '29',
#   '25',
#   '18',
#   '15',
#   '17',
#   '14',
#   '10',
#   '13',
#   '11',
#   '17',
#   '9',
#   '10',
#   '15',
#   '15',
#   '17',
#   '15',
#   '21',
#   '19',
#   '19',
#   '15',
#   '13',
#   '9',
#   '11'),
#  ('2013/05/17',
#   '二林',
#   'PM2.5',
#   '12',
#   '15',
#   '15',
#   '14',
#   '10',
#   '12',
#   '11',
#   '15',
#   '18',
#   '17',
#   '17',
#   '17',
#   '19',
#   '19',
#   '12',
#   '16',
#   '19',
#   '17',
#   '15',
#   '16',
#   '17',
#   '20',
#   '11',
#   '18'),
#  ('2013/05/18',
#   '二林',
#   'PM2.5',
#   '15',
#   '23',
#   '19',
#   '22',
#   '20',
#   '20',
#   '18',
#   '15',
#   '17',
#   '12',
#   '14',
#   '17',
#   '19',
#   '26',
#   '22',
#   '24',
#   '15',
#   '11',
#   '10',
#   '16',
#   '17',
#   '20',
#   '14',
#   '17'),
#  ('2013/05/19',
#   '二林',
#   'PM2.5',
#   '11',
#   '13',
#   '12',
#   '20',
#   '18',
#   '18',
#   '15',
#   '18',
#   '17',
#   '11',
#   '13',
#   '14',
#   '15',
#   '11',
#   '11',
#   '12',
#   '15',
#   '14',
#   '13',
#   '11',
#   '15',
#   '14',
#   '12',
#   '9'),
#  ('2013/05/20',
#   '二林',
#   'PM2.5',
#   '15',
#   '17',
#   '16',
#   '13',
#   '12',
#   '10',
#   '12',
#   '18',
#   '19',
#   '19',
#   '15',
#   '14',
#   '19',
#   '18',
#   '19',
#   '14',
#   '12',
#   '14',
#   '14',
#   '16',
#   '12',
#   '14',
#   '19',
#   '21'),
#  ('2013/05/21',
#   '二林',
#   'PM2.5',
#   '15',
#   '7',
#   '8',
#   '8',
#   '5',
#   '5',
#   '8',
#   '9',
#   '7',
#   '8',
#   '14',
#   '12',
#   '14',
#   '8',
#   '16',
#   '12',
#   '16',
#   '15',
#   '21',
#   '19',
#   '18',
#   '20',
#   '24',
#   '22'),
#  ('2013/05/24',
#   '二林',
#   'PM2.5',
#   '18',
#   '17',
#   '26',
#   '27',
#   '25',
#   '20',
#   '20',
#   '22',
#   '32',
#   '37',
#   '47',
#   '42',
#   '35',
#   '32',
#   '37',
#   '33',
#   '32',
#   '30',
#   '31',
#   '25',
#   '20',
#   '22',
#   '24',
#   '25'),
#  ('2013/05/25',
#   '二林',
#   'PM2.5',
#   '23',
#   '24',
#   '21',
#   '23',
#   '20',
#   '24',
#   '22',
#   '32',
#   '38',
#   '55',
#   '58',
#   '60',
#   '46',
#   '42',
#   '39',
#   '39',
#   '38',
#   '35',
#   '37',
#   '32',
#   '33',
#   '28',
#   '31',
#   '28'),
#  ('2013/05/26',
#   '二林',
#   'PM2.5',
#   '31',
#   '32',
#   '31',
#   '33',
#   '32',
#   '33',
#   '32',
#   '34',
#   '34',
#   '32',
#   '36',
#   '36',
#   '33',
#   '27',
#   '26',
#   '28',
#   '25',
#   '26',
#   '27',
#   '28',
#   '32',
#   '24',
#   '25',
#   '15'),
#  ('2013/05/27',
#   '二林',
#   'PM2.5',
#   '23',
#   '20',
#   '27',
#   '23',
#   '22',
#   '19',
#   '16',
#   '15',
#   '17',
#   '21',
#   '24',
#   '20',
#   '15',
#   '9',
#   '10',
#   '16',
#   '18',
#   '19',
#   '18',
#   '19',
#   '16',
#   '11',
#   '16',
#   '17'),
#  ('2013/05/28',
#   '二林',
#   'PM2.5',
#   '23',
#   '19',
#   '22',
#   '20',
#   '22',
#   '22',
#   '28',
#   '25',
#   '22',
#   '19',
#   '23',
#   '20',
#   '21',
#   '16',
#   '15',
#   '15',
#   '8',
#   '14',
#   '18',
#   '25',
#   '22',
#   '17',
#   '15',
#   '14'),
#  ('2013/05/31',
#   '二林',
#   'PM2.5',
#   '14',
#   '17',
#   '11',
#   '18',
#   '14',
#   '18',
#   '17',
#   '26',
#   '29',
#   '28',
#   '21',
#   '26',
#   '29',
#   '21',
#   '22',
#   '26',
#   '21',
#   '13',
#   '10',
#   '17',
#   '27',
#   '32',
#   '29',
#   '21'),
#  ('2013/06/01',
#   '二林',
#   'PM2.5',
#   '21',
#   '21',
#   '24',
#   '14',
#   '19',
#   '17',
#   '23',
#   '23',
#   '20',
#   '27',
#   '18',
#   '27',
#   '18',
#   '25',
#   '24',
#   '23',
#   '19',
#   '12',
#   '12',
#   '12',
#   '10',
#   '14',
#   '10',
#   '11'),
#  ('2013/06/02',
#   '二林',
#   'PM2.5',
#   '14',
#   '17',
#   '15',
#   '8',
#   '15',
#   '18',
#   '21',
#   '18',
#   '21',
#   '18',
#   '20',
#   '16',
#   '18',
#   '15',
#   '19',
#   '19',
#   '23',
#   '16',
#   '25',
#   '23',
#   '31',
#   '20',
#   '24',
#   '14'),
#  ('2013/06/04',
#   '二林',
#   'PM2.5',
#   '29',
#   '25',
#   '19',
#   '20',
#   '24',
#   '22',
#   '23',
#   '26',
#   '36',
#   '42',
#   '41',
#   '38',
#   '37',
#   '38',
#   '14',
#   '13',
#   '23',
#   '25',
#   '19',
#   '22',
#   '30',
#   '44',
#   '38',
#   '34'),
#  ('2013/06/05',
#   '二林',
#   'PM2.5',
#   '26',
#   '36',
#   '41',
#   '44',
#   '37',
#   '32',
#   '27',
#   '28',
#   '38',
#   '46',
#   '49',
#   '41',
#   '38',
#   '32',
#   '28',
#   '25',
#   '22',
#   '23',
#   '30',
#   '34',
#   '31',
#   '25',
#   '25',
#   '30'),
#  ('2013/06/06',
#   '二林',
#   'PM2.5',
#   '31',
#   '30',
#   '32',
#   '29',
#   '35',
#   '31',
#   '38',
#   '37',
#   '44',
#   '45',
#   '47',
#   '54',
#   '53',
#   '51',
#   '34',
#   '29',
#   '27',
#   '28',
#   '25',
#   '25',
#   '28',
#   '35',
#   '33',
#   '37'),
#  ('2013/06/07',
#   '二林',
#   'PM2.5',
#   '36',
#   '38',
#   '39',
#   '34',
#   '35',
#   '31',
#   '34',
#   '38',
#   '42',
#   '44',
#   '34',
#   '32',
#   '34',
#   '33',
#   '29',
#   '24',
#   '23',
#   '23',
#   '16',
#   '24',
#   '40',
#   '49',
#   '39',
#   '25'),
#  ('2013/06/08',
#   '二林',
#   'PM2.5',
#   '22',
#   '28',
#   '25',
#   '20',
#   '16',
#   '20',
#   '23',
#   '25',
#   '22',
#   '22',
#   '18',
#   '14',
#   '14',
#   '12',
#   '15',
#   '8',
#   '15',
#   '15',
#   '19',
#   '18',
#   '15',
#   '19',
#   '22',
#   '24'),
#  ('2013/06/09',
#   '二林',
#   'PM2.5',
#   '24',
#   '23',
#   '24',
#   '24',
#   '17',
#   '19',
#   '15',
#   '19',
#   '19',
#   '25',
#   '23',
#   '21',
#   '18',
#   '18',
#   '19',
#   '14',
#   '17',
#   '14',
#   '17',
#   '21',
#   '20',
#   '19',
#   '15',
#   '14'),
#  ('2013/06/11',
#   '二林',
#   'PM2.5',
#   '20',
#   '19',
#   '22',
#   '18',
#   '16',
#   '17',
#   '19',
#   '22',
#   '23',
#   '23',
#   '28',
#   '27',
#   '26',
#   '25',
#   '27',
#   '28',
#   '18',
#   '21',
#   '17',
#   '21',
#   '21',
#   '31',
#   '38',
#   '35'),
#  ('2013/06/12',
#   '二林',
#   'PM2.5',
#   '28',
#   '21',
#   '18',
#   '14',
#   '13',
#   '16',
#   '14',
#   '20',
#   '21',
#   '26',
#   '29',
#   '28',
#   '35',
#   '32',
#   '39',
#   '31',
#   '29',
#   '23',
#   '26',
#   '19',
#   '18',
#   '11',
#   '16',
#   '16'),
#  ('2013/06/13',
#   '二林',
#   'PM2.5',
#   '21',
#   '12',
#   '11',
#   '13',
#   '13',
#   '15',
#   '12',
#   '17',
#   '21',
#   '23',
#   '25',
#   '25',
#   '27',
#   '22',
#   '23',
#   '18',
#   '20',
#   '15',
#   '22',
#   '19',
#   '23',
#   '11',
#   '18',
#   '10'),
#  ('2013/06/14',
#   '二林',
#   'PM2.5',
#   '8',
#   '12',
#   '14',
#   '12',
#   '9',
#   '14',
#   '15',
#   '21',
#   '15',
#   '20',
#   '18',
#   '25',
#   '24',
#   '25',
#   '23',
#   '21',
#   '27',
#   '31',
#   '32',
#   '29',
#   '24',
#   '28',
#   '32',
#   '35'),
#  ('2013/06/15',
#   '二林',
#   'PM2.5',
#   '41',
#   '34',
#   '41',
#   '28',
#   '31',
#   '24',
#   '29',
#   '37',
#   '38',
#   '46',
#   '38',
#   '40',
#   '40',
#   '43',
#   '35',
#   '27',
#   '24',
#   '31',
#   '30',
#   '33',
#   '32',
#   '35',
#   '30',
#   '21'),
#  ('2013/06/16',
#   '二林',
#   'PM2.5',
#   '17',
#   '14',
#   '15',
#   '15',
#   '20',
#   '24',
#   '22',
#   '21',
#   '32',
#   '44',
#   '48',
#   '48',
#   '56',
#   '58',
#   '54',
#   '45',
#   '47',
#   '48',
#   '50',
#   '38',
#   '26',
#   '19',
#   '17',
#   '23'),
#  ('2013/06/17',
#   '二林',
#   'PM2.5',
#   '25',
#   '34',
#   '33',
#   '36',
#   '37',
#   '38',
#   '29',
#   '25',
#   '36',
#   '52',
#   '68',
#   '56',
#   '47',
#   '26',
#   '21',
#   '18',
#   '19',
#   '28',
#   '42',
#   '51',
#   '51',
#   '42',
#   '35',
#   '37'),
#  ('2013/06/19',
#   '二林',
#   'PM2.5',
#   '26',
#   '26',
#   '31',
#   '27',
#   '23',
#   '15',
#   '25',
#   '33',
#   '30',
#   '26',
#   '27',
#   '34',
#   '34',
#   '31',
#   '30',
#   '32',
#   '32',
#   '26',
#   '18',
#   '17',
#   '22',
#   '28',
#   '24',
#   '20'),
#  ('2013/06/20',
#   '二林',
#   'PM2.5',
#   '19',
#   '29',
#   '35',
#   '41',
#   '36',
#   '39',
#   '38',
#   '41',
#   '40',
#   '32',
#   '44',
#   '39',
#   '34',
#   '17',
#   '18',
#   '25',
#   '24',
#   '21',
#   '24',
#   '28',
#   '30',
#   '28',
#   '24',
#   '27'),
#  ('2013/06/21',
#   '二林',
#   'PM2.5',
#   '30',
#   '33',
#   '34',
#   '26',
#   '29',
#   '29',
#   '38',
#   '38',
#   '41',
#   '37',
#   '33',
#   '32',
#   '21',
#   '24',
#   '19',
#   '19',
#   '16',
#   '17',
#   '27',
#   '33',
#   '34',
#   '34',
#   '26',
#   '37'),
#  ('2013/06/22',
#   '二林',
#   'PM2.5',
#   '35',
#   '36',
#   '27',
#   '25',
#   '26',
#   '24',
#   '28',
#   '34',
#   '38',
#   '48',
#   '65',
#   '70',
#   '64',
#   '55',
#   '58',
#   '62',
#   '57',
#   '48',
#   '38',
#   '36',
#   '41',
#   '40',
#   '33',
#   '23'),
#  ('2013/06/23',
#   '二林',
#   'PM2.5',
#   '27',
#   '22',
#   '30',
#   '34',
#   '44',
#   '47',
#   '50',
#   '54',
#   '54',
#   '39',
#   '31',
#   '15',
#   '21',
#   '20',
#   '20',
#   '17',
#   '22',
#   '33',
#   '32',
#   '21',
#   '12',
#   '9',
#   '10',
#   '12'),
#  ('2013/06/25',
#   '二林',
#   'PM2.5',
#   '15',
#   '16',
#   '21',
#   '20',
#   '17',
#   '13',
#   '10',
#   '16',
#   '16',
#   '16',
#   '14',
#   '18',
#   '18',
#   '15',
#   '11',
#   '17',
#   '24',
#   '31',
#   '35',
#   '30',
#   '28',
#   '27',
#   '31',
#   '30'),
#  ('2013/06/26',
#   '二林',
#   'PM2.5',
#   '33',
#   '37',
#   '33',
#   '40',
#   '37',
#   '44',
#   '36',
#   '38',
#   '39',
#   '38',
#   '40',
#   '38',
#   '40',
#   '34',
#   '37',
#   '34',
#   '33',
#   '29',
#   '34',
#   '37',
#   '40',
#   '40',
#   '38',
#   '32'),
#  ('2013/06/27',
#   '二林',
#   'PM2.5',
#   '29',
#   '32',
#   '32',
#   '32',
#   '30',
#   '31',
#   '36',
#   '30',
#   '34',
#   '27',
#   '39',
#   '35',
#   '41',
#   '32',
#   '29',
#   '23',
#   '20',
#   '27',
#   '25',
#   '31',
#   '29',
#   '31',
#   '32',
#   '27'),
#  ('2013/06/28',
#   '二林',
#   'PM2.5',
#   '30',
#   '28',
#   '33',
#   '34',
#   '38',
#   '30',
#   '31',
#   '30',
#   '33',
#   '31',
#   '30',
#   '26',
#   '27',
#   '18',
#   '25',
#   '29',
#   '39',
#   '37',
#   '33',
#   '37',
#   '36',
#   '37',
#   '31',
#   '31'),
#  ('2013/06/29',
#   '二林',
#   'PM2.5',
#   '28',
#   '29',
#   '26',
#   '29',
#   '27',
#   '37',
#   '30',
#   '32',
#   '31',
#   '33',
#   '35',
#   '32',
#   '42',
#   '46',
#   '48',
#   '38',
#   '59',
#   '73',
#   '78',
#   '54',
#   '42',
#   '40',
#   '39',
#   '32'),
#  ('2013/07/01',
#   '二林',
#   'PM2.5',
#   '32',
#   '29',
#   '25',
#   '31',
#   '32',
#   '29',
#   '30',
#   '33',
#   '43',
#   '39',
#   '29',
#   '29',
#   '41',
#   '26',
#   '28',
#   '103',
#   '120',
#   '145',
#   '83',
#   '82',
#   '67',
#   '55',
#   '50',
#   '41'),
#  ('2013/07/04',
#   '二林',
#   'PM2.5',
#   '19',
#   '15',
#   '15',
#   '14',
#   '18',
#   '18',
#   '22',
#   '20',
#   '21',
#   '22',
#   '25',
#   '32',
#   '28',
#   '27',
#   '29',
#   '37',
#   '43',
#   '40',
#   '32',
#   '25',
#   '17',
#   '18',
#   '14',
#   '16'),
#  ('2013/07/05',
#   '二林',
#   'PM2.5',
#   '18',
#   '16',
#   '12',
#   '7',
#   '15',
#   '16',
#   '17',
#   '10',
#   '14',
#   '20',
#   '28',
#   '26',
#   '23',
#   '17',
#   '27',
#   '35',
#   '53',
#   '46',
#   '36',
#   '20',
#   '17',
#   '14',
#   '12',
#   '8'),
#  ('2013/07/06',
#   '二林',
#   'PM2.5',
#   '7',
#   '7',
#   '10',
#   '10',
#   '10',
#   '14',
#   '12',
#   '17',
#   '14',
#   '17',
#   '17',
#   '16',
#   '21',
#   '20',
#   '20',
#   '18',
#   '22',
#   '19',
#   '17',
#   '15',
#   '20',
#   '22',
#   '18',
#   '13'),
#  ('2013/07/07',
#   '二林',
#   'PM2.5',
#   '12',
#   '17',
#   '17',
#   '15',
#   '8',
#   '9',
#   '9',
#   '15',
#   '14',
#   '14',
#   '20',
#   '26',
#   '37',
#   '26',
#   '30',
#   '23',
#   '32',
#   '36',
#   '31',
#   '21',
#   '7',
#   '6',
#   '3',
#   '7'),
#  ('2013/07/09',
#   '二林',
#   'PM2.5',
#   '23',
#   '22',
#   '17',
#   '15',
#   '20',
#   '18',
#   '16',
#   '13',
#   '17',
#   '20',
#   '24',
#   '18',
#   '17',
#   '13',
#   '17',
#   '26',
#   '33',
#   '33',
#   '29',
#   '22',
#   '22',
#   '18',
#   '19',
#   '18'),
#  ('2013/07/10',
#   '二林',
#   'PM2.5',
#   '15',
#   '15',
#   '14',
#   '12',
#   '7',
#   '5',
#   '9',
#   '15',
#   '20',
#   '23',
#   '22',
#   '18',
#   '10',
#   '8',
#   '11',
#   '10',
#   '15',
#   '12',
#   '19',
#   '21',
#   '38',
#   '41',
#   '38',
#   '25'),
#  ('2013/07/11',
#   '二林',
#   'PM2.5',
#   '21',
#   '18',
#   '18',
#   '20',
#   '22',
#   '21',
#   '21',
#   '26',
#   '26',
#   '23',
#   '14',
#   '12',
#   '14',
#   '14',
#   '15',
#   '14',
#   '23',
#   '24',
#   '30',
#   '36',
#   '39',
#   '34',
#   '29',
#   '22'),
#  ('2013/07/12',
#   '二林',
#   'PM2.5',
#   '22',
#   '14',
#   '12',
#   '13',
#   '16',
#   '21',
#   '22',
#   '22',
#   '20',
#   '19',
#   '19',
#   '16',
#   '18',
#   '14',
#   '17',
#   '14',
#   '14',
#   '12',
#   '11',
#   '12',
#   '10',
#   '10',
#   '5',
#   '6'),
#  ('2013/07/16',
#   '二林',
#   'PM2.5',
#   '13',
#   '15',
#   '11',
#   '17',
#   '12',
#   '17',
#   '10',
#   '13',
#   '7',
#   '10',
#   '10',
#   '21',
#   '15',
#   '11',
#   '17',
#   '13',
#   '10',
#   '9',
#   '18',
#   '22',
#   '22',
#   '20',
#   '21',
#   '18'),
#  ('2013/07/17',
#   '二林',
#   'PM2.5',
#   '18',
#   '11',
#   '10',
#   '9',
#   '9',
#   '12',
#   '14',
#   '18',
#   '19',
#   '19',
#   '21',
#   '23',
#   '26',
#   '27',
#   '29',
#   '28',
#   '34',
#   '33',
#   '38',
#   '31',
#   '33',
#   '37',
#   '43',
#   '43'),
#  ('2013/07/18',
#   '二林',
#   'PM2.5',
#   '36',
#   '35',
#   '36',
#   '38',
#   '40',
#   '34',
#   '35',
#   '31',
#   '34',
#   '37',
#   '41',
#   '48',
#   '50',
#   '44',
#   '40',
#   '29',
#   '30',
#   '27',
#   '28',
#   '30',
#   '39',
#   '50',
#   '56',
#   '56'),
#  ('2013/07/19',
#   '二林',
#   'PM2.5',
#   '55',
#   '57',
#   '48',
#   '34',
#   '15',
#   '15',
#   '21',
#   '32',
#   '33',
#   '36',
#   '41',
#   '45',
#   '43',
#   '33',
#   '27',
#   '26',
#   '33',
#   '33',
#   '34',
#   '32',
#   '32',
#   '36',
#   '32',
#   '29'),
#  ('2013/07/20',
#   '二林',
#   'PM2.5',
#   '23',
#   '24',
#   '28',
#   '29',
#   '25',
#   '17',
#   '13',
#   '20',
#   '30',
#   '40',
#   '50',
#   '57',
#   '47',
#   '36',
#   '25',
#   '27',
#   '25',
#   '19',
#   '28',
#   '28',
#   '33',
#   '22',
#   '23',
#   '29'),
#  ('2013/07/21',
#   '二林',
#   'PM2.5',
#   '37',
#   '37',
#   '33',
#   '32',
#   '29',
#   '31',
#   '30',
#   '46',
#   '51',
#   '47',
#   '33',
#   '26',
#   '23',
#   '20',
#   '17',
#   '16',
#   '14',
#   '11',
#   '22',
#   '22',
#   '28',
#   '20',
#   '24',
#   '24'),
#  ('2013/07/23',
#   '二林',
#   'PM2.5',
#   '36',
#   '43',
#   '44',
#   '48',
#   '47',
#   '51',
#   '60',
#   '60',
#   '61',
#   '43',
#   '39',
#   '31',
#   '35',
#   '31',
#   '26',
#   '25',
#   '21',
#   '22',
#   '23',
#   '33',
#   '39',
#   '37',
#   '30',
#   '23'),
#  ('2013/07/24',
#   '二林',
#   'PM2.5',
#   '25',
#   '22',
#   '18',
#   '21',
#   '22',
#   '24',
#   '24',
#   '30',
#   '32',
#   '27',
#   '25',
#   '35',
#   '43',
#   '45',
#   '33',
#   '22',
#   '21',
#   '25',
#   '21',
#   '11',
#   '5',
#   '8',
#   '10',
#   '12'),
#  ('2013/07/25',
#   '二林',
#   'PM2.5',
#   '8',
#   '11',
#   '15',
#   '16',
#   '15',
#   '11',
#   '9',
#   '15',
#   '15',
#   '21',
#   '16',
#   '20',
#   '23',
#   '21',
#   '16',
#   '15',
#   '17',
#   '15',
#   '12',
#   '8',
#   '8',
#   '6',
#   '10',
#   '5'),
#  ('2013/07/26',
#   '二林',
#   'PM2.5',
#   '3',
#   '6',
#   '11',
#   '13',
#   '8',
#   '3',
#   '11',
#   '12',
#   '23',
#   '16',
#   '16',
#   '15',
#   '17',
#   '24',
#   '22',
#   '23',
#   '15',
#   '11',
#   '7',
#   '14',
#   '11',
#   '14',
#   '12',
#   '20'),
#  ('2013/07/27',
#   '二林',
#   'PM2.5',
#   '20',
#   '16',
#   '10',
#   '5',
#   '5',
#   '5',
#   '9',
#   '15',
#   '13',
#   '17',
#   '13',
#   '16',
#   '17',
#   '21',
#   '26',
#   '20',
#   '23',
#   '26',
#   '29',
#   '29',
#   '24',
#   '23',
#   '18',
#   '20'),
#  ('2013/07/28',
#   '二林',
#   'PM2.5',
#   '17',
#   '21',
#   '13',
#   '20',
#   '18',
#   '23',
#   '21',
#   '21',
#   '19',
#   '20',
#   '20',
#   '20',
#   '18',
#   '21',
#   '20',
#   '17',
#   '11',
#   '16',
#   '17',
#   '22',
#   '22',
#   '23',
#   '21',
#   '25'),
#  ('2013/07/30',
#   '二林',
#   'PM2.5',
#   '24',
#   '19',
#   '13',
#   '13',
#   '14',
#   '19',
#   '15',
#   '13',
#   '17',
#   '14',
#   '20',
#   '26',
#   '28',
#   '32',
#   '28',
#   '28',
#   '22',
#   '18',
#   '22',
#   '22',
#   '24',
#   '17',
#   '17',
#   '10'),
#  ('2013/08/01',
#   '二林',
#   'PM2.5',
#   '24',
#   '22',
#   '18',
#   '18',
#   '16',
#   '19',
#   '20',
#   '26',
#   '26',
#   '24',
#   '21',
#   '27',
#   '28',
#   '27',
#   '21',
#   '30',
#   '32',
#   '37',
#   '33',
#   '45',
#   '44',
#   '52',
#   '52',
#   '61'),
#  ('2013/08/02',
#   '二林',
#   'PM2.5',
#   '46',
#   '36',
#   '16',
#   '18',
#   '12',
#   '14',
#   '10',
#   '16',
#   '17',
#   '20',
#   '20',
#   '19',
#   '19',
#   '19',
#   '19',
#   '19',
#   '16',
#   '16',
#   '11',
#   '18',
#   '16',
#   '24',
#   '25',
#   '26'),
#  ('2013/08/03',
#   '二林',
#   'PM2.5',
#   '23',
#   '23',
#   '34',
#   '38',
#   '34',
#   '26',
#   '27',
#   '33',
#   '38',
#   '38',
#   '33',
#   '31',
#   '35',
#   '33',
#   '29',
#   '19',
#   '17',
#   '23',
#   '31',
#   '39',
#   '38',
#   '37',
#   '35',
#   '37'),
#  ('2013/08/04',
#   '二林',
#   'PM2.5',
#   '42',
#   '39',
#   '38',
#   '34',
#   '35',
#   '34',
#   '35',
#   '41',
#   '41',
#   '40',
#   '36',
#   '33',
#   '31',
#   '25',
#   '19',
#   '13',
#   '11',
#   '13',
#   '20',
#   '25',
#   '29',
#   '29',
#   '26',
#   '31'),
#  ('2013/08/05',
#   '二林',
#   'PM2.5',
#   '29',
#   '31',
#   '27',
#   '25',
#   '23',
#   '23',
#   '25',
#   '29',
#   '26',
#   '28',
#   '27',
#   '28',
#   '31',
#   '31',
#   '29',
#   '20',
#   '20',
#   '25',
#   '28',
#   '26',
#   '22',
#   '23',
#   '21',
#   '19'),
#  ('2013/08/06',
#   '二林',
#   'PM2.5',
#   '15',
#   '16',
#   '17',
#   '20',
#   '17',
#   '20',
#   '19',
#   '20',
#   '16',
#   '10',
#   '12',
#   '22',
#   '33',
#   '42',
#   '41',
#   '36',
#   '25',
#   '13',
#   '12',
#   '19',
#   '29',
#   '32',
#   '32',
#   '35'),
#  ('2013/08/08',
#   '二林',
#   'PM2.5',
#   '10',
#   '8',
#   '12',
#   '12',
#   '19',
#   '12',
#   '16',
#   '10',
#   '18',
#   '17',
#   '25',
#   '22',
#   '20',
#   '15',
#   '11',
#   '8',
#   '11',
#   '7',
#   '10',
#   '12',
#   '20',
#   '22',
#   '19',
#   '18'),
#  ('2013/08/09',
#   '二林',
#   'PM2.5',
#   '13',
#   '15',
#   '14',
#   '19',
#   '24',
#   '38',
#   '36',
#   '36',
#   '23',
#   '24',
#   '13',
#   '14',
#   '17',
#   '21',
#   '18',
#   '16',
#   '16',
#   '11',
#   '16',
#   '16',
#   '18',
#   '16',
#   '19',
#   '25'),
#  ('2013/08/10',
#   '二林',
#   'PM2.5',
#   '26',
#   '23',
#   '26',
#   '20',
#   '17',
#   '13',
#   '14',
#   '19',
#   '14',
#   '16',
#   '24',
#   '26',
#   '27',
#   '13',
#   '15',
#   '14',
#   '15',
#   '9',
#   '11',
#   '12',
#   '12',
#   '13',
#   '20',
#   '25'),
#  ('2013/08/11',
#   '二林',
#   'PM2.5',
#   '24',
#   '19',
#   '22',
#   '22',
#   '25',
#   '23',
#   '22',
#   '23',
#   '23',
#   '27',
#   '26',
#   '25',
#   '19',
#   '16',
#   '13',
#   '19',
#   '14',
#   '19',
#   '10',
#   '15',
#   '14',
#   '22',
#   '24',
#   '20'),
#  ('2013/08/12',
#   '二林',
#   'PM2.5',
#   '19',
#   '22',
#   '22',
#   '23',
#   '26',
#   '27',
#   '27',
#   '30',
#   '30',
#   '35',
#   '32',
#   '33',
#   '27',
#   '25',
#   '22',
#   '23',
#   '21',
#   '24',
#   '40',
#   '44',
#   '51',
#   '41',
#   '48',
#   '46'),
#  ('2013/08/14',
#   '二林',
#   'PM2.5',
#   '31',
#   '30',
#   '27',
#   '29',
#   '28',
#   '24',
#   '21',
#   '28',
#   '41',
#   '45',
#   '44',
#   '42',
#   '40',
#   '25',
#   '24',
#   '21',
#   '29',
#   '19',
#   '17',
#   '10',
#   '6',
#   '1',
#   '5',
#   '7'),
#  ('2013/08/15',
#   '二林',
#   'PM2.5',
#   '11',
#   '11',
#   '9',
#   '10',
#   '14',
#   '14',
#   '17',
#   '11',
#   '14',
#   '10',
#   '14',
#   '14',
#   '17',
#   '14',
#   '16',
#   '9',
#   '15',
#   '19',
#   '22',
#   '19',
#   '9',
#   '10',
#   '16',
#   '25'),
#  ('2013/08/16',
#   '二林',
#   'PM2.5',
#   '23',
#   '21',
#   '19',
#   '20',
#   '11',
#   '11',
#   '13',
#   '20',
#   '24',
#   '31',
#   '36',
#   '45',
#   '44',
#   '43',
#   '33',
#   '24',
#   '19',
#   '17',
#   '19',
#   '20',
#   '21',
#   '31',
#   '29',
#   '32'),
#  ('2013/08/17',
#   '二林',
#   'PM2.5',
#   '27',
#   '31',
#   '33',
#   '33',
#   '33',
#   '26',
#   '26',
#   '23',
#   '27',
#   '26',
#   '27',
#   '28',
#   '31',
#   '26',
#   '26',
#   '20',
#   '24',
#   '21',
#   '24',
#   '24',
#   '19',
#   '13',
#   '11',
#   '11'),
#  ('2013/08/18',
#   '二林',
#   'PM2.5',
#   '13',
#   '18',
#   '27',
#   '34',
#   '32',
#   '23',
#   '26',
#   '31',
#   '39',
#   '38',
#   '33',
#   '33',
#   '30',
#   '28',
#   '21',
#   '15',
#   '16',
#   '23',
#   '27',
#   '29',
#   '30',
#   '36',
#   '34',
#   '27'),
#  ('2013/08/19',
#   '二林',
#   'PM2.5',
#   '25',
#   '25',
#   '35',
#   '31',
#   '32',
#   '19',
#   '25',
#   '23',
#   '26',
#   '19',
#   '25',
#   '31',
#   '32',
#   '24',
#   '16',
#   '17',
#   '16',
#   '19',
#   '17',
#   '24',
#   '22',
#   '23',
#   '20',
#   '23'),
#  ('2013/08/20',
#   '二林',
#   'PM2.5',
#   '28',
#   '23',
#   '27',
#   '18',
#   '24',
#   '30',
#   '41',
#   '45',
#   '37',
#   '32',
#   '25',
#   '22',
#   '15',
#   '12',
#   '10',
#   '15',
#   '11',
#   '9',
#   '10',
#   '10',
#   '13',
#   '6',
#   '7',
#   '9'),
#  ('2013/08/22',
#   '二林',
#   'PM2.5',
#   '11',
#   '13',
#   '15',
#   '16',
#   '13',
#   '13',
#   '18',
#   '23',
#   '21',
#   '12',
#   '12',
#   '10',
#   '9',
#   '16',
#   '16',
#   '13',
#   '10',
#   '16',
#   '20',
#   '23',
#   '16',
#   '19',
#   '11',
#   '17'),
#  ('2013/08/23',
#   '二林',
#   'PM2.5',
#   '8',
#   '9',
#   '6',
#   '10',
#   '14',
#   '10',
#   '7',
#   '6',
#   '10',
#   '12',
#   '12',
#   '13',
#   '16',
#   '15',
#   '14',
#   '12',
#   '13',
#   '10',
#   '7',
#   '6',
#   '5',
#   '8',
#   '8',
#   '11'),
#  ('2013/08/24',
#   '二林',
#   'PM2.5',
#   '5',
#   '7',
#   '4',
#   '10',
#   '7',
#   '13',
#   '9',
#   '11',
#   '12',
#   '16',
#   '13',
#   '12',
#   '6',
#   '13',
#   '10',
#   '18',
#   '11',
#   '14',
#   '15',
#   '19',
#   '16',
#   '15',
#   '11',
#   '15'),
#  ('2013/08/25',
#   '二林',
#   'PM2.5',
#   '12',
#   '14',
#   '16',
#   '15',
#   '16',
#   '9',
#   '10',
#   '11',
#   '16',
#   '19',
#   '22',
#   '29',
#   '23',
#   '21',
#   '12',
#   '12',
#   '16',
#   '12',
#   '23',
#   '15',
#   '19',
#   '14',
#   '19',
#   '19'),
#  ('2013/08/26',
#   '二林',
#   'PM2.5',
#   '19',
#   '17',
#   '17',
#   '10',
#   '10',
#   '10',
#   '18',
#   '17',
#   '21',
#   '17',
#   '30',
#   '30',
#   '32',
#   '23',
#   '19',
#   '18',
#   '17',
#   '17',
#   '17',
#   '18',
#   '18',
#   '19',
#   '14',
#   '16'),
#  ('2013/08/27',
#   '二林',
#   'PM2.5',
#   '13',
#   '17',
#   '18',
#   '20',
#   '19',
#   '21',
#   '25',
#   '28',
#   '26',
#   '23',
#   '24',
#   '20',
#   '20',
#   '16',
#   '17',
#   '12',
#   '13',
#   '21',
#   '34',
#   '35',
#   '30',
#   '25',
#   '24',
#   '26'),
#  ('2013/08/29',
#   '二林',
#   'PM2.5',
#   '22',
#   '20',
#   '13',
#   '9',
#   '5',
#   '6',
#   '9',
#   '12',
#   '12',
#   '11',
#   '17',
#   '14',
#   '18',
#   '15',
#   '15',
#   '7',
#   '4',
#   '6',
#   '10',
#   '9',
#   '10',
#   '12',
#   '14',
#   '11'),
#  ('2013/08/30',
#   '二林',
#   'PM2.5',
#   '11',
#   '13',
#   '13',
#   '11',
#   '10',
#   '13',
#   '12',
#   '10',
#   '9',
#   '9',
#   '12',
#   '12',
#   '11',
#   '4',
#   '1',
#   '5',
#   '10',
#   '10',
#   '9',
#   '7',
#   '9',
#   '6',
#   '10',
#   '10'),
#  ('2013/09/01',
#   '二林',
#   'PM2.5',
#   '23',
#   '20',
#   '13',
#   '16',
#   '13',
#   '20',
#   '15',
#   '15',
#   '12',
#   '12',
#   '14',
#   '14',
#   '18',
#   '22',
#   '23',
#   '22',
#   '20',
#   '20',
#   '19',
#   '30',
#   '29',
#   '38',
#   '29',
#   '31'),
#  ('2013/09/03',
#   '二林',
#   'PM2.5',
#   '51',
#   '52',
#   '57',
#   '54',
#   '62',
#   '57',
#   '63',
#   '54',
#   '50',
#   '41',
#   '34',
#   '31',
#   '30',
#   '34',
#   '39',
#   '39',
#   '48',
#   '50',
#   '42',
#   '38',
#   '33',
#   '36',
#   '35',
#   '34'),
#  ('2013/09/04',
#   '二林',
#   'PM2.5',
#   '34',
#   '30',
#   '28',
#   '31',
#   '41',
#   '50',
#   '50',
#   '47',
#   '46',
#   '47',
#   '39',
#   '31',
#   '24',
#   '26',
#   '24',
#   '26',
#   '26',
#   '30',
#   '29',
#   '26',
#   '23',
#   '22',
#   '22',
#   '20'),
#  ('2013/09/05',
#   '二林',
#   'PM2.5',
#   '18',
#   '23',
#   '28',
#   '30',
#   '22',
#   '19',
#   '25',
#   '28',
#   '45',
#   '48',
#   '64',
#   '62',
#   '66',
#   '63',
#   '61',
#   '62',
#   '56',
#   '51',
#   '39',
#   '37',
#   '36',
#   '32',
#   '29',
#   '21'),
#  ('2013/09/06',
#   '二林',
#   'PM2.5',
#   '25',
#   '20',
#   '19',
#   '21',
#   '23',
#   '33',
#   '34',
#   '51',
#   '67',
#   '80',
#   '71',
#   '56',
#   '42',
#   '33',
#   '29',
#   '23',
#   '25',
#   '23',
#   '23',
#   '19',
#   '16',
#   '17',
#   '16',
#   '14'),
#  ('2013/09/07',
#   '二林',
#   'PM2.5',
#   '13',
#   '14',
#   '11',
#   '11',
#   '13',
#   '17',
#   '21',
#   '24',
#   '32',
#   '42',
#   '44',
#   '54',
#   '48',
#   '49',
#   '45',
#   '46',
#   '39',
#   '23',
#   '21',
#   '17',
#   '18',
#   '17',
#   '21',
#   '26'),
#  ('2013/09/08',
#   '二林',
#   'PM2.5',
#   '26',
#   '31',
#   '36',
#   '42',
#   '51',
#   '53',
#   '57',
#   '59',
#   '60',
#   '54',
#   '44',
#   '46',
#   '46',
#   '48',
#   '37',
#   '41',
#   '39',
#   '40',
#   '28',
#   '25',
#   '25',
#   '25',
#   '29',
#   '30'),
#  ('2013/09/10',
#   '二林',
#   'PM2.5',
#   '17',
#   '16',
#   '16',
#   '15',
#   '18',
#   '16',
#   '23',
#   '34',
#   '41',
#   '43',
#   '38',
#   '28',
#   '25',
#   '40',
#   '36',
#   '35',
#   '37',
#   '48',
#   '62',
#   '59',
#   '46',
#   '39',
#   '38',
#   '38'),
#  ('2013/09/11',
#   '二林',
#   'PM2.5',
#   '34',
#   '29',
#   '36',
#   '38',
#   '51',
#   '51',
#   '52',
#   '57',
#   '62',
#   '65',
#   '61',
#   '62',
#   '67',
#   '58',
#   '48',
#   '32',
#   '38',
#   '34',
#   '48',
#   '48',
#   '53',
#   '47',
#   '40',
#   '41'),
#  ('2013/09/12',
#   '二林',
#   'PM2.5',
#   '38',
#   '41',
#   '45',
#   '48',
#   '52',
#   '48',
#   '49',
#   '49',
#   '50',
#   '57',
#   '56',
#   '57',
#   '57',
#   '53',
#   '40',
#   '33',
#   '23',
#   '26',
#   '17',
#   '27',
#   '27',
#   '32',
#   '24',
#   '21'),
#  ('2013/09/16',
#   '二林',
#   'PM2.5',
#   '22',
#   '25',
#   '20',
#   '25',
#   '22',
#   '26',
#   '27',
#   '35',
#   '37',
#   '39',
#   '29',
#   '30',
#   '24',
#   '20',
#   '22',
#   '31',
#   '29',
#   '32',
#   '71',
#   '71',
#   '69',
#   '35',
#   '39',
#   '45'),
#  ('2013/09/17',
#   '二林',
#   'PM2.5',
#   '45',
#   '41',
#   '35',
#   '29',
#   '30',
#   '25',
#   '33',
#   '31',
#   '35',
#   '33',
#   '37',
#   '42',
#   '39',
#   '41',
#   '35',
#   '34',
#   '23',
#   '23',
#   '23',
#   '23',
#   '20',
#   '23',
#   '22',
#   '25'),
#  ('2013/09/18',
#   '二林',
#   'PM2.5',
#   '24',
#   '26',
#   '25',
#   '19',
#   '21',
#   '21',
#   '23',
#   '28',
#   '37',
#   '47',
#   '50',
#   '51',
#   '43',
#   '35',
#   '25',
#   '25',
#   '24',
#   '36',
#   '38',
#   '43',
#   '36',
#   '35',
#   '40',
#   '38'),
#  ('2013/09/19',
#   '二林',
#   'PM2.5',
#   '41',
#   '33',
#   '28',
#   '26',
#   '26',
#   '21',
#   '21',
#   '23',
#   '31',
#   '39',
#   '42',
#   '45',
#   '42',
#   '44',
#   '44',
#   '43',
#   '30',
#   '23',
#   '17',
#   '20',
#   '23',
#   '24',
#   '23',
#   '20'),
#  ('2013/09/20',
#   '二林',
#   'PM2.5',
#   '15',
#   '13',
#   '8',
#   '7',
#   '10',
#   '17',
#   '14',
#   '15',
#   '15',
#   '18',
#   '19',
#   '21',
#   '19',
#   '19',
#   '20',
#   '26',
#   '23',
#   '22',
#   '15',
#   '17',
#   '10',
#   '14',
#   '15',
#   '19'),
#  ('2013/09/21',
#   '二林',
#   'PM2.5',
#   '17',
#   '12',
#   '5',
#   '6',
#   '6',
#   '9',
#   '10',
#   '12',
#   '15',
#   '11',
#   '14',
#   '8',
#   '13',
#   '12',
#   '18',
#   '20',
#   '18',
#   '21',
#   '16',
#   '13',
#   '6',
#   '9',
#   '14',
#   '18'),
#  ('2013/09/22',
#   '二林',
#   'PM2.5',
#   '19',
#   '17',
#   '12',
#   '13',
#   '14',
#   '21',
#   '17',
#   '15',
#   '7',
#   '12',
#   '17',
#   '22',
#   '17',
#   '15',
#   '15',
#   '15',
#   '14',
#   '16',
#   '12',
#   '18',
#   '17',
#   '20',
#   '15',
#   '15'),
#  ('2013/09/23',
#   '二林',
#   'PM2.5',
#   '17',
#   '20',
#   '22',
#   '16',
#   '15',
#   '8',
#   '15',
#   '14',
#   '22',
#   '26',
#   '20',
#   '17',
#   '13',
#   '20',
#   '22',
#   '18',
#   '21',
#   '26',
#   '36',
#   '38',
#   '38',
#   '30',
#   '33',
#   '34'),
#  ('2013/09/25',
#   '二林',
#   'PM2.5',
#   '19',
#   '17',
#   '22',
#   '16',
#   '20',
#   '11',
#   '19',
#   '17',
#   '22',
#   '25',
#   '29',
#   '36',
#   '33',
#   '35',
#   '30',
#   '32',
#   '32',
#   '33',
#   '29',
#   '31',
#   '32',
#   '36',
#   '32',
#   '33'),
#  ('2013/09/27',
#   '二林',
#   'PM2.5',
#   '19',
#   '11',
#   '15',
#   '12',
#   '15',
#   '16',
#   '17',
#   '18',
#   '14',
#   '12',
#   '17',
#   '20',
#   '24',
#   '18',
#   '17',
#   '21',
#   '24',
#   '24',
#   '20',
#   '19',
#   '20',
#   '19',
#   '16',
#   '21'),
#  ('2013/09/28',
#   '二林',
#   'PM2.5',
#   '23',
#   '22',
#   '22',
#   '23',
#   '25',
#   '22',
#   '21',
#   '28',
#   '41',
#   '52',
#   '48',
#   '47',
#   '41',
#   '43',
#   '35',
#   '37',
#   '29',
#   '29',
#   '26',
#   '26',
#   '20',
#   '22',
#   '21',
#   '22'),
#  ('2013/09/29',
#   '二林',
#   'PM2.5',
#   '22',
#   '23',
#   '22',
#   '22',
#   '21',
#   '19',
#   '18',
#   '26',
#   '43',
#   '59',
#   '71',
#   '69',
#   '58',
#   '42',
#   '32',
#   '31',
#   '48',
#   '57',
#   '59',
#   '41',
#   '40',
#   '36',
#   '34',
#   '28'),
# ...
#   'PM2.5',
#   '44',
#   '43',
#   '41',
#   '41',
#   '42',
#   '37',
#   '30',
#   '29',
#   '34',
#   '40',
#   '42',
#   '45',
#   '45',
#   '43',
#   '42',
#   '40',
#   '42',
#   '41',
#   '38',
#   '38',
#   '41',
#   '51',
#   '65',
#   '63'),
#  ('2013/05/09',
#   '大里',
#   'PM2.5',
#   '61',
#   '48',
#   '40',
#   '37',
#   '41',
#   '45',
#   '51',
#   '53',
#   '54',
#   '47',
#   '45',
#   '23',
#   '18',
#   '32',
#   '48',
#   '59',
#   '75',
#   '71',
#   '58',
#   '54',
#   '59',
#   '78',
#   '86',
#   '78'),
#  ('2013/05/10',
#   '大里',
#   'PM2.5',
#   '73',
#   '62',
#   '61',
#   '58',
#   '52',
#   '51',
#   '54',
#   '57',
#   '58',
#   '54',
#   '46',
#   '49',
#   '38',
#   '35',
#   '26',
#   '29',
#   '26',
#   '23',
#   '10',
#   '7',
#   '14',
#   '19',
#   '21',
#   '14'),
#  ('2013/05/12',
#   '大里',
#   'PM2.5',
#   '20',
#   '22',
#   '28',
#   '19',
#   '12',
#   '4',
#   '3',
#   '8',
#   '15',
#   '25',
#   '25',
#   '27',
#   '28',
#   '29',
#   '28',
#   '15',
#   '7',
#   '4',
#   '9',
#   '13',
#   '23',
#   '19',
#   '12',
#   '8'),
#  ('2013/05/18',
#   '大里',
#   'PM2.5',
#   '21',
#   '19',
#   '19',
#   '13',
#   '14',
#   '7',
#   '4',
#   '7',
#   '16',
#   '16',
#   '19',
#   '20',
#   '21',
#   '8',
#   '9',
#   '15',
#   '21',
#   '26',
#   '25',
#   '13',
#   '9',
#   '10',
#   '8',
#   '8'),
#  ('2013/05/19',
#   '大里',
#   'PM2.5',
#   '7',
#   '14',
#   '7',
#   '9',
#   '6',
#   '14',
#   '12',
#   '16',
#   '16',
#   '20',
#   '19',
#   '18',
#   '14',
#   '15',
#   '16',
#   '20',
#   '28',
#   '30',
#   '32',
#   '29',
#   '24',
#   '19',
#   '8',
#   '6'),
#  ('2013/05/20',
#   '大里',
#   'PM2.5',
#   '14',
#   '13',
#   '18',
#   '12',
#   '15',
#   '17',
#   '16',
#   '20',
#   '21',
#   '22',
#   '19',
#   '11',
#   '20',
#   '24',
#   '19',
#   '8',
#   '3',
#   '9',
#   '15',
#   '19',
#   '19',
#   '17',
#   '16',
#   '11'),
#  ('2013/05/22',
#   '大里',
#   'PM2.5',
#   '24',
#   '21',
#   '13',
#   '11',
#   '6',
#   '6',
#   '0',
#   '2',
#   '5',
#   '9',
#   '8',
#   '14',
#   '13',
#   '13',
#   '4',
#   '5',
#   '6',
#   '4',
#   '5',
#   '10',
#   '18',
#   '20',
#   '22',
#   '25'),
#  ('2013/05/24',
#   '大里',
#   'PM2.5',
#   '15',
#   '15',
#   '9',
#   '10',
#   '15',
#   '18',
#   '19',
#   '12',
#   '21',
#   '41',
#   '47',
#   '45',
#   '17',
#   '23',
#   '21',
#   '20',
#   '23',
#   '24',
#   '19',
#   '27',
#   '24',
#   '21',
#   '30',
#   '34'),
#  ('2013/05/25',
#   '大里',
#   'PM2.5',
#   '36',
#   '34',
#   '31',
#   '34',
#   '22',
#   '17',
#   '14',
#   '14',
#   '24',
#   '23',
#   '36',
#   '49',
#   '51',
#   '55',
#   '45',
#   '54',
#   '40',
#   '32',
#   '26',
#   '30',
#   '35',
#   '36',
#   '36',
#   '33'),
#  ('2013/05/26',
#   '大里',
#   'PM2.5',
#   '29',
#   '22',
#   '26',
#   '22',
#   '25',
#   '20',
#   '22',
#   '26',
#   '26',
#   '27',
#   '23',
#   '15',
#   '19',
#   '25',
#   '31',
#   '26',
#   '30',
#   '32',
#   '29',
#   '15',
#   '25',
#   '31',
#   '29',
#   '17'),
#  ('2013/05/29',
#   '大里',
#   'PM2.5',
#   '19',
#   '19',
#   '13',
#   '13',
#   '7',
#   '12',
#   '8',
#   '9',
#   '2',
#   '9',
#   '26',
#   '26',
#   '23',
#   '31',
#   '28',
#   '22',
#   '26',
#   '31',
#   '34',
#   '25',
#   '21',
#   '20',
#   '24',
#   '19'),
#  ('2013/05/30',
#   '大里',
#   'PM2.5',
#   '17',
#   '15',
#   '21',
#   '21',
#   '25',
#   '16',
#   '9',
#   '5',
#   '9',
#   '15',
#   '16',
#   '24',
#   '38',
#   '35',
#   '29',
#   '20',
#   '23',
#   '25',
#   '19',
#   '18',
#   '14',
#   '22',
#   '25',
#   '19'),
#  ('2013/06/03',
#   '大里',
#   'PM2.5',
#   '30',
#   '28',
#   '20',
#   '18',
#   '18',
#   '28',
#   '21',
#   '23',
#   '13',
#   '12',
#   '15',
#   '25',
#   '36',
#   '33',
#   '26',
#   '28',
#   '30',
#   '41',
#   '35',
#   '34',
#   '30',
#   '36',
#   '41',
#   '42'),
#  ('2013/06/04',
#   '大里',
#   'PM2.5',
#   '41',
#   '39',
#   '40',
#   '39',
#   '34',
#   '30',
#   '30',
#   '38',
#   '31',
#   '28',
#   '23',
#   '33',
#   '39',
#   '48',
#   '46',
#   '41',
#   '41',
#   '40',
#   '30',
#   '18',
#   '21',
#   '31',
#   '34',
#   '36'),
#  ('2013/06/07',
#   '大里',
#   'PM2.5',
#   '28',
#   '24',
#   '24',
#   '21',
#   '21',
#   '26',
#   '30',
#   '30',
#   '29',
#   '24',
#   '41',
#   '47',
#   '57',
#   '31',
#   '34',
#   '28',
#   '42',
#   '37',
#   '47',
#   '41',
#   '43',
#   '32',
#   '37',
#   '30'),
#  ('2013/06/10',
#   '大里',
#   'PM2.5',
#   '16',
#   '19',
#   '19',
#   '15',
#   '8',
#   '12',
#   '12',
#   '8',
#   '7',
#   '7',
#   '9',
#   '5',
#   '11',
#   '14',
#   '19',
#   '14',
#   '15',
#   '17',
#   '21',
#   '29',
#   '32',
#   '36',
#   '36',
#   '38'),
#  ('2013/06/12',
#   '大里',
#   'PM2.5',
#   '5',
#   '13',
#   '10',
#   '18',
#   '11',
#   '6',
#   '5',
#   '8',
#   '9',
#   '10',
#   '23',
#   '23',
#   '15',
#   '25',
#   '21',
#   '18',
#   '10',
#   '11',
#   '17',
#   '19',
#   '17',
#   '12',
#   '13',
#   '13'),
#  ('2013/06/13',
#   '大里',
#   'PM2.5',
#   '7',
#   '9',
#   '8',
#   '8',
#   '5',
#   '8',
#   '10',
#   '15',
#   '15',
#   '28',
#   '35',
#   '38',
#   '36',
#   '36',
#   '40',
#   '45',
#   '42',
#   '42',
#   '33',
#   '24',
#   '20',
#   '21',
#   '23',
#   '20'),
#  ('2013/06/14',
#   '大里',
#   'PM2.5',
#   '22',
#   '17',
#   '14',
#   '9',
#   '20',
#   '26',
#   '31',
#   '30',
#   '22',
#   '25',
#   '16',
#   '25',
#   '24',
#   '25',
#   '20',
#   '21',
#   '18',
#   '24',
#   '23',
#   '34',
#   '34',
#   '26',
#   '26',
#   '23'),
#  ('2013/06/17',
#   '大里',
#   'PM2.5',
#   '24',
#   '21',
#   '19',
#   '21',
#   '20',
#   '23',
#   '15',
#   '16',
#   '18',
#   '26',
#   '21',
#   '23',
#   '21',
#   '46',
#   '45',
#   '41',
#   '23',
#   '23',
#   '21',
#   '26',
#   '24',
#   '29',
#   '26',
#   '32'),
#  ('2013/06/21',
#   '大里',
#   'PM2.5',
#   '18',
#   '20',
#   '24',
#   '25',
#   '26',
#   '22',
#   '18',
#   '16',
#   '24',
#   '32',
#   '46',
#   '47',
#   '42',
#   '33',
#   '26',
#   '28',
#   '28',
#   '25',
#   '24',
#   '17',
#   '21',
#   '17',
#   '19',
#   '14'),
#  ('2013/06/22',
#   '大里',
#   'PM2.5',
#   '11',
#   '10',
#   '7',
#   '18',
#   '17',
#   '18',
#   '7',
#   '8',
#   '11',
#   '21',
#   '18',
#   '27',
#   '30',
#   '31',
#   '34',
#   '32',
#   '40',
#   '33',
#   '34',
#   '31',
#   '27',
#   '29',
#   '30',
#   '30'),
#  ('2013/06/23',
#   '大里',
#   'PM2.5',
#   '35',
#   '31',
#   '32',
#   '30',
#   '29',
#   '25',
#   '24',
#   '27',
#   '36',
#   '38',
#   '38',
#   '41',
#   '45',
#   '34',
#   '26',
#   '27',
#   '31',
#   '35',
#   '24',
#   '30',
#   '27',
#   '23',
#   '18',
#   '15'),
#  ('2013/06/24',
#   '大里',
#   'PM2.5',
#   '25',
#   '23',
#   '21',
#   '8',
#   '4',
#   '5',
#   '9',
#   '15',
#   '16',
#   '20',
#   '26',
#   '20',
#   '20',
#   '20',
#   '26',
#   '30',
#   '21',
#   '17',
#   '11',
#   '15',
#   '22',
#   '23',
#   '14',
#   '11'),
#  ('2013/06/26',
#   '大里',
#   'PM2.5',
#   '22',
#   '20',
#   '23',
#   '22',
#   '26',
#   '30',
#   '31',
#   '26',
#   '26',
#   '31',
#   '35',
#   '40',
#   '46',
#   '55',
#   '55',
#   '35',
#   '38',
#   '55',
#   '50',
#   '47',
#   '42',
#   '41',
#   '40',
#   '38'),
#  ('2013/06/27',
#   '大里',
#   'PM2.5',
#   '36',
#   '31',
#   '32',
#   '36',
#   '36',
#   '35',
#   '28',
#   '25',
#   '20',
#   '26',
#   '34',
#   '41',
#   '35',
#   '36',
#   '33',
#   '38',
#   '33',
#   '34',
#   '39',
#   '46',
#   '45',
#   '36',
#   '32',
#   '35'),
#  ('2013/06/28',
#   '大里',
#   'PM2.5',
#   '37',
#   '35',
#   '27',
#   '22',
#   '24',
#   '27',
#   '28',
#   '15',
#   '9',
#   '19',
#   '28',
#   '47',
#   '37',
#   '47',
#   '43',
#   '54',
#   '47',
#   '43',
#   '42',
#   '40',
#   '40',
#   '41',
#   '44',
#   '44'),
#  ('2013/06/29',
#   '大里',
#   'PM2.5',
#   '37',
#   '33',
#   '29',
#   '27',
#   '24',
#   '22',
#   '20',
#   '32',
#   '36',
#   '39',
#   '31',
#   '26',
#   '30',
#   '32',
#   '45',
#   '49',
#   '54',
#   '47',
#   '48',
#   '51',
#   '56',
#   '54',
#   '58',
#   '74'),
#  ('2013/06/30',
#   '大里',
#   'PM2.5',
#   '80',
#   '73',
#   '59',
#   '44',
#   '41',
#   '36',
#   '42',
#   '41',
#   '41',
#   '41',
#   '44',
#   '54',
#   '56',
#   '62',
#   '51',
#   '48',
#   '45',
#   '38',
#   '32',
#   '30',
#   '40',
#   '37',
#   '38',
#   '30'),
#  ('2013/07/04',
#   '大里',
#   'PM2.5',
#   '8',
#   '10',
#   '12',
#   '14',
#   '7',
#   '8',
#   '5',
#   '8',
#   '10',
#   '22',
#   '31',
#   '26',
#   '27',
#   '31',
#   '50',
#   '50',
#   '46',
#   '35',
#   '22',
#   '17',
#   '17',
#   '21',
#   '19',
#   '18'),
#  ('2013/07/06',
#   '大里',
#   'PM2.5',
#   '9',
#   '2',
#   '6',
#   '8',
#   '7',
#   '4',
#   '2',
#   '4',
#   '8',
#   '10',
#   '14',
#   '11',
#   '17',
#   '17',
#   '16',
#   '9',
#   '16',
#   '17',
#   '17',
#   '14',
#   '14',
#   '20',
#   '21',
#   '17'),
#  ('2013/07/12',
#   '大里',
#   'PM2.5',
#   '34',
#   '41',
#   '32',
#   '36',
#   '27',
#   '26',
#   '31',
#   '37',
#   '41',
#   '43',
#   '52',
#   '56',
#   '49',
#   '41',
#   '32',
#   '31',
#   '15',
#   '13',
#   '15',
#   '15',
#   '10',
#   '15',
#   '11',
#   '8'),
#  ('2013/07/13',
#   '大里',
#   'PM2.5',
#   '11',
#   '11',
#   '8',
#   '5',
#   '6',
#   '7',
#   '3',
#   '7',
#   '9',
#   '19',
#   '14',
#   '15',
#   '14',
#   '18',
#   '25',
#   '23',
#   '31',
#   '26',
#   '22',
#   '17',
#   '13',
#   '20',
#   '15',
#   '17'),
#  ('2013/07/16',
#   '大里',
#   'PM2.5',
#   '19',
#   '6',
#   '5',
#   '5',
#   '6',
#   '6',
#   '8',
#   '7',
#   '6',
#   '5',
#   '17',
#   '28',
#   '39',
#   '30',
#   '25',
#   '14',
#   '15',
#   '11',
#   '12',
#   '14',
#   '17',
#   '17',
#   '16',
#   '15'),
#  ('2013/07/17',
#   '大里',
#   'PM2.5',
#   '18',
#   '17',
#   '15',
#   '11',
#   '12',
#   '7',
#   '7',
#   '5',
#   '5',
#   '5',
#   '13',
#   '23',
#   '36',
#   '33',
#   '31',
#   '20',
#   '22',
#   '22',
#   '20',
#   '14',
#   '17',
#   '19',
#   '26',
#   '23'),
#  ('2013/07/19',
#   '大里',
#   'PM2.5',
#   '29',
#   '21',
#   '19',
#   '25',
#   '20',
#   '17',
#   '10',
#   '19',
#   '15',
#   '20',
#   '22',
#   '37',
#   '48',
#   '67',
#   '50',
#   '15',
#   '19',
#   '34',
#   '28',
#   '31',
#   '30',
#   '34',
#   '33',
#   '31'),
#  ('2013/07/20',
#   '大里',
#   'PM2.5',
#   '33',
#   '37',
#   '41',
#   '41',
#   '31',
#   '26',
#   '30',
#   '31',
#   '38',
#   '36',
#   '49',
#   '50',
#   '54',
#   '62',
#   '54',
#   '50',
#   '35',
#   '31',
#   '33',
#   '32',
#   '40',
#   '48',
#   '58',
#   '57'),
#  ('2013/07/23',
#   '大里',
#   'PM2.5',
#   '45',
#   '46',
#   '47',
#   '48',
#   '51',
#   '52',
#   '51',
#   '47',
#   '43',
#   '48',
#   '51',
#   '51',
#   '59',
#   '51',
#   '52',
#   '38',
#   '41',
#   '33',
#   '28',
#   '25',
#   '22',
#   '37',
#   '42',
#   '53'),
#  ('2013/07/24',
#   '大里',
#   'PM2.5',
#   '41',
#   '40',
#   '29',
#   '35',
#   '35',
#   '37',
#   '36',
#   '32',
#   '33',
#   '42',
#   '38',
#   '29',
#   '27',
#   '39',
#   '63',
#   '68',
#   '51',
#   '44',
#   '27',
#   '23',
#   '13',
#   '12',
#   '16',
#   '18'),
#  ('2013/07/25',
#   '大里',
#   'PM2.5',
#   '14',
#   '10',
#   '3',
#   '2',
#   '4',
#   '2',
#   '7',
#   '11',
#   '16',
#   '18',
#   '14',
#   '9',
#   '15',
#   '13',
#   '15',
#   '14',
#   '9',
#   '18',
#   '13',
#   '20',
#   '20',
#   '15',
#   '13',
#   '4'),
#  ('2013/07/27',
#   '大里',
#   'PM2.5',
#   '9',
#   '11',
#   '9',
#   '9',
#   '7',
#   '15',
#   '14',
#   '15',
#   '5',
#   '15',
#   '13',
#   '23',
#   '22',
#   '18',
#   '17',
#   '18',
#   '31',
#   '27',
#   '19',
#   '15',
#   '19',
#   '25',
#   '17',
#   '15'),
#  ('2013/07/30',
#   '大里',
#   'PM2.5',
#   '29',
#   '23',
#   '19',
#   '12',
#   '10',
#   '16',
#   '13',
#   '19',
#   '9',
#   '23',
#   '39',
#   '54',
#   '50',
#   '40',
#   '36',
#   '35',
#   '35',
#   '36',
#   '31',
#   '23',
#   '11',
#   '9',
#   '14',
#   '18'),
#  ('2013/08/01',
#   '大里',
#   'PM2.5',
#   '24',
#   '19',
#   '11',
#   '8',
#   '4',
#   '8',
#   '9',
#   '12',
#   '19',
#   '25',
#   '27',
#   '27',
#   '41',
#   '36',
#   '29',
#   '15',
#   '21',
#   '26',
#   '29',
#   '31',
#   '45',
#   '48',
#   '57',
#   '48'),
#  ('2013/08/02',
#   '大里',
#   'PM2.5',
#   '50',
#   '44',
#   '33',
#   '22',
#   '19',
#   '20',
#   '16',
#   '10',
#   '16',
#   '23',
#   '26',
#   '30',
#   '37',
#   '36',
#   '30',
#   '26',
#   '26',
#   '27',
#   '21',
#   '19',
#   '15',
#   '9',
#   '12',
#   '10'),
#  ('2013/08/04',
#   '大里',
#   'PM2.5',
#   '27',
#   '21',
#   '23',
#   '29',
#   '28',
#   '23',
#   '15',
#   '18',
#   '29',
#   '37',
#   '48',
#   '32',
#   '43',
#   '37',
#   '47',
#   '44',
#   '33',
#   '33',
#   '21',
#   '25',
#   '16',
#   '17',
#   '21',
#   '30'),
#  ('2013/08/06',
#   '大里',
#   'PM2.5',
#   '27',
#   '28',
#   '16',
#   '12',
#   '20',
#   '25',
#   '29',
#   '23',
#   '20',
#   '19',
#   '28',
#   '33',
#   '35',
#   '26',
#   '30',
#   '29',
#   '20',
#   '31',
#   '43',
#   '38',
#   '34',
#   '36',
#   '36',
#   '35'),
#  ('2013/08/07',
#   '大里',
#   'PM2.5',
#   '29',
#   '31',
#   '32',
#   '30',
#   '25',
#   '17',
#   '20',
#   '20',
#   '27',
#   '26',
#   '31',
#   '35',
#   '47',
#   '42',
#   '36',
#   '30',
#   '26',
#   '25',
#   '23',
#   '27',
#   '16',
#   '19',
#   '15',
#   '18'),
#  ('2013/08/09',
#   '大里',
#   'PM2.5',
#   '26',
#   '26',
#   '19',
#   '13',
#   '9',
#   '16',
#   '10',
#   '13',
#   '19',
#   '16',
#   '23',
#   '15',
#   '21',
#   '21',
#   '24',
#   '16',
#   '20',
#   '19',
#   '15',
#   '20',
#   '22',
#   '32',
#   '30',
#   '27'),
#  ('2013/08/10',
#   '大里',
#   'PM2.5',
#   '16',
#   '17',
#   '20',
#   '25',
#   '23',
#   '17',
#   '15',
#   '18',
#   '17',
#   '26',
#   '27',
#   '39',
#   '30',
#   '37',
#   '31',
#   '39',
#   '31',
#   '28',
#   '27',
#   '19',
#   '22',
#   '16',
#   '26',
#   '26'),
#  ('2013/08/11',
#   '大里',
#   'PM2.5',
#   '24',
#   '20',
#   '17',
#   '10',
#   '15',
#   '13',
#   '20',
#   '21',
#   '15',
#   '19',
#   '14',
#   '26',
#   '22',
#   '28',
#   '22',
#   '18',
#   '17',
#   '15',
#   '20',
#   '20',
#   '29',
#   '32',
#   '31',
#   '34'),
#  ('2013/08/12',
#   '大里',
#   'PM2.5',
#   '43',
#   '44',
#   '40',
#   '26',
#   '25',
#   '21',
#   '26',
#   '25',
#   '26',
#   '31',
#   '42',
#   '51',
#   '48',
#   '36',
#   '35',
#   '30',
#   '34',
#   '35',
#   '43',
#   '42',
#   '42',
#   '46',
#   '54',
#   '55'),
#  ('2013/08/13',
#   '大里',
#   'PM2.5',
#   '51',
#   '41',
#   '38',
#   '36',
#   '45',
#   '42',
#   '46',
#   '42',
#   '49',
#   '53',
#   '55',
#   '47',
#   '41',
#   '43',
#   '47',
#   '40',
#   '30',
#   '28',
#   '34',
#   '36',
#   '44',
#   '44',
#   '42',
#   '38'),
#  ('2013/08/15',
#   '大里',
#   'PM2.5',
#   '11',
#   '8',
#   '12',
#   '6',
#   '5',
#   '5',
#   '6',
#   '13',
#   '7',
#   '15',
#   '18',
#   '23',
#   '20',
#   '13',
#   '17',
#   '14',
#   '9',
#   '15',
#   '19',
#   '20',
#   '20',
#   '18',
#   '16',
#   '18'),
#  ('2013/08/16',
#   '大里',
#   'PM2.5',
#   '12',
#   '13',
#   '11',
#   '16',
#   '9',
#   '4',
#   '11',
#   '14',
#   '26',
#   '21',
#   '31',
#   '28',
#   '31',
#   '30',
#   '35',
#   '34',
#   '31',
#   '26',
#   '26',
#   '24',
#   '19',
#   '22',
#   '24',
#   '34'),
#  ('2013/08/17',
#   '大里',
#   'PM2.5',
#   '26',
#   '17',
#   '19',
#   '22',
#   '31',
#   '23',
#   '20',
#   '8',
#   '12',
#   '15',
#   '25',
#   '26',
#   '30',
#   '28',
#   '24',
#   '19',
#   '23',
#   '20',
#   '25',
#   '20',
#   '27',
#   '35',
#   '33',
#   '38'),
#  ('2013/08/18',
#   '大里',
#   'PM2.5',
#   '29',
#   '29',
#   '27',
#   '31',
#   '30',
#   '30',
#   '27',
#   '37',
#   '38',
#   '39',
#   '36',
#   '45',
#   '41',
#   '42',
#   '35',
#   '30',
#   '17',
#   '11',
#   '8',
#   '18',
#   '22',
#   '30',
#   '31',
#   '27'),
#  ('2013/08/19',
#   '大里',
#   'PM2.5',
#   '23',
#   '17',
#   '23',
#   '21',
#   '24',
#   '19',
#   '24',
#   '26',
#   '25',
#   '24',
#   '22',
#   '23',
#   '21',
#   '26',
#   '25',
#   '29',
#   '28',
#   '26',
#   '23',
#   '16',
#   '25',
#   '25',
#   '29',
#   '23'),
#  ('2013/08/20',
#   '大里',
#   'PM2.5',
#   '26',
#   '21',
#   '25',
#   '14',
#   '8',
#   '8',
#   '21',
#   '30',
#   '26',
#   '21',
#   '18',
#   '26',
#   '22',
#   '23',
#   '20',
#   '19',
#   '14',
#   '9',
#   '11',
#   '9',
#   '13',
#   '9',
#   '11',
#   '10'),
#  ('2013/08/25',
#   '大里',
#   'PM2.5',
#   '11',
#   '15',
#   '14',
#   '9',
#   '12',
#   '8',
#   '11',
#   '11',
#   '14',
#   '16',
#   '16',
#   '25',
#   '24',
#   '33',
#   '22',
#   '18',
#   '13',
#   '17',
#   '14',
#   '10',
#   '13',
#   '18',
#   '21',
#   '18'),
#  ('2013/08/26',
#   '大里',
#   'PM2.5',
#   '19',
#   '11',
#   '16',
#   '13',
#   '17',
#   '14',
#   '15',
#   '15',
#   '16',
#   '23',
#   '41',
#   '35',
#   '39',
#   '30',
#   '29',
#   '23',
#   '10',
#   '14',
#   '9',
#   '15',
#   '15',
#   '17',
#   '13',
#   '15'),
#  ('2013/08/28',
#   '大里',
#   'PM2.5',
#   '30',
#   '27',
#   '20',
#   '21',
#   '24',
#   '23',
#   '24',
#   '24',
#   '31',
#   '38',
#   '43',
#   '48',
#   '47',
#   '37',
#   '35',
#   '21',
#   '18',
#   '24',
#   '32',
#   '41',
#   '48',
#   '42',
#   '39',
#   '33'),
#  ('2013/08/29',
#   '大里',
#   'PM2.5',
#   '34',
#   '26',
#   '30',
#   '27',
#   '23',
#   '18',
#   '10',
#   '12',
#   '9',
#   '10',
#   '16',
#   '12',
#   '15',
#   '11',
#   '10',
#   '9',
#   '12',
#   '12',
#   '8',
#   '6',
#   '10',
#   '15',
#   '13',
#   '15'),
#  ('2013/08/31',
#   '大里',
#   'PM2.5',
#   '11',
#   '13',
#   '10',
#   '6',
#   '2',
#   '5',
#   '6',
#   '8',
#   '3',
#   '6',
#   '7',
#   '16',
#   '10',
#   '6',
#   '1',
#   '5',
#   '9',
#   '9',
#   '15',
#   '20',
#   '20',
#   '15',
#   '11',
#   '11'),
#  ('2013/09/01',
#   '大里',
#   'PM2.5',
#   '14',
#   '9',
#   '11',
#   '5',
#   '6',
#   '4',
#   '13',
#   '20',
#   '22',
#   '18',
#   '15',
#   '20',
#   '18',
#   '21',
#   '17',
#   '17',
#   '13',
#   '15',
#   '21',
#   '19',
#   '21',
#   '21',
#   '30',
#   '29'),
#  ('2013/09/02',
#   '大里',
#   'PM2.5',
#   '27',
#   '20',
#   '21',
#   '20',
#   '22',
#   '21',
#   '15',
#   '15',
#   '13',
#   '18',
#   '21',
#   '30',
#   '40',
#   '44',
#   '47',
#   '42',
#   '45',
#   '42',
#   '48',
#   '57',
#   '58',
#   '62',
#   '51',
#   '51'),
#  ('2013/09/03',
#   '大里',
#   'PM2.5',
#   '44',
#   '40',
#   '37',
#   '40',
#   '34',
#   '37',
#   '28',
#   '32',
#   '35',
#   '40',
#   '48',
#   '45',
#   '46',
#   '41',
#   '44',
#   '46',
#   '44',
#   '44',
#   '44',
#   '44',
#   '41',
#   '42',
#   '51',
#   '58'),
#  ('2013/09/04',
#   '大里',
#   'PM2.5',
#   '57',
#   '50',
#   '44',
#   '46',
#   '48',
#   '52',
#   '54',
#   '51',
#   '55',
#   '58',
#   '73',
#   '71',
#   '67',
#   '57',
#   '50',
#   '52',
#   '47',
#   '42',
#   '30',
#   '24',
#   '24',
#   '32',
#   '48',
#   '47'),
#  ('2013/09/06',
#   '大里',
#   'PM2.5',
#   '48',
#   '47',
#   '53',
#   '52',
#   '52',
#   '46',
#   '45',
#   '48',
#   '55',
#   '72',
#   '77',
#   '84',
#   '73',
#   '68',
#   '54',
#   '38',
#   '36',
#   '30',
#   '36',
#   '26',
#   '28',
#   '24',
#   '30',
#   '30'),
#  ('2013/09/07',
#   '大里',
#   'PM2.5',
#   '30',
#   '24',
#   '29',
#   '28',
#   '39',
#   '39',
#   '44',
#   '42',
#   '41',
#   '51',
#   '64',
#   '70',
#   '69',
#   '75',
#   '85',
#   '88',
#   '66',
#   '43',
#   '32',
#   '21',
#   '26',
#   '18',
#   '25',
#   '30'),
#  ('2013/09/09',
#   '大里',
#   'PM2.5',
#   '53',
#   '51',
#   '55',
#   '52',
#   '58',
#   '55',
#   '53',
#   '53',
#   '46',
#   '55',
#   '62',
#   '75',
#   '82',
#   '76',
#   '87',
#   '69',
#   '64',
#   '50',
#   '47',
#   '42',
#   '40',
#   '41',
#   '41',
#   '40'),
#  ...)
