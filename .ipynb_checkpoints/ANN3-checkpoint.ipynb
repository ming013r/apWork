# %%
import numpy as np
import math
import matplotlib.pyplot as plt  
from sklearn.metrics import mean_squared_error
import pandas as pd

from keras.layers import Dropout
from keras.layers import Dense,Input
from keras.models import Sequential,Model
from keras.callbacks import EarlyStopping
import numpy

import sys
import xlwt
##get data##
import MySQLdb
from sklearn.preprocessing import MinMaxScaler


def transfromData(trainRaw, testRaw,windosSize):  ##Train ratial, train, test
    sc = MinMaxScaler(feature_range = (0, 1))
    #npRaw = np.array(rawData)
    #scaledData = sc.fit_transform(npRaw.reshape(-1,1))  
    #trainData = np.array(scaledData[:trainCount]).reshape(-1,1)##train 
    #testData = np.array(scaledData[-testCount:]).reshape(-1,1)
    
    npTrain = sc.fit_transform(np.array(trainRaw).reshape(-1,1))
    npTest = sc.fit_transform(np.array(trainRaw).reshape(-1,1))
    

    X_train, y_train = splitXy(npTrain,windosSize)
    X_test, y_test = splitXy(npTest,windosSize)
    return sc, X_train, y_train, X_test, y_test

def splitXy(data,windosSize):
    windows = []
    for i in range(windosSize, data.shape[0]):
        windows.append(data[i-windosSize:i, 0])
    np.random.shuffle(windows)
    X = []
    y = []
    for i in range(len(windows)):
        X.append(windows[i][:windosSize-1])
        y.append(windows[i][-1:])
    X, y = np.array(X), np.array(y)
    #X = np.reshape(X, (X.shape[0], X.shape[1], 1))
    return X,y
def buildModel(shape):
    dnn_1_input = Input(shape=(shape,),name='dnn_1_input')
    dnn_1 = Dense(128,activation="tanh", name='dnn_1')(dnn_1_input)
    dnn_2 = Dense(64,activation="tanh", name='dnn_2')(dnn_1)
    dnn_3 = Dense(32,activation="tanh", name='dnn_3')(dnn_2)
    dnn_4 = Dense(1, activation='tanh', name='dnn_4')(dnn_3)

    model = Model(dnn_1_input,dnn_4)
    model.summary()
    model.compile(loss='mse',
                  optimizer='adam')
    return model
def getStationList(cursor):
    stationList = []
    queryString = "SELECT distinct station from cleandata"
    cursor.execute(queryString)
    results = cursor.fetchall()
    for row in results :
        val = str(row).strip("',()")
        stationList.append(val)
    stationList.remove('富貴角')##only 106少數資料
    return stationList
def Visualize():
    predicted = sc.inverse_transform(regressor.predict(X_test))
    originY = sc.inverse_transform (y_test)
    print("MSE : ["+str(mean_squared_error(predicted, originY))+"]")
    # Visualising the results
    plt.plot(originY[:100], color = 'red', label = 'Real')  
    plt.plot(predicted[:100], color = 'blue', label = 'Predicted ') 
    plt.legend()
    plt.show()
def writeExcelHead(sheet1,epochs,station):
    sheet1.write(0,1,station)
    raw = 1
    for e in range(epochs):
        sheet1.write(raw,0,e+1)
        raw+=1


def fetchData(cursor,station,windosSize):
    queryString = "SELECT * from cleandata where station='"+station+"' and item = 'PM2.5' and date NOT like '2017%'"
    cursor.execute(queryString)
    results = cursor.fetchall()

    trainRawData = []
    for row in results:
        for i in range(3,27):
            trainRawData.append(float(row[i]))
            
    queryString = "SELECT * from cleandata where station='"+station+"' and item = 'PM2.5' and date like '2017%'"
    cursor.execute(queryString)
    results = cursor.fetchall()

    testRawData = []
    for row in results:
        for i in range(3,27):
            testRawData.append(float(row[i]))

    sc, X_train, y_train, X_test, y_test = transfromData(trainRawData,testRawData,windosSize)
    return sc, X_train, y_train, X_test, y_test
def train(regressor,sc, X_train, y_train, X_test, y_test,epochs):
 
    for i in range(epochs):
        regressor.fit(X_train, y_train,validation_split=0.2, epochs = 1, batch_size = 32,verbose=2)
        predicted = sc.inverse_transform(regressor.predict(X_test))
        originY = sc.inverse_transform (y_test)
        mse = mean_squared_error(predicted, originY)
        print("Epoch : " +str(i+1)+", MSE : ["+str(mse)+"]")
        print('-------------------------------------------')
    return mse

# %%
import datetime
db=MySQLdb.connect(host="localhost",user="root", passwd="swater0", db="airdb", charset="utf8")
cursor = db.cursor()

epochs = 200
stationList = getStationList(cursor)
col=1

for station in stationList:
    print("training : " +station)
    MSEs = []
    for windowSize in range(2,22):
        sc, X_train, y_train, X_test, y_test = fetchData(cursor,station,windowSize)
        regressor = buildModel(windowSize-1)
        mse = train(regressor,sc,X_train, y_train, X_test, y_test,epochs)
        MSEs.append(mse)
    print('check point at ' + str(datetime.datetime.now()))
    
    book = xlwt.Workbook(encoding="utf-8")
    sheet1 = book.add_sheet("Sheet1")
    writeExcelHead(sheet1,epochs,station)
    row = 1
    for m in MSEs:
        sheet1.write(row,1,m)
        row+=1
    book.save("excelFiles/ANN/ANNresult"+station+".xls")
        
    

db.close()
# Out:
# training : 二林
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dnn_1_input (InputLayer)     (None, 1)                 0
# _________________________________________________________________
# dnn_1 (Dense)                (None, 128)               256
# _________________________________________________________________
# dnn_2 (Dense)                (None, 64)                8256
# _________________________________________________________________
# dnn_3 (Dense)                (None, 32)                2080
# _________________________________________________________________
# dnn_4 (Dense)                (None, 1)                 33
# =================================================================
# Total params: 10,625
# Trainable params: 10,625
# Non-trainable params: 0
# _________________________________________________________________
# Train on 17144 samples, validate on 4286 samples
# Epoch 1/1
#  - 1s - loss: 9.9584e-04 - val_loss: 8.0485e-04
# Epoch : 1, MSE : [50.32254148128187]
# -------------------------------------------
# Train on 17144 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 9.0269e-04 - val_loss: 7.9980e-04
# Epoch : 2, MSE : [49.99400627396333]
# -------------------------------------------
# Train on 17144 samples, validate on 4286 samples
# Epoch 1/1
#  - 1s - loss: 8.9712e-04 - val_loss: 8.3003e-04
# Epoch : 3, MSE : [51.33902246515643]
# -------------------------------------------
# Train on 17144 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 9.1249e-04 - val_loss: 7.8204e-04
# Epoch : 4, MSE : [48.63281330887965]
# -------------------------------------------
# Train on 17144 samples, validate on 4286 samples
# Epoch 1/1
#  - 1s - loss: 8.9668e-04 - val_loss: 7.6289e-04
# Epoch : 5, MSE : [47.88282986611613]
# -------------------------------------------
# Train on 17144 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 8.9861e-04 - val_loss: 8.7677e-04
# Epoch : 6, MSE : [54.55083279595855]
# -------------------------------------------
# Train on 17144 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 8.9865e-04 - val_loss: 7.7362e-04
# Epoch : 7, MSE : [48.25771587080674]
# -------------------------------------------
# Train on 17144 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 8.9553e-04 - val_loss: 7.6767e-04
# Epoch : 8, MSE : [47.85005933501508]
# -------------------------------------------
# Train on 17144 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 8.8640e-04 - val_loss: 7.5755e-04
# Epoch : 9, MSE : [47.35454269166783]
# -------------------------------------------
# Train on 17144 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 8.9530e-04 - val_loss: 8.1597e-04
# Epoch : 10, MSE : [50.36418580491046]
# -------------------------------------------
# Train on 17144 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 8.9921e-04 - val_loss: 7.6312e-04
# Epoch : 11, MSE : [47.7056932797725]
# -------------------------------------------
# Train on 17144 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 8.9373e-04 - val_loss: 7.6865e-04
# Epoch : 12, MSE : [47.8781141898595]
# -------------------------------------------
# Train on 17144 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 8.8393e-04 - val_loss: 7.6120e-04
# Epoch : 13, MSE : [47.58885586876777]
# -------------------------------------------
# Train on 17144 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 8.9100e-04 - val_loss: 8.6894e-04
# Epoch : 14, MSE : [53.477768125689735]
# -------------------------------------------
# Train on 17144 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 8.8238e-04 - val_loss: 7.7447e-04
# Epoch : 15, MSE : [48.48957957117438]
# -------------------------------------------
# Train on 17144 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 8.8881e-04 - val_loss: 7.8155e-04
# Epoch : 16, MSE : [48.7721867019185]
# -------------------------------------------
# Train on 17144 samples, validate on 4286 samples
# Epoch 1/1
#  - 1s - loss: 8.7729e-04 - val_loss: 7.7355e-04
# Epoch : 17, MSE : [48.1468079644201]
# -------------------------------------------
# Train on 17144 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 8.8819e-04 - val_loss: 8.2302e-04
# Epoch : 18, MSE : [51.09512318721854]
# -------------------------------------------
# Train on 17144 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 8.8764e-04 - val_loss: 8.2669e-04
# Epoch : 19, MSE : [51.23780323474584]
# -------------------------------------------
# Train on 17144 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 8.8802e-04 - val_loss: 7.7973e-04
# Epoch : 20, MSE : [48.42288431754342]
# -------------------------------------------
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dnn_1_input (InputLayer)     (None, 2)                 0
# _________________________________________________________________
# dnn_1 (Dense)                (None, 128)               384
# _________________________________________________________________
# dnn_2 (Dense)                (None, 64)                8256
# _________________________________________________________________
# dnn_3 (Dense)                (None, 32)                2080
# _________________________________________________________________
# dnn_4 (Dense)                (None, 1)                 33
# =================================================================
# Total params: 10,753
# Trainable params: 10,753
# Non-trainable params: 0
# _________________________________________________________________
# Train on 17143 samples, validate on 4286 samples
# Epoch 1/1
#  - 1s - loss: 0.0011 - val_loss: 9.5570e-04
# Epoch : 1, MSE : [57.16363344128257]
# -------------------------------------------
# Train on 17143 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 8.9016e-04 - val_loss: 8.3817e-04
# Epoch : 2, MSE : [50.886511033286055]
# -------------------------------------------
# Train on 17143 samples, validate on 4286 samples
# Epoch 1/1
#  - 1s - loss: 8.7574e-04 - val_loss: 7.5093e-04
# Epoch : 3, MSE : [45.802721982887626]
# -------------------------------------------
# Train on 17143 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 8.6383e-04 - val_loss: 9.2977e-04
# Epoch : 4, MSE : [55.68240790881695]
# -------------------------------------------
# Train on 17143 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 8.7980e-04 - val_loss: 7.5220e-04
# Epoch : 5, MSE : [45.94707775915024]
# -------------------------------------------
# Train on 17143 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 8.6725e-04 - val_loss: 7.7592e-04
# Epoch : 6, MSE : [47.10499782941206]
# -------------------------------------------
# Train on 17143 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 8.5445e-04 - val_loss: 8.0556e-04
# Epoch : 7, MSE : [49.14803233284525]
# -------------------------------------------
# Train on 17143 samples, validate on 4286 samples
# Epoch 1/1
#  - 1s - loss: 8.7721e-04 - val_loss: 7.5576e-04
# Epoch : 8, MSE : [46.09514023215448]
# -------------------------------------------
# Train on 17143 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 8.6603e-04 - val_loss: 7.7514e-04
# Epoch : 9, MSE : [47.206257831828324]
# -------------------------------------------
# Train on 17143 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 8.6429e-04 - val_loss: 7.7144e-04
# Epoch : 10, MSE : [46.87635208561921]
# -------------------------------------------
# Train on 17143 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 8.7883e-04 - val_loss: 8.2519e-04
# Epoch : 11, MSE : [50.40826623484383]
# -------------------------------------------
# Train on 17143 samples, validate on 4286 samples
# Epoch 1/1
#  - 1s - loss: 8.6197e-04 - val_loss: 7.6157e-04
# Epoch : 12, MSE : [46.544014438806386]
# -------------------------------------------
# Train on 17143 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 8.5529e-04 - val_loss: 8.2960e-04
# Epoch : 13, MSE : [50.7398895667149]
# -------------------------------------------
# Train on 17143 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 8.6865e-04 - val_loss: 7.8579e-04
# Epoch : 14, MSE : [47.723096592745655]
# -------------------------------------------
# Train on 17143 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 8.6633e-04 - val_loss: 7.5440e-04
# Epoch : 15, MSE : [46.121649150773315]
# -------------------------------------------
# Train on 17143 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 8.6091e-04 - val_loss: 7.5089e-04
# Epoch : 16, MSE : [45.81033228240025]
# -------------------------------------------
# Train on 17143 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 8.6052e-04 - val_loss: 7.7153e-04
# Epoch : 17, MSE : [46.9235245001216]
# -------------------------------------------
# Train on 17143 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 8.5439e-04 - val_loss: 7.4814e-04
# Epoch : 18, MSE : [45.71168946283388]
# -------------------------------------------
# Train on 17143 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 8.5680e-04 - val_loss: 7.7344e-04
# Epoch : 19, MSE : [47.390951118601095]
# -------------------------------------------
# Train on 17143 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 8.6767e-04 - val_loss: 7.6468e-04
# Epoch : 20, MSE : [46.772053078635516]
# -------------------------------------------
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dnn_1_input (InputLayer)     (None, 3)                 0
# _________________________________________________________________
# dnn_1 (Dense)                (None, 128)               512
# _________________________________________________________________
# dnn_2 (Dense)                (None, 64)                8256
# _________________________________________________________________
# dnn_3 (Dense)                (None, 32)                2080
# _________________________________________________________________
# dnn_4 (Dense)                (None, 1)                 33
# =================================================================
# Total params: 10,881
# Trainable params: 10,881
# Non-trainable params: 0
# _________________________________________________________________
# Train on 17142 samples, validate on 4286 samples
# Epoch 1/1
#  - 1s - loss: 9.8785e-04 - val_loss: 7.3676e-04
# Epoch : 1, MSE : [47.17889978521445]
# -------------------------------------------
# Train on 17142 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 8.9053e-04 - val_loss: 9.9406e-04
# Epoch : 2, MSE : [62.53618676401221]
# -------------------------------------------
# Train on 17142 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 8.8090e-04 - val_loss: 7.0689e-04
# Epoch : 3, MSE : [45.0368350680707]
# -------------------------------------------
# Train on 17142 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 8.7806e-04 - val_loss: 7.0735e-04
# Epoch : 4, MSE : [45.38667673701437]
# -------------------------------------------
# Train on 17142 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 8.6190e-04 - val_loss: 9.1960e-04
# Epoch : 5, MSE : [58.77281152528589]
# -------------------------------------------
# Train on 17142 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 8.8000e-04 - val_loss: 7.2721e-04
# Epoch : 6, MSE : [46.19673380701201]
# -------------------------------------------
# Train on 17142 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 8.6696e-04 - val_loss: 7.6288e-04
# Epoch : 7, MSE : [48.62786836006218]
# -------------------------------------------
# Train on 17142 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 8.5817e-04 - val_loss: 7.0604e-04
# Epoch : 8, MSE : [45.47827716284506]
# -------------------------------------------
# Train on 17142 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 8.6738e-04 - val_loss: 7.4735e-04
# Epoch : 9, MSE : [47.022561206381724]
# -------------------------------------------
# Train on 17142 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 8.5994e-04 - val_loss: 7.4469e-04
# Epoch : 10, MSE : [48.0177685778573]
# -------------------------------------------
# Train on 17142 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 8.5586e-04 - val_loss: 7.5899e-04
# Epoch : 11, MSE : [48.497263784659]
# -------------------------------------------
# Train on 17142 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 8.6181e-04 - val_loss: 7.2408e-04
# Epoch : 12, MSE : [45.56404079382775]
# -------------------------------------------
# Train on 17142 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 8.5616e-04 - val_loss: 7.0852e-04
# Epoch : 13, MSE : [44.97081428332052]
# -------------------------------------------
# Train on 17142 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 8.5285e-04 - val_loss: 7.0701e-04
# Epoch : 14, MSE : [44.800390294387675]
# -------------------------------------------
# Train on 17142 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 8.5869e-04 - val_loss: 7.4641e-04
# Epoch : 15, MSE : [46.72020454492878]
# -------------------------------------------
# Train on 17142 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 8.4417e-04 - val_loss: 7.2573e-04
# Epoch : 16, MSE : [45.63810129591726]
# -------------------------------------------
# Train on 17142 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 8.4420e-04 - val_loss: 7.5177e-04
# Epoch : 17, MSE : [46.56576604281581]
# -------------------------------------------
# Train on 17142 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 8.4926e-04 - val_loss: 7.2912e-04
# Epoch : 18, MSE : [45.45871373149604]
# -------------------------------------------
# Train on 17142 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 8.4341e-04 - val_loss: 7.1541e-04
# Epoch : 19, MSE : [44.85286565036336]
# -------------------------------------------
# Train on 17142 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 8.4393e-04 - val_loss: 7.4362e-04
# Epoch : 20, MSE : [47.83681570615608]
# -------------------------------------------
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dnn_1_input (InputLayer)     (None, 4)                 0
# _________________________________________________________________
# dnn_1 (Dense)                (None, 128)               640
# _________________________________________________________________
# dnn_2 (Dense)                (None, 64)                8256
# _________________________________________________________________
# dnn_3 (Dense)                (None, 32)                2080
# _________________________________________________________________
# dnn_4 (Dense)                (None, 1)                 33
# =================================================================
# Total params: 11,009
# Trainable params: 11,009
# Non-trainable params: 0
# _________________________________________________________________
# Train on 17141 samples, validate on 4286 samples
# Epoch 1/1
#  - 1s - loss: 9.8770e-04 - val_loss: 0.0011
# Epoch : 1, MSE : [60.03521470099605]
# -------------------------------------------
# Train on 17141 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 8.4655e-04 - val_loss: 9.8725e-04
# Epoch : 2, MSE : [54.525528675343296]
# -------------------------------------------
# Train on 17141 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 8.0889e-04 - val_loss: 7.8463e-04
# Epoch : 3, MSE : [42.94150692835604]
# -------------------------------------------
# Train on 17141 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 7.9762e-04 - val_loss: 8.7670e-04
# Epoch : 4, MSE : [48.26571224353041]
# -------------------------------------------
# Train on 17141 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 8.0302e-04 - val_loss: 7.7522e-04
# Epoch : 5, MSE : [42.81896267644414]
# -------------------------------------------
# Train on 17141 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 7.8771e-04 - val_loss: 7.7394e-04
# Epoch : 6, MSE : [42.10926771545217]
# -------------------------------------------
# Train on 17141 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 8.0121e-04 - val_loss: 7.7842e-04
# Epoch : 7, MSE : [42.77504731028633]
# -------------------------------------------
# Train on 17141 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 7.8616e-04 - val_loss: 7.5648e-04
# Epoch : 8, MSE : [41.63962655130166]
# -------------------------------------------
# Train on 17141 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 7.8484e-04 - val_loss: 8.3721e-04
# Epoch : 9, MSE : [45.87818402943223]
# -------------------------------------------
# Train on 17141 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 7.7705e-04 - val_loss: 7.7994e-04
# Epoch : 10, MSE : [42.619383102888094]
# -------------------------------------------
# Train on 17141 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 8.0460e-04 - val_loss: 8.6551e-04
# Epoch : 11, MSE : [47.88341180637682]
# -------------------------------------------
# Train on 17141 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 7.7633e-04 - val_loss: 8.1293e-04
# Epoch : 12, MSE : [45.24787707789374]
# -------------------------------------------
# Train on 17141 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 7.8503e-04 - val_loss: 7.7075e-04
# Epoch : 13, MSE : [42.43006720152605]
# -------------------------------------------
# Train on 17141 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 7.7751e-04 - val_loss: 7.6634e-04
# Epoch : 14, MSE : [42.37028594395105]
# -------------------------------------------
# Train on 17141 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 7.7672e-04 - val_loss: 8.2674e-04
# Epoch : 15, MSE : [45.843252456270086]
# -------------------------------------------
# Train on 17141 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 7.7044e-04 - val_loss: 7.5824e-04
# Epoch : 16, MSE : [41.78744133691032]
# -------------------------------------------
# Train on 17141 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 7.8096e-04 - val_loss: 7.6259e-04
# Epoch : 17, MSE : [41.687791488141706]
# -------------------------------------------
# Train on 17141 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 7.7691e-04 - val_loss: 8.0803e-04
# Epoch : 18, MSE : [44.39622877905857]
# -------------------------------------------
# Train on 17141 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 7.7588e-04 - val_loss: 7.9647e-04
# Epoch : 19, MSE : [43.376361852723406]
# -------------------------------------------
# Train on 17141 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 7.7993e-04 - val_loss: 7.9042e-04
# Epoch : 20, MSE : [43.34040768813215]
# -------------------------------------------
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dnn_1_input (InputLayer)     (None, 5)                 0
# _________________________________________________________________
# dnn_1 (Dense)                (None, 128)               768
# _________________________________________________________________
# dnn_2 (Dense)                (None, 64)                8256
# _________________________________________________________________
# dnn_3 (Dense)                (None, 32)                2080
# _________________________________________________________________
# dnn_4 (Dense)                (None, 1)                 33
# =================================================================
# Total params: 11,137
# Trainable params: 11,137
# Non-trainable params: 0
# _________________________________________________________________
# Train on 17140 samples, validate on 4286 samples
# Epoch 1/1
#  - 1s - loss: 9.3575e-04 - val_loss: 8.3224e-04
# Epoch : 1, MSE : [44.84207725343852]
# -------------------------------------------
# Train on 17140 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 8.1806e-04 - val_loss: 8.6648e-04
# Epoch : 2, MSE : [47.043528016015955]
# -------------------------------------------
# Train on 17140 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 8.1316e-04 - val_loss: 8.2146e-04
# Epoch : 3, MSE : [44.665690676978635]
# -------------------------------------------
# Train on 17140 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 7.8310e-04 - val_loss: 7.9611e-04
# Epoch : 4, MSE : [42.71103351915801]
# -------------------------------------------
# Train on 17140 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 7.8947e-04 - val_loss: 8.5109e-04
# Epoch : 5, MSE : [45.93248396400889]
# -------------------------------------------
# Train on 17140 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 7.8010e-04 - val_loss: 8.1683e-04
# Epoch : 6, MSE : [44.404416980303345]
# -------------------------------------------
# Train on 17140 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 7.8928e-04 - val_loss: 8.5399e-04
# Epoch : 7, MSE : [46.43472186197471]
# -------------------------------------------
# Train on 17140 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 7.8586e-04 - val_loss: 7.8565e-04
# Epoch : 8, MSE : [42.58299541210016]
# -------------------------------------------
# Train on 17140 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 7.7543e-04 - val_loss: 7.8795e-04
# Epoch : 9, MSE : [42.63853780813274]
# -------------------------------------------
# Train on 17140 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 7.8125e-04 - val_loss: 8.3381e-04
# Epoch : 10, MSE : [44.901543274524684]
# -------------------------------------------
# Train on 17140 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 7.8054e-04 - val_loss: 8.8843e-04
# Epoch : 11, MSE : [48.456810483035774]
# -------------------------------------------
# Train on 17140 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 7.7323e-04 - val_loss: 7.7615e-04
# Epoch : 12, MSE : [41.88530353586151]
# -------------------------------------------
# Train on 17140 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 7.7690e-04 - val_loss: 7.7603e-04
# Epoch : 13, MSE : [41.69370181178501]
# -------------------------------------------
# Train on 17140 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 7.6176e-04 - val_loss: 8.1323e-04
# Epoch : 14, MSE : [43.43480973694806]
# -------------------------------------------
# Train on 17140 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 7.6011e-04 - val_loss: 7.9401e-04
# Epoch : 15, MSE : [42.42799721641132]
# -------------------------------------------
# Train on 17140 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 7.6322e-04 - val_loss: 8.0004e-04
# Epoch : 16, MSE : [42.64863392703705]
# -------------------------------------------
# Train on 17140 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 7.6522e-04 - val_loss: 7.7983e-04
# Epoch : 17, MSE : [41.38531843570727]
# -------------------------------------------
# Train on 17140 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 7.6453e-04 - val_loss: 8.1316e-04
# Epoch : 18, MSE : [43.48058995501166]
# -------------------------------------------
# Train on 17140 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 7.6245e-04 - val_loss: 8.2451e-04
# Epoch : 19, MSE : [44.306503379816256]
# -------------------------------------------
# Train on 17140 samples, validate on 4286 samples
# Epoch 1/1
#  - 0s - loss: 7.4977e-04 - val_loss: 8.3192e-04
# Epoch : 20, MSE : [44.63875220858186]
# -------------------------------------------
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dnn_1_input (InputLayer)     (None, 6)                 0
# _________________________________________________________________
# dnn_1 (Dense)                (None, 128)               896
# _________________________________________________________________
# dnn_2 (Dense)                (None, 64)                8256
# _________________________________________________________________
# dnn_3 (Dense)                (None, 32)                2080
# _________________________________________________________________
# dnn_4 (Dense)                (None, 1)                 33
# =================================================================
# Total params: 11,265
# Trainable params: 11,265
# Non-trainable params: 0
# _________________________________________________________________
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0010 - val_loss: 8.9762e-04
# Epoch : 1, MSE : [52.10115360827476]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 0s - loss: 8.2455e-04 - val_loss: 7.6656e-04
# Epoch : 2, MSE : [45.354938063520294]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 0s - loss: 8.2476e-04 - val_loss: 7.8114e-04
# Epoch : 3, MSE : [46.12657802852675]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 8.1864e-04 - val_loss: 7.5163e-04
# Epoch : 4, MSE : [44.246992731703166]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 0s - loss: 8.1197e-04 - val_loss: 7.3249e-04
# Epoch : 5, MSE : [42.647711825600815]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 0s - loss: 8.0935e-04 - val_loss: 7.4130e-04
# Epoch : 6, MSE : [43.43805060800881]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 7.9806e-04 - val_loss: 7.1461e-04
# Epoch : 7, MSE : [42.224424002943145]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 0s - loss: 8.0250e-04 - val_loss: 7.2570e-04
# Epoch : 8, MSE : [42.813276552865965]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 0s - loss: 7.9608e-04 - val_loss: 7.2687e-04
# Epoch : 9, MSE : [42.68929812287485]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 0s - loss: 7.9926e-04 - val_loss: 7.6461e-04
# Epoch : 10, MSE : [44.928391254850936]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 0s - loss: 7.9227e-04 - val_loss: 7.2455e-04
# Epoch : 11, MSE : [42.5292344108452]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 0s - loss: 7.8804e-04 - val_loss: 7.6019e-04
# Epoch : 12, MSE : [43.59868329996133]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 0s - loss: 7.8229e-04 - val_loss: 7.2223e-04
# Epoch : 13, MSE : [42.39304183382706]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 0s - loss: 7.8987e-04 - val_loss: 7.4633e-04
# Epoch : 14, MSE : [43.16848912759604]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 0s - loss: 7.8437e-04 - val_loss: 7.5434e-04
# Epoch : 15, MSE : [43.93892507740349]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 7.7665e-04 - val_loss: 7.4053e-04
# Epoch : 16, MSE : [43.07682739801451]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 0s - loss: 7.8283e-04 - val_loss: 7.0818e-04
# Epoch : 17, MSE : [41.484318770738106]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 7.8803e-04 - val_loss: 7.4856e-04
# Epoch : 18, MSE : [43.36592334033944]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 7.7108e-04 - val_loss: 7.1320e-04
# Epoch : 19, MSE : [42.15229592276976]
# -------------------------------------------
# Train on 17140 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 7.9042e-04 - val_loss: 7.2418e-04
# Epoch : 20, MSE : [41.681233036784135]
# -------------------------------------------
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dnn_1_input (InputLayer)     (None, 7)                 0
# _________________________________________________________________
# dnn_1 (Dense)                (None, 128)               1024
# _________________________________________________________________
# dnn_2 (Dense)                (None, 64)                8256
# _________________________________________________________________
# dnn_3 (Dense)                (None, 32)                2080
# _________________________________________________________________
# dnn_4 (Dense)                (None, 1)                 33
# =================================================================
# Total params: 11,393
# Trainable params: 11,393
# Non-trainable params: 0
# _________________________________________________________________
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 9.0816e-04 - val_loss: 7.7988e-04
# Epoch : 1, MSE : [43.32545625258072]
# -------------------------------------------
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 7.9924e-04 - val_loss: 8.3439e-04
# Epoch : 2, MSE : [45.092793029952155]
# -------------------------------------------
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 7.9810e-04 - val_loss: 9.2306e-04
# Epoch : 3, MSE : [51.22088322154184]
# -------------------------------------------
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 0s - loss: 7.8059e-04 - val_loss: 8.1321e-04
# Epoch : 4, MSE : [45.606614938977806]
# -------------------------------------------
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 7.7996e-04 - val_loss: 7.7098e-04
# Epoch : 5, MSE : [42.594932394464905]
# -------------------------------------------
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 7.8823e-04 - val_loss: 8.1401e-04
# Epoch : 6, MSE : [44.92570197990048]
# -------------------------------------------
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 0s - loss: 7.6786e-04 - val_loss: 7.8311e-04
# Epoch : 7, MSE : [43.82016414838742]
# -------------------------------------------
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 7.8652e-04 - val_loss: 7.8392e-04
# Epoch : 8, MSE : [42.9160329849721]
# -------------------------------------------
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 7.6907e-04 - val_loss: 7.9737e-04
# Epoch : 9, MSE : [44.5587481425674]
# -------------------------------------------
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 0s - loss: 7.7497e-04 - val_loss: 7.3698e-04
# Epoch : 10, MSE : [40.84815117555946]
# -------------------------------------------
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 0s - loss: 7.6689e-04 - val_loss: 7.9998e-04
# Epoch : 11, MSE : [43.82089617186955]
# -------------------------------------------
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 7.6519e-04 - val_loss: 7.6937e-04
# Epoch : 12, MSE : [42.80812565950835]
# -------------------------------------------
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 0s - loss: 7.8112e-04 - val_loss: 7.4216e-04
# Epoch : 13, MSE : [41.16428805998052]
# -------------------------------------------
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 0s - loss: 7.7910e-04 - val_loss: 7.7624e-04
# Epoch : 14, MSE : [43.11406455500448]
# -------------------------------------------
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 7.5977e-04 - val_loss: 7.5472e-04
# Epoch : 15, MSE : [41.92338940985335]
# -------------------------------------------
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 7.5867e-04 - val_loss: 8.1051e-04
# Epoch : 16, MSE : [45.680088072837925]
# -------------------------------------------
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 0s - loss: 7.5494e-04 - val_loss: 7.5119e-04
# Epoch : 17, MSE : [41.80236936381395]
# -------------------------------------------
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 0s - loss: 7.5570e-04 - val_loss: 8.3823e-04
# Epoch : 18, MSE : [46.70400202188913]
# -------------------------------------------
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 0s - loss: 7.5213e-04 - val_loss: 7.4049e-04
# Epoch : 19, MSE : [41.26279081951517]
# -------------------------------------------
# Train on 17139 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 7.5516e-04 - val_loss: 7.4574e-04
# Epoch : 20, MSE : [41.2693147491571]
# -------------------------------------------
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dnn_1_input (InputLayer)     (None, 8)                 0
# _________________________________________________________________
# dnn_1 (Dense)                (None, 128)               1152
# _________________________________________________________________
# dnn_2 (Dense)                (None, 64)                8256
# _________________________________________________________________
# dnn_3 (Dense)                (None, 32)                2080
# _________________________________________________________________
# dnn_4 (Dense)                (None, 1)                 33
# =================================================================
# Total params: 11,521
# Trainable params: 11,521
# Non-trainable params: 0
# _________________________________________________________________
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0012 - val_loss: 7.4338e-04
# Epoch : 1, MSE : [44.4213081386917]
# -------------------------------------------
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 8.0258e-04 - val_loss: 6.7979e-04
# Epoch : 2, MSE : [41.072878158908914]
# -------------------------------------------
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 8.0893e-04 - val_loss: 6.9505e-04
# Epoch : 3, MSE : [41.754211259293996]
# -------------------------------------------
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 8.0331e-04 - val_loss: 7.6094e-04
# Epoch : 4, MSE : [45.22832162301456]
# -------------------------------------------
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 8.1425e-04 - val_loss: 7.2535e-04
# Epoch : 5, MSE : [42.84113729986578]
# -------------------------------------------
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 7.9323e-04 - val_loss: 7.0292e-04
# Epoch : 6, MSE : [41.900048518754396]
# -------------------------------------------
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 7.9615e-04 - val_loss: 8.8462e-04
# Epoch : 7, MSE : [53.317149178694734]
# -------------------------------------------
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 7.9598e-04 - val_loss: 6.9885e-04
# Epoch : 8, MSE : [41.779222232748644]
# -------------------------------------------
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 7.9116e-04 - val_loss: 8.2368e-04
# Epoch : 9, MSE : [49.422057938999565]
# -------------------------------------------
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 7.9297e-04 - val_loss: 6.6467e-04
# Epoch : 10, MSE : [39.985210254815925]
# -------------------------------------------
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 7.9244e-04 - val_loss: 7.0880e-04
# Epoch : 11, MSE : [43.010026774822435]
# -------------------------------------------
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 7.6930e-04 - val_loss: 6.8213e-04
# Epoch : 12, MSE : [40.85681804221388]
# -------------------------------------------
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 0s - loss: 7.7254e-04 - val_loss: 6.9430e-04
# Epoch : 13, MSE : [41.990276489042124]
# -------------------------------------------
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 7.6541e-04 - val_loss: 6.8283e-04
# Epoch : 14, MSE : [41.7992046828815]
# -------------------------------------------
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 0s - loss: 7.5526e-04 - val_loss: 7.1874e-04
# Epoch : 15, MSE : [42.8393089976244]
# -------------------------------------------
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 7.6386e-04 - val_loss: 6.6887e-04
# Epoch : 16, MSE : [40.50967224729723]
# -------------------------------------------
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 7.5461e-04 - val_loss: 6.4029e-04
# Epoch : 17, MSE : [39.319205374632766]
# -------------------------------------------
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 7.8052e-04 - val_loss: 7.0010e-04
# Epoch : 18, MSE : [42.10160855248355]
# -------------------------------------------
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 7.5530e-04 - val_loss: 6.7025e-04
# Epoch : 19, MSE : [40.33866469806361]
# -------------------------------------------
# Train on 17138 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 7.5517e-04 - val_loss: 6.6710e-04
# Epoch : 20, MSE : [40.64180352740716]
# -------------------------------------------
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dnn_1_input (InputLayer)     (None, 9)                 0
# _________________________________________________________________
# dnn_1 (Dense)                (None, 128)               1280
# _________________________________________________________________
# dnn_2 (Dense)                (None, 64)                8256
# _________________________________________________________________
# dnn_3 (Dense)                (None, 32)                2080
# _________________________________________________________________
# dnn_4 (Dense)                (None, 1)                 33
# =================================================================
# Total params: 11,649
# Trainable params: 11,649
# Non-trainable params: 0
# _________________________________________________________________
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0017 - val_loss: 6.9786e-04
# Epoch : 1, MSE : [41.7292838083344]
# -------------------------------------------
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 8.2956e-04 - val_loss: 7.2860e-04
# Epoch : 2, MSE : [43.44887550787577]
# -------------------------------------------
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 8.2273e-04 - val_loss: 0.0011
# Epoch : 3, MSE : [66.04543479117689]
# -------------------------------------------
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 8.0787e-04 - val_loss: 0.0010
# Epoch : 4, MSE : [59.87614400322082]
# -------------------------------------------
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 8.0205e-04 - val_loss: 8.3003e-04
# Epoch : 5, MSE : [49.020940968181264]
# -------------------------------------------
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 7.8777e-04 - val_loss: 7.4351e-04
# Epoch : 6, MSE : [44.65096774263248]
# -------------------------------------------
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 8.1882e-04 - val_loss: 7.1026e-04
# Epoch : 7, MSE : [42.4057191859886]
# -------------------------------------------
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 7.9655e-04 - val_loss: 7.3514e-04
# Epoch : 8, MSE : [43.32954550384337]
# -------------------------------------------
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 7.9449e-04 - val_loss: 7.0822e-04
# Epoch : 9, MSE : [42.29859450072787]
# -------------------------------------------
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 7.9859e-04 - val_loss: 7.7181e-04
# Epoch : 10, MSE : [45.12253757335409]
# -------------------------------------------
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 7.8813e-04 - val_loss: 7.0393e-04
# Epoch : 11, MSE : [41.724973678351276]
# -------------------------------------------
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 7.8526e-04 - val_loss: 7.0961e-04
# Epoch : 12, MSE : [41.669700902760475]
# -------------------------------------------
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 7.8758e-04 - val_loss: 8.6801e-04
# Epoch : 13, MSE : [50.59493688647534]
# -------------------------------------------
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 7.8156e-04 - val_loss: 7.2034e-04
# Epoch : 14, MSE : [42.179103160461864]
# -------------------------------------------
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 7.7494e-04 - val_loss: 7.4701e-04
# Epoch : 15, MSE : [44.14100500050516]
# -------------------------------------------
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 7.7430e-04 - val_loss: 7.1925e-04
# Epoch : 16, MSE : [42.334449457072125]
# -------------------------------------------
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 7.7476e-04 - val_loss: 7.1519e-04
# Epoch : 17, MSE : [42.14916712890322]
# -------------------------------------------
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 7.7918e-04 - val_loss: 7.1245e-04
# Epoch : 18, MSE : [41.6700763510864]
# -------------------------------------------
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 7.6455e-04 - val_loss: 7.6790e-04
# Epoch : 19, MSE : [45.345026686851874]
# -------------------------------------------
# Train on 17137 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 7.6474e-04 - val_loss: 7.0252e-04
# Epoch : 20, MSE : [40.74176122707173]
# -------------------------------------------
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dnn_1_input (InputLayer)     (None, 10)                0
# _________________________________________________________________
# dnn_1 (Dense)                (None, 128)               1408
# _________________________________________________________________
# dnn_2 (Dense)                (None, 64)                8256
# _________________________________________________________________
# dnn_3 (Dense)                (None, 32)                2080
# _________________________________________________________________
# dnn_4 (Dense)                (None, 1)                 33
# =================================================================
# Total params: 11,777
# Trainable params: 11,777
# Non-trainable params: 0
# _________________________________________________________________
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 0.0012 - val_loss: 8.6028e-04
# Epoch : 1, MSE : [51.08262728082031]
# -------------------------------------------
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 8.3134e-04 - val_loss: 7.3690e-04
# Epoch : 2, MSE : [43.82448186360053]
# -------------------------------------------
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 8.1788e-04 - val_loss: 6.9176e-04
# Epoch : 3, MSE : [41.18575212665427]
# -------------------------------------------
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 7.9906e-04 - val_loss: 7.0810e-04
# Epoch : 4, MSE : [42.72710774011509]
# -------------------------------------------
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 8.1036e-04 - val_loss: 8.1224e-04
# Epoch : 5, MSE : [47.689408654929586]
# -------------------------------------------
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 8.0871e-04 - val_loss: 0.0010
# Epoch : 6, MSE : [60.36424674306497]
# -------------------------------------------
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 7.9575e-04 - val_loss: 6.9392e-04
# Epoch : 7, MSE : [41.72521807029681]
# -------------------------------------------
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 7.9264e-04 - val_loss: 9.6202e-04
# Epoch : 8, MSE : [55.77143377977873]
# -------------------------------------------
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 7.8145e-04 - val_loss: 7.8544e-04
# Epoch : 9, MSE : [46.29520197925134]
# -------------------------------------------
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 7.9898e-04 - val_loss: 6.8871e-04
# Epoch : 10, MSE : [41.62662881695282]
# -------------------------------------------
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 7.9230e-04 - val_loss: 7.5606e-04
# Epoch : 11, MSE : [46.823545517263774]
# -------------------------------------------
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 7.8516e-04 - val_loss: 6.8610e-04
# Epoch : 12, MSE : [41.371611521051086]
# -------------------------------------------
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 7.8702e-04 - val_loss: 7.1687e-04
# Epoch : 13, MSE : [43.015687588642685]
# -------------------------------------------
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 7.8353e-04 - val_loss: 6.9242e-04
# Epoch : 14, MSE : [41.59240643167435]
# -------------------------------------------
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 7.8283e-04 - val_loss: 7.1016e-04
# Epoch : 15, MSE : [42.427597841356516]
# -------------------------------------------
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 7.8089e-04 - val_loss: 7.7131e-04
# Epoch : 16, MSE : [46.24312016300382]
# -------------------------------------------
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 7.7860e-04 - val_loss: 6.8192e-04
# Epoch : 17, MSE : [41.064234489473186]
# -------------------------------------------
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 7.7490e-04 - val_loss: 6.8388e-04
# Epoch : 18, MSE : [40.96919505442918]
# -------------------------------------------
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 7.8650e-04 - val_loss: 6.7292e-04
# Epoch : 19, MSE : [40.702074529430824]
# -------------------------------------------
# Train on 17136 samples, validate on 4285 samples
# Epoch 1/1
#  - 1s - loss: 7.7884e-04 - val_loss: 6.7641e-04
# Epoch : 20, MSE : [40.89106882517467]
# -------------------------------------------
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dnn_1_input (InputLayer)     (None, 11)                0
# _________________________________________________________________
# ...
# Epoch : 17, MSE : [21.678694422726483]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 1s - loss: 7.0067e-04 - val_loss: 7.8453e-04
# Epoch : 18, MSE : [24.39207524932063]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 1s - loss: 7.0017e-04 - val_loss: 7.3146e-04
# Epoch : 19, MSE : [23.00589697168605]
# -------------------------------------------
# Train on 22036 samples, validate on 5509 samples
# Epoch 1/1
#  - 1s - loss: 7.0662e-04 - val_loss: 6.8146e-04
# Epoch : 20, MSE : [21.240607854526605]
# -------------------------------------------
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dnn_1_input (InputLayer)     (None, 7)                 0
# _________________________________________________________________
# dnn_1 (Dense)                (None, 128)               1024
# _________________________________________________________________
# dnn_2 (Dense)                (None, 64)                8256
# _________________________________________________________________
# dnn_3 (Dense)                (None, 32)                2080
# _________________________________________________________________
# dnn_4 (Dense)                (None, 1)                 33
# =================================================================
# Total params: 11,393
# Trainable params: 11,393
# Non-trainable params: 0
# _________________________________________________________________
# Train on 22035 samples, validate on 5509 samples
# Epoch 1/1
#  - 2s - loss: 9.6286e-04 - val_loss: 7.7248e-04
# Epoch : 1, MSE : [21.61313877777769]
# -------------------------------------------
# Train on 22035 samples, validate on 5509 samples
# Epoch 1/1
#  - 1s - loss: 7.4408e-04 - val_loss: 7.6562e-04
# Epoch : 2, MSE : [21.94504432944403]
# -------------------------------------------
# Train on 22035 samples, validate on 5509 samples
# Epoch 1/1
#  - 1s - loss: 7.4143e-04 - val_loss: 9.8813e-04
# Epoch : 3, MSE : [28.75295747160795]
# -------------------------------------------
# Train on 22035 samples, validate on 5509 samples
# Epoch 1/1
#  - 1s - loss: 7.1403e-04 - val_loss: 8.0618e-04
# Epoch : 4, MSE : [22.560145274451813]
# -------------------------------------------
# Train on 22035 samples, validate on 5509 samples
# Epoch 1/1
#  - 1s - loss: 7.1083e-04 - val_loss: 7.5499e-04
# Epoch : 5, MSE : [21.321768601224004]
# -------------------------------------------
# Train on 22035 samples, validate on 5509 samples
# Epoch 1/1
#  - 1s - loss: 7.0711e-04 - val_loss: 9.6315e-04
# Epoch : 6, MSE : [27.695589576078092]
# -------------------------------------------
# Train on 22035 samples, validate on 5509 samples
# Epoch 1/1
#  - 1s - loss: 7.1017e-04 - val_loss: 8.8676e-04
# Epoch : 7, MSE : [25.128804065541054]
# -------------------------------------------
# Train on 22035 samples, validate on 5509 samples
# Epoch 1/1
#  - 1s - loss: 7.1203e-04 - val_loss: 7.0105e-04
# Epoch : 8, MSE : [19.693065982684008]
# -------------------------------------------
# Train on 22035 samples, validate on 5509 samples
# Epoch 1/1
#  - 1s - loss: 6.6660e-04 - val_loss: 7.5380e-04
# Epoch : 9, MSE : [21.07667513342623]
# -------------------------------------------
# Train on 22035 samples, validate on 5509 samples
# Epoch 1/1
#  - 1s - loss: 6.8759e-04 - val_loss: 7.1423e-04
# Epoch : 10, MSE : [20.170022071192918]
# -------------------------------------------
# Train on 22035 samples, validate on 5509 samples
# Epoch 1/1
#  - 1s - loss: 6.7209e-04 - val_loss: 8.0373e-04
# Epoch : 11, MSE : [22.67218878562164]
# -------------------------------------------
# Train on 22035 samples, validate on 5509 samples
# Epoch 1/1
#  - 1s - loss: 6.9165e-04 - val_loss: 7.4730e-04
# Epoch : 12, MSE : [20.88472604610782]
# -------------------------------------------
# Train on 22035 samples, validate on 5509 samples
# Epoch 1/1
#  - 1s - loss: 6.7452e-04 - val_loss: 7.1839e-04
# Epoch : 13, MSE : [20.006100077951764]
# -------------------------------------------
# Train on 22035 samples, validate on 5509 samples
# Epoch 1/1
#  - 1s - loss: 6.6956e-04 - val_loss: 7.3011e-04
# Epoch : 14, MSE : [20.509768235695212]
# -------------------------------------------
# Train on 22035 samples, validate on 5509 samples
# Epoch 1/1
#  - 1s - loss: 6.7138e-04 - val_loss: 7.5339e-04
# Epoch : 15, MSE : [21.25628981162828]
# -------------------------------------------
# Train on 22035 samples, validate on 5509 samples
# Epoch 1/1
#  - 1s - loss: 6.5953e-04 - val_loss: 7.0990e-04
# Epoch : 16, MSE : [19.801204557512733]
# -------------------------------------------
# Train on 22035 samples, validate on 5509 samples
# Epoch 1/1
#  - 1s - loss: 6.7991e-04 - val_loss: 7.1467e-04
# Epoch : 17, MSE : [20.00605724165813]
# -------------------------------------------
# Train on 22035 samples, validate on 5509 samples
# Epoch 1/1
#  - 1s - loss: 6.7154e-04 - val_loss: 7.7676e-04
# Epoch : 18, MSE : [22.017685258149537]
# -------------------------------------------
# Train on 22035 samples, validate on 5509 samples
# Epoch 1/1
#  - 1s - loss: 6.7139e-04 - val_loss: 7.0797e-04
# Epoch : 19, MSE : [19.846474274575712]
# -------------------------------------------
# Train on 22035 samples, validate on 5509 samples
# Epoch 1/1
#  - 1s - loss: 6.6311e-04 - val_loss: 7.0187e-04
# Epoch : 20, MSE : [19.581777083352396]
# -------------------------------------------
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dnn_1_input (InputLayer)     (None, 8)                 0
# _________________________________________________________________
# dnn_1 (Dense)                (None, 128)               1152
# _________________________________________________________________
# dnn_2 (Dense)                (None, 64)                8256
# _________________________________________________________________
# dnn_3 (Dense)                (None, 32)                2080
# _________________________________________________________________
# dnn_4 (Dense)                (None, 1)                 33
# =================================================================
# Total params: 11,521
# Trainable params: 11,521
# Non-trainable params: 0
# _________________________________________________________________
# Train on 22034 samples, validate on 5509 samples
# Epoch 1/1
#  - 2s - loss: 0.0011 - val_loss: 7.0171e-04
# Epoch : 1, MSE : [20.957095999099725]
# -------------------------------------------
# Train on 22034 samples, validate on 5509 samples
# Epoch 1/1
#  - 1s - loss: 7.5054e-04 - val_loss: 7.4244e-04
# Epoch : 2, MSE : [22.258483370202736]
# -------------------------------------------
# Train on 22034 samples, validate on 5509 samples
# Epoch 1/1
#  - 1s - loss: 7.3960e-04 - val_loss: 7.9525e-04
# Epoch : 3, MSE : [23.848425294385052]
# -------------------------------------------
# Train on 22034 samples, validate on 5509 samples
# Epoch 1/1
#  - 1s - loss: 7.1157e-04 - val_loss: 6.8352e-04
# Epoch : 4, MSE : [20.266098047012733]
# -------------------------------------------
# Train on 22034 samples, validate on 5509 samples
# Epoch 1/1
#  - 1s - loss: 7.0455e-04 - val_loss: 6.4843e-04
# Epoch : 5, MSE : [19.376005028868732]
# -------------------------------------------
# Train on 22034 samples, validate on 5509 samples
# Epoch 1/1
#  - 1s - loss: 6.9928e-04 - val_loss: 7.2981e-04
# Epoch : 6, MSE : [21.700072430906953]
# -------------------------------------------
# Train on 22034 samples, validate on 5509 samples
# Epoch 1/1
#  - 1s - loss: 7.2637e-04 - val_loss: 6.6099e-04
# Epoch : 7, MSE : [19.67661980255465]
# -------------------------------------------
# Train on 22034 samples, validate on 5509 samples
# Epoch 1/1
#  - 1s - loss: 7.0652e-04 - val_loss: 6.5497e-04
# Epoch : 8, MSE : [19.60056702787736]
# -------------------------------------------
# Train on 22034 samples, validate on 5509 samples
# Epoch 1/1
#  - 1s - loss: 6.8979e-04 - val_loss: 6.4107e-04
# Epoch : 9, MSE : [19.23102065270806]
# -------------------------------------------
# Train on 22034 samples, validate on 5509 samples
# Epoch 1/1
#  - 1s - loss: 6.9182e-04 - val_loss: 6.5744e-04
# Epoch : 10, MSE : [19.554375202788613]
# -------------------------------------------
# Train on 22034 samples, validate on 5509 samples
# Epoch 1/1
#  - 1s - loss: 6.8372e-04 - val_loss: 7.1705e-04
# Epoch : 11, MSE : [21.572830536273315]
# -------------------------------------------
# Train on 22034 samples, validate on 5509 samples
# Epoch 1/1
#  - 1s - loss: 6.8655e-04 - val_loss: 6.7398e-04
# Epoch : 12, MSE : [20.15025446122341]
# -------------------------------------------
# Train on 22034 samples, validate on 5509 samples
# Epoch 1/1
#  - 1s - loss: 6.9658e-04 - val_loss: 6.4988e-04
# Epoch : 13, MSE : [19.334667001484046]
# -------------------------------------------
# Train on 22034 samples, validate on 5509 samples
# Epoch 1/1
#  - 1s - loss: 6.7139e-04 - val_loss: 6.6908e-04
# Epoch : 14, MSE : [19.98771276451043]
# -------------------------------------------
# Train on 22034 samples, validate on 5509 samples
# Epoch 1/1
#  - 1s - loss: 6.8687e-04 - val_loss: 6.9791e-04
# Epoch : 15, MSE : [20.756420354751633]
# -------------------------------------------
# Train on 22034 samples, validate on 5509 samples
# Epoch 1/1
#  - 1s - loss: 6.7769e-04 - val_loss: 6.6206e-04
# Epoch : 16, MSE : [19.740867401689655]
# -------------------------------------------
# Train on 22034 samples, validate on 5509 samples
# Epoch 1/1
#  - 1s - loss: 6.9053e-04 - val_loss: 6.5078e-04
# Epoch : 17, MSE : [19.446901915951862]
# -------------------------------------------
# Train on 22034 samples, validate on 5509 samples
# Epoch 1/1
#  - 1s - loss: 6.8182e-04 - val_loss: 7.3851e-04
# Epoch : 18, MSE : [22.11769596998083]
# -------------------------------------------
# Train on 22034 samples, validate on 5509 samples
# Epoch 1/1
#  - 1s - loss: 6.7903e-04 - val_loss: 6.9853e-04
# Epoch : 19, MSE : [20.88868662651508]
# -------------------------------------------
# Train on 22034 samples, validate on 5509 samples
# Epoch 1/1
#  - 1s - loss: 6.7779e-04 - val_loss: 6.7544e-04
# Epoch : 20, MSE : [20.062818956164534]
# -------------------------------------------
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dnn_1_input (InputLayer)     (None, 9)                 0
# _________________________________________________________________
# dnn_1 (Dense)                (None, 128)               1280
# _________________________________________________________________
# dnn_2 (Dense)                (None, 64)                8256
# _________________________________________________________________
# dnn_3 (Dense)                (None, 32)                2080
# _________________________________________________________________
# dnn_4 (Dense)                (None, 1)                 33
# =================================================================
# Total params: 11,649
# Trainable params: 11,649
# Non-trainable params: 0
# _________________________________________________________________
# Train on 22033 samples, validate on 5509 samples
# Epoch 1/1
#  - 2s - loss: 0.0011 - val_loss: 6.6650e-04
# Epoch : 1, MSE : [21.040956655510435]
# -------------------------------------------
# Train on 22033 samples, validate on 5509 samples
# Epoch 1/1
#  - 1s - loss: 7.8691e-04 - val_loss: 9.1354e-04
# Epoch : 2, MSE : [28.908555084998476]
# -------------------------------------------
# Train on 22033 samples, validate on 5509 samples
# Epoch 1/1
#  - 1s - loss: 7.8521e-04 - val_loss: 8.2188e-04
# Epoch : 3, MSE : [26.481392423946666]
# -------------------------------------------
# Train on 22033 samples, validate on 5509 samples
# Epoch 1/1
#  - 1s - loss: 7.6520e-04 - val_loss: 6.4197e-04
# Epoch : 4, MSE : [20.4313169107543]
# -------------------------------------------
# Train on 22033 samples, validate on 5509 samples
# Epoch 1/1
#  - 1s - loss: 7.3487e-04 - val_loss: 6.4023e-04
# Epoch : 5, MSE : [20.417774134285878]
# -------------------------------------------
# Train on 22033 samples, validate on 5509 samples
# Epoch 1/1
#  - 1s - loss: 7.2750e-04 - val_loss: 7.2784e-04
# Epoch : 6, MSE : [23.136148714525287]
# -------------------------------------------
# Train on 22033 samples, validate on 5509 samples
# Epoch 1/1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-0cfe8506ff8c> in <module>
#      13         sc, X_train, y_train, X_test, y_test = fetchData(cursor,station,windowSize)
#      14         regressor = buildModel(windowSize-1)
# ---> 15         mse = train(regressor,sc,X_train, y_train, X_test, y_test,epochs)
#      16         MSEs.append(mse)
#      17     print('check point at ' + str(datetime.datetime.now()))
#
# <ipython-input-5-05dd6bcec01f> in train(regressor, sc, X_train, y_train, X_test, y_test, epochs)
#     109
#     110     for i in range(epochs):
# --> 111         regressor.fit(X_train, y_train,validation_split=0.2, epochs = 1, batch_size = 32,verbose=2)
#     112         predicted = sc.inverse_transform(regressor.predict(X_test))
#     113         originY = sc.inverse_transform (y_test)
#
# c:\users\ming\appdata\local\programs\python\python36\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# c:\users\ming\appdata\local\programs\python\python36\lib\site-packages\keras\engine\training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     210                         val_outs = test_loop(model, val_f, val_ins,
#     211                                              batch_size=batch_size,
# --> 212                                              verbose=0)
#     213                         val_outs = to_list(val_outs)
#     214                         # Same labels assumed.
#
# c:\users\ming\appdata\local\programs\python\python36\lib\site-packages\keras\engine\training_arrays.py in test_loop(model, f, ins, batch_size, verbose, steps)
#     390                 ins_batch[i] = ins_batch[i].toarray()
#     391
# --> 392             batch_outs = f(ins_batch)
#     393             if isinstance(batch_outs, list):
#     394                 if batch_index == 0:
#
# c:\users\ming\appdata\local\programs\python\python36\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# c:\users\ming\appdata\local\programs\python\python36\lib\site-packages\keras\backend\tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# c:\users\ming\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
X_train.shape
# Out:
# (21422, 9, 1)
